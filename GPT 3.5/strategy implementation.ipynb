# %%
# BUY RULE:
# if (bm > 1.5 AND mom12m > 1.0) OR mve > 1.5:
#     signal = BUY

# SELL RULE:
# if bm < -1.5 OR mom12m < -1.0:
#     signal = SELL

# %%
import pandas as pd
import numpy as np

green_cleaned = pd.read_csv('../green cleaned.csv', dtype={'ncusip': 'string'})
green_cleaned['ret_fwd_1'] = (green_cleaned.groupby('permno')['ret_excess'].shift(-1) )

# %%
variables = ['datadate', 'permno', 'ticker', 'comnam', 'bm', 'mom12m', 'mve', 'ret_fwd_1']

# %%
start_date = '2021-09-30'

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()
    
# BUY RULE:
# if bm > 0.5 AND mom12m > 0.5 AND mve > 0.5:
#     signal = BUY

# SELL RULE:
# if bm < -1.5 OR mom12m < -1.0:
#     signal = SELL

# │  BUY RULE:                                                                                                      │
# │  if (bm > 1.0 OR mom12m > 1.0) AND mve > 1.0:                                                                   │
# │      signal = BUY                                                                                               │
# │                                                                                                                 │
# │  SELL RULE:                                                                                                     │
# │  if bm < -1.5 AND mom12m < -1.5:                                                                                │
# │      signal = SELL  

conditions = [
    ( (analysis_df['bm'] > 1.0) & (analysis_df['mom12m'] > 0.5) ) | ( (analysis_df['mve'] > 2.0) ),
    
    ( (analysis_df['bm'] < -1.0) & (analysis_df['mom12m'] < -0.5) ) | ( (analysis_df['mve'] < -2.0) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2021.csv', index=False)
sells.to_csv('sells_2021.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                            comnam  ret_fwd_1
# 15878   2021-09-30   12073   PBCT      PEOPLES UNITED FINANCIAL INC  -0.008443
# 17541   2021-09-30   12369     GM                 GENERAL MOTORS CO   0.032631
# 21326   2021-09-30   12872    MPC           MARATHON PETROLEUM CORP   0.066656
# 24070   2021-09-30   13641   FANG            DIAMONDBACK ENERGY INC   0.132249
# 27197   2021-09-30   13936    PVH                        P V H CORP   0.063625
# 27371   2021-09-30   13963   NWSA                     NEWS CORP NEW  -0.026774
# 32979   2021-09-30   14889    CFG      CITIZENS FINANCIAL GROUP INC   0.016816
# 33968   2021-09-30   15069    MRO                 MARATHON OIL CORP   0.193855
# 37409   2021-09-30   15707    HPE     HEWLETT PACKARD ENTERPRISE CO   0.028070
# 64645   2021-09-30   21186    WRK                       WESTROCK CO  -0.034718
# 92175   2021-09-30   25081    CMA                      COMERICA INC   0.057019
# 96460   2021-09-30   25785      F                 FORD MOTOR CO DEL   0.206215
# 115408  2021-09-30   34746   FITB               FIFTH THIRD BANCORP   0.025683
# 116811  2021-09-30   35044     RF        REGIONS FINANCIAL CORP NEW   0.111215
# 121846  2021-09-30   38703    WFC              WELLS FARGO & CO NEW   0.102349
# 126759  2021-09-30   40125    DXC               D X C TECHNOLOGY CO  -0.030943
# 134665  2021-09-30   42906   HBAN         HUNTINGTON BANCSHARES INC   0.018111
# 153743  2021-09-30   49015    LNC             LINCOLN NATIONAL CORP   0.055564
# 165432  2021-09-30   53613     MU             MICRON TECHNOLOGY INC  -0.026486
# 172774  2021-09-30   57904    AFL                         AFLAC INC   0.029542
# 182542  2021-09-30   60442    PNC  P N C FINANCIAL SERVICES GRP INC   0.085054
# 194992  2021-09-30   64995    KEY                       KEYCORP NEW   0.076318
# 199839  2021-09-30   66384    WDC              WESTERN DIGITAL CORP  -0.073529
# 200378  2021-09-30   66800    AIG  AMERICAN INTERNATIONAL GROUP INC   0.076517
# 202322  2021-09-30   69032     MS   MORGAN STANLEY DEAN WITTER & CO   0.063406
# 202666  2021-09-30   69649    RJF       RAYMOND JAMES FINANCIAL INC   0.068379
# 221147  2021-09-30   77496    MHK             MOHAWK INDUSTRIES INC  -0.001071
# 231563  2021-09-30   81055    COF        CAPITAL ONE FINANCIAL CORP  -0.067543
# 236466  2021-09-30   82775    HIG   HARTFORD FINANCIAL SVCS GRP INC   0.038150
# 239544  2021-09-30   84129   ZION          ZIONS BANCORPORATION N A   0.017774
# 248964  2021-09-30   86868     GS           GOLDMAN SACHS GROUP INC   0.093432
# 261425  2021-09-30   90386    MOS                     MOSAIC CO NEW   0.163774
#
# --- SELL ---
#           datadate  permno ticker                         comnam  ret_fwd_1
# 136368  2021-09-30   43449    MCD                 MCDONALDS CORP   0.018415
# 244259  2021-09-30   85753   VRSN                   VERISIGN INC   0.086142
# 249688  2021-09-30   86996   SBAC  S B A COMMUNICATIONS CORP NEW   0.044650
# 258753  2021-09-30   89533   WYNN               WYNN RESORTS LTD   0.059587

# %%
start_date = '2021-12-31'

# BUY RULE:
# if bm > 1.5 AND mom12m > 1.5:
#     signal = BUY

# SELL RULE:
# if mve < -2.0:
#     signal = SELL

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()

conditions = [
    ( (analysis_df['bm'] > 2.0) & (analysis_df['mom12m'] < -1.0) ),
    
    ( (analysis_df['bm'] < -2.0) ) | ( (analysis_df['mom12m'] > 1.0) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2022.csv', index=False)
sells.to_csv('sells_2022.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                    comnam  ret_fwd_1
# 177554  2021-12-31   59248    TAP  MOLSON COORS BEVERAGE CO   0.028263
#
# --- SELL ---
#           datadate  permno ticker                       comnam  ret_fwd_1
# 801     2021-12-31   10104   ORCL                  ORACLE CORP  -0.065703
# 12756   2021-12-31   11786   SIVB        S V B FINANCIAL GROUP  -0.139095
# 13274   2021-12-31   11850    XOM             EXXON MOBIL CORP   0.241379
# 13364   2021-12-31   11891    MGM  M G M RESORTS INTERNATIONAL  -0.048128
# 18140   2021-12-31   12448    FRC  FIRST REPUBLIC BANK S F NEW  -0.158346
# ...            ...     ...    ...                          ...        ...
# 262523  2021-12-31   90664   DXCM                   DEXCOM INC  -0.198287
# 263335  2021-12-31   90880    AMP     AMERIPRISE FINANCIAL INC   0.008785
# 267223  2021-12-31   92402   MSCI                  M S C I INC  -0.124973
# 268925  2021-12-31   93132   FTNT                 FORTINET INC  -0.172955
# 269218  2021-12-31   93436   TSLA                    TESLA INC  -0.113609
#
# [67 rows x 5 columns]

# %%
start_date = '2022-12-31'

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()

conditions = [
    ( (analysis_df['bm'] > 0.5) & (analysis_df['mom12m'] > 0.5) ) | (analysis_df['mve'] > 0.5),
    
    ( (analysis_df['bm'] < -1.5) ) | ( (analysis_df['mom12m'] < -1.5) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2023.csv', index=False)
sells.to_csv('sells_2023.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                            comnam  ret_fwd_1
# 813     2022-12-31   10104   ORCL                       ORACLE CORP   0.082627
# 1180    2022-12-31   10107   MSFT                    MICROSOFT CORP   0.029817
# 2182    2022-12-31   10145    HON       HONEYWELL INTERNATIONAL INC  -0.030658
# 4993    2022-12-31   10516    ADM         ARCHER DANIELS MIDLAND CO  -0.111201
# 5742    2022-12-31   10696   FISV                        FISERV INC   0.052006
# 8783    2022-12-31   11308     KO                      COCA COLA CO  -0.039501
# 9693    2022-12-31   11404     ED           CONSOLIDATED EDISON INC  -0.003500
# 12686   2022-12-31   11762    ETN                    EATON CORP PLC   0.030014
# 13286   2022-12-31   11850    XOM                  EXXON MOBIL CORP   0.048268
# 13814   2022-12-31   11955     WM          WASTE MANAGEMENT INC DEL  -0.017205
# 14773   2022-12-31   12052     GD             GENERAL DYNAMICS CORP  -0.059080
# 15313   2022-12-31   12060     GE               GENERAL ELECTRIC CO   0.232877
# 17006   2022-12-31   12308   CHTR    CHARTER COMMUNICATIONS INC NEW   0.129823
# 17556   2022-12-31   12369     GM                 GENERAL MOTORS CO   0.165347
# 19015   2022-12-31   12490    IBM  INTERNATIONAL BUSINESS MACHS COR  -0.047222
# 20120   2022-12-31   12558    KMI                 KINDER MORGAN INC   0.024017
# 20623   2022-12-31   12622    HCA              H C A HEALTHCARE INC   0.059469
# 21341   2022-12-31   12872    MPC           MARATHON PETROLEUM CORP   0.100719
# 23546   2022-12-31   13356    PSX                       PHILLIPS 66  -0.040107
# 23679   2022-12-31   13407   META                META PLATFORMS INC   0.234409
# 23741   2022-12-31   13447    NOW                    SERVICENOW INC   0.168700
# 24085   2022-12-31   13641   FANG            DIAMONDBACK ENERGY INC   0.064785
# 24809   2022-12-31   13721   ABBV                        ABBVIE INC  -0.080104
# 25035   2022-12-31   13788    ZTS                        ZOETIS INC   0.128298
# 25900   2022-12-31   13856    PEP                       PEPSICO INC  -0.056860
# 26440   2022-12-31   13901     MO                  ALTRIA GROUP INC  -0.018158
# 27069   2022-12-31   13928    COP                    CONOCOPHILLIPS   0.029297
# 27829   2022-12-31   14008   AMGN                         AMGEN INC  -0.042489
# 30293   2022-12-31   14541    CVX                  CHEVRON CORP NEW  -0.033975
# 30956   2022-12-31   14593   AAPL                         APPLE INC   0.107021
# 31756   2022-12-31   14702   AMAT             APPLIED MATERIALS INC   0.141396
# 33983   2022-12-31   15069    MRO                 MARATHON OIL CORP   0.011277
# 35006   2022-12-31   15408    KHC                    KRAFT HEINZ CO  -0.007922
# 35732   2022-12-31   15488   PYPL               PAYPAL HOLDINGS INC   0.140701
# 36705   2022-12-31   15579    TXN             TEXAS INSTRUMENTS INC   0.076575
# 42281   2022-12-31   17005    CVS                 C V S HEALTH CORP  -0.050340
# 44160   2022-12-31   17478   SPGI                  S & P GLOBAL INC   0.115924
# 44846   2022-12-31   17743    WRB                  BERKLEY W R CORP  -0.030095
# 46252   2022-12-31   17830    RTX        RAYTHEON TECHNOLOGIES CORP  -0.014103
# 46283   2022-12-31   17942    KDP              KEURIG DR PEPPER INC  -0.008548
# 48629   2022-12-31   18163     PG               PROCTER & GAMBLE CO  -0.058044
# 48806   2022-12-31   18312   MRNA                       MODERNA INC  -0.023320
# 50303   2022-12-31   18411     SO                       SOUTHERN CO  -0.055734
# 51162   2022-12-31   18542    CAT                   CATERPILLAR INC   0.054648
# 51512   2022-12-31   18592   CTVA                       CORTEVA INC   0.092961
# 52592   2022-12-31   18729     CL              COLGATE PALMOLIVE CO  -0.051603
# 55122   2022-12-31   19350     DE                        DEERE & CO  -0.017307
# 55884   2022-12-31   19393    BMY           BRISTOL MYERS SQUIBB CO   0.014151
# 57382   2022-12-31   19561     BA                         BOEING CO   0.114669
# 61208   2022-12-31   20482    ABT               ABBOTT LABORATORIES   0.008068
# 64120   2022-12-31   21178    LMT              LOCKHEED MARTIN CORP  -0.051250
# 68277   2022-12-31   21792    CNP            CENTERPOINT ENERGY INC   0.000835
# 69057   2022-12-31   21936    PFE                        PFIZER INC  -0.133672
# 70605   2022-12-31   22103    EMR               EMERSON ELECTRIC CO  -0.064295
# 71145   2022-12-31   22111    JNJ                 JOHNSON & JOHNSON  -0.078394
# 73524   2022-12-31   22592    MMM                             3M CO  -0.043860
# 74484   2022-12-31   22752    MRK                MERCK & CO INC NEW  -0.035406
# 83917   2022-12-31   24010    ETR                  ENTERGY CORP NEW  -0.041011
# 84690   2022-12-31   24109    AEP    AMERICAN ELECTRIC POWER CO INC  -0.013927
# 85750   2022-12-31   24205    NEE                NEXTERA ENERGY INC  -0.110797
# 89550   2022-12-31   24766    NOC             NORTHROP GRUMMAN CORP  -0.182327
# 95115   2022-12-31   25582    LHX         L3HARRIS TECHNOLOGIES INC   0.028247
# 96475   2022-12-31   25785      F                 FORD MOTOR CO DEL   0.158151
# 99102   2022-12-31   26403    DIS                    DISNEY WALT CO   0.245234
# 106618  2022-12-31   27959    DUK              DUKE ENERGY CORP NEW  -0.008743
# 108224  2022-12-31   28222    APD      AIR PRODUCTS & CHEMICALS INC   0.036239
# 113626  2022-12-31   32986    ATO                 ATMOS ENERGY CORP   0.045309
# 115900  2022-12-31   34817    NUE                        NUCOR CORP   0.278800
# 116405  2022-12-31   34833    OXY         OCCIDENTAL PETROLEUM CORP   0.025076
# 117783  2022-12-31   35554    MTB                   M & T BANK CORP   0.071917
# 118556  2022-12-31   36468    SHW               SHERWIN WILLIAMS CO  -0.006618
# 121861  2022-12-31   38703    WFC              WELLS FARGO & CO NEW   0.131642
# 124854  2022-12-31   39642    BDX             BECTON DICKINSON & CO  -0.011679
# 128900  2022-12-31   40539    TJX           T J X COMPANIES INC NEW   0.024892
# 133555  2022-12-31   42585    SJM                    SMUCKER J M CO  -0.039219
# 136383  2022-12-31   43449    MCD                    MCDONALDS CORP   0.011185
# 139210  2022-12-31   44644    ADP     AUTOMATIC DATA PROCESSING INC  -0.058135
# 142141  2022-12-31   45751    MMC          MARSH & MCLENNAN COS INC   0.057051
# 145992  2022-12-31   46886   KLAC                        K L A CORP   0.037478
# 148510  2022-12-31   47896    JPM               JPMORGAN CHASE & CO   0.047656
# 150971  2022-12-31   48486   LRCX                     LAM RESH CORP   0.186364
# 151511  2022-12-31   48506    MCO                       MOODYS CORP   0.154888
# 152361  2022-12-31   48653    HUM                        HUMANA INC  -0.004457
# 152901  2022-12-31   48725    UNP                UNION PACIFIC CORP  -0.017408
# 154282  2022-12-31   49154    TGT                       TARGET CORP   0.151492
# 158097  2022-12-31   50876    LLY                    LILLY ELI & CO  -0.062788
# 165447  2022-12-31   53613     MU             MICRON TECHNOLOGY INC   0.202983
# 168470  2022-12-31   55976    WMT                       WALMART INC   0.011170
# 169705  2022-12-31   56274    CAG                CONAGRA BRANDS INC  -0.033991
# 170397  2022-12-31   56573    ITW           ILLINOIS TOOL WORKS INC   0.067948
# 172040  2022-12-31   57665    NKE                          NIKE INC   0.084698
# 172789  2022-12-31   57904    AFL                         AFLAC INC   0.018185
# 176111  2022-12-31   59176    AXP               AMERICAN EXPRESS CO   0.183979
# 177566  2022-12-31   59248    TAP          MOLSON COORS BEVERAGE CO   0.017075
# 178212  2022-12-31   59328   INTC                        INTEL CORP   0.065740
# 179098  2022-12-31   59408    BAC              BANK OF AMERICA CORP   0.067756
# 180262  2022-12-31   59459    TRV           TRAVELERS COMPANIES INC   0.015861
# 181518  2022-12-31   60097    MDT                     MEDTRONIC PLC   0.073314
# 182557  2022-12-31   60442    PNC  P N C FINANCIAL SERVICES GRP INC   0.053420
# 184304  2022-12-31   60871    ADI                ANALOG DEVICES INC   0.041858
# 185737  2022-12-31   61241    AMD        ADVANCED MICRO DEVICES INC   0.156759
# 186386  2022-12-31   61399    LOW               LOWES COMPANIES INC   0.046992
# 187295  2022-12-31   61735    AON                       AON PLC NEW   0.060137
# 188255  2022-12-31   62092    TMO      THERMO FISHER SCIENTIFIC INC   0.032164
# 188784  2022-12-31   62148    CSX                        C S X CORP  -0.005437
# 189471  2022-12-31   62308     GL                    GLOBE LIFE INC   0.000710
# 191715  2022-12-31   64186     CI                    CIGNA CORP NEW  -0.047775
# 192782  2022-12-31   64311    NSC             NORFOLK SOUTHERN CORP  -0.005975
# 193245  2022-12-31   64390    PGR               PROGRESSIVE CORP OH   0.048462
# 196824  2022-12-31   65875     VZ        VERIZON COMMUNICATIONS INC   0.068137
# 198237  2022-12-31   66093      T                       A T & T INC   0.118037
# 199036  2022-12-31   66157    USB                   U S BANCORP DEL   0.138440
# 199478  2022-12-31   66181     HD                    HOME DEPOT INC   0.022809
# 200393  2022-12-31   66800    AIG  AMERICAN INTERNATIONAL GROUP INC  -0.003816
# 202337  2022-12-31   69032     MS   MORGAN STANLEY DEAN WITTER & CO   0.150405
# 204737  2022-12-31   70519      C                     CITIGROUP INC   0.151043
# 206267  2022-12-31   71563    TFC             TRUIST FINANCIAL CORP   0.144304
# 207145  2022-12-31   73139    SYK                      STRYKER CORP   0.034620
# 207995  2022-12-31   75034    BKR                   BAKER HUGHES CO   0.071339
# 209275  2022-12-31   75186   SCHW           SCHWAB CHARLES CORP NEW  -0.073642
# 209604  2022-12-31   75241    PXD      PIONEER NATURAL RESOURCES CO   0.005082
# 210688  2022-12-31   75510   ADBE                         ADOBE INC   0.096967
# 212701  2022-12-31   75825    EOG                 EOG RESOURCES INC   0.023948
# 213672  2022-12-31   76076   CSCO                 CISCO SYSTEMS INC   0.026097
# 213871  2022-12-31   76082   CTRA                COTERRA ENERGY INC   0.015222
# 216536  2022-12-31   76614   REGN     REGENERON PHARMACEUTICALS INC   0.047755
# 217910  2022-12-31   76744   VRTX        VERTEX PHARMACEUTICALS INC   0.115345
# 219488  2022-12-31   77178   QCOM                      QUALCOMM INC   0.208161
# 219851  2022-12-31   77274   GILD               GILEAD SCIENCES INC  -0.025748
# 221677  2022-12-31   77605    BSX            BOSTON SCIENTIFIC CORP  -0.003932
# 222973  2022-12-31   77702   SBUX                    STARBUCKS CORP   0.096702
# 224870  2022-12-31   78975   INTU                        INTUIT INC   0.084445
# 225749  2022-12-31   79103   ORLY       O REILLY AUTOMOTIVE INC NEW  -0.064730
# 226850  2022-12-31   79323    ALL                     ALLSTATE CORP  -0.056081
# 227607  2022-12-31   79678   ATVI           ACTIVISION BLIZZARD INC  -0.003239
# 231890  2022-12-31   81061    MCK              MCKESSON H B O C INC   0.005990
# 233825  2022-12-31   81774    FCX              FREEPORT MCMORAN INC   0.174658
# 234259  2022-12-31   82303     RE              EVEREST RE GROUP LTD   0.052104
# 235331  2022-12-31   82642     EL              LAUDER ESTEE COS INC   0.113263
# 236481  2022-12-31   82775    HIG   HARTFORD FINANCIAL SVCS GRP INC   0.019974
# 241161  2022-12-31   84788   AMZN                    AMAZON COM INC   0.224238
# 242464  2022-12-31   85269    VLO            VALERO ENERGY CORP NEW   0.100315
# 246191  2022-12-31   86111    AMT           AMERICAN TOWER CORP NEW   0.050923
# 246509  2022-12-31   86136    SRE                     SEMPRA ENERGY   0.033966
# 247567  2022-12-31   86339    CCI                  CROWN CASTLE INC   0.088435
# 248144  2022-12-31   86580   NVDA                       NVIDIA CORP   0.333369
# 248571  2022-12-31   86783   BKNG              BOOKING HOLDINGS INC   0.204322
# 248979  2022-12-31   86868     GS           GOLDMAN SACHS GROUP INC   0.061821
# 250115  2022-12-31   87055   COST         COSTCO WHOLESALE CORP NEW   0.116193
# 250920  2022-12-31   87267    BLK                     BLACKROCK INC   0.067877
# 251881  2022-12-31   87447    UPS         UNITED PARCEL SERVICE INC   0.062020
# 252691  2022-12-31   87842    MET                       METLIFE INC   0.005482
# 252842  2022-12-31   88031   MNST         MONSTER BEVERAGE CORP NEW   0.021616
# 253318  2022-12-31   88352   ISRG            INTUITIVE SURGICAL INC  -0.077591
# 255697  2022-12-31   89006   MDLZ        MONDELEZ INTERNATIONAL INC  -0.021655
# 256823  2022-12-31   89179    ELV               ELEVANCE HEALTH INC  -0.028804
# 257093  2022-12-31   89195    PFG     PRINCIPAL FINANCIAL GROUP INC   0.099336
# 257591  2022-12-31   89269    CNC                  CENTENE CORP DEL  -0.073857
# 257989  2022-12-31   89393   NFLX                       NETFLIX INC   0.196513
# 258574  2022-12-31   89525  CMCSA                  COMCAST CORP NEW   0.129471
# 258886  2022-12-31   89617   EQIX                       EQUINIX INC   0.123364
# 259107  2022-12-31   89626    CME                   C M E GROUP INC   0.047047
# 260767  2022-12-31   90215    CRM                    SALESFORCE INC   0.263338
# 261440  2022-12-31   90386    MOS                     MOSAIC CO NEW   0.125746
# 263580  2022-12-31   90993    ICE  INTERCONTINENTALEXCHANGE GRP INC   0.044848
# 264619  2022-12-31   91233     MA                    MASTERCARD INC   0.063909
# 266363  2022-12-31   91937   TMUS                  T MOBILE U S INC   0.063000
# 267436  2022-12-31   92602     PM   PHILIP MORRIS INTERNATIONAL INC   0.026438
# 267617  2022-12-31   92611      V                          VISA INC   0.104557
# 268206  2022-12-31   92655    UNH            UNITEDHEALTH GROUP INC  -0.061952
# 268862  2022-12-31   93096     DG           DOLLAR GENERAL CORP NEW  -0.054871
# 269230  2022-12-31   93436   TSLA                         TESLA INC   0.402735
#
# --- SELL ---
#           datadate  permno ticker                        comnam  ret_fwd_1
# 12768   2022-12-31   11786   SIVB         S V B FINANCIAL GROUP   0.310657
# 32655   2022-12-31   14882    CZR  CAESARS ENTERTAINMENT INC DE   0.247942
# 34624   2022-12-31   15291   ETSY                      ETSY INC   0.145106
# 38316   2022-12-31   15850   MTCH           MATCH GROUP INC NEW   0.300911
# 63346   2022-12-31   21020    AAL   AMERICAN AIRLINES GROUP INC   0.265368
# 63649   2022-12-31   21124    OGN                  ORGANON & CO   0.075268
# 123864  2022-12-31   39490    APA                    A P A CORP  -0.048487
# 135843  2022-12-31   43350    SWK    STANLEY BLACK & DECKER INC   0.185398
# 136995  2022-12-31   43553    VFC                      V F CORP   0.117108
# 186441  2022-12-31   61516    BIO      BIO RAD LABORATORIES INC   0.108203
# 192275  2022-12-31   64282   BBWI         BATH & BODY WORKS INC   0.088337
# 218091  2022-12-31   76795   ZBRA       ZEBRA TECHNOLOGIES CORP   0.229603
# 233401  2022-12-31   81696   DISH             DISH NETWORK CORP   0.021429
# 242810  2022-12-31   85348    YUM                YUM BRANDS INC   0.015473
# 254860  2022-12-31   88860   ALGN          ALIGN TECHNOLOGY INC   0.275447
# 258240  2022-12-31   89508    KMX                    CARMAX INC   0.153504
# 260823  2022-12-31   90248    DPZ             DOMINOS PIZZA INC   0.015553
# 265768  2022-12-31   91611   FSLR               FIRST SOLAR INC   0.182160
# 269027  2022-12-31   93246   GNRC          GENERAC HOLDINGS INC   0.194593

# %%
start_date = '2023-12-31'

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()

conditions = [
    ( (analysis_df['bm'] > 1.5) & (analysis_df['mom12m'] > 1.5) ),
    
    ( (analysis_df['bm'] < -1.5) ) | ( (analysis_df['mom12m'] < -1.5) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2024.csv', index=False)
sells.to_csv('sells_2024.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker           comnam  ret_fwd_1
# 167037  2023-12-31   54148    PHM  PULTE GROUP INC   0.008282
#
# --- SELL ---
#           datadate  permno ticker                            comnam  ret_fwd_1
# 23007   2023-12-31   13210   EPAM                  EPAM SYSTEMS INC  -0.069374
# 23241   2023-12-31   13323   ENPH                ENPHASE ENERGY INC  -0.216672
# 33006   2023-12-31   14889    CFG      CITIZENS FINANCIAL GROUP INC  -0.005303
# 34636   2023-12-31   15291   ETSY                          ETSY INC  -0.183479
# 48818   2023-12-31   18312   MRNA                       MODERNA INC   0.011389
# 54156   2023-12-31   19166    FMC                        F M C CORP  -0.113344
# 54556   2023-12-31   19286   OTIS               OTIS WORLDWIDE CORP  -0.016212
# 56486   2023-12-31   19502    WBA      WALGREENS BOOTS ALLIANCE INC  -0.140280
# 57394   2023-12-31   19561     BA                         BOEING CO  -0.195063
# 63358   2023-12-31   21020    AAL       AMERICAN AIRLINES GROUP INC   0.030962
# 69069   2023-12-31   21936    PFE                        PFIZER INC  -0.049507
# 92202   2023-12-31   25081    CMA                      COMERICA INC  -0.062575
# 105297  2023-12-31   27828    HPQ                           H P INC  -0.050562
# 105837  2023-12-31   27887    BAX          BAXTER INTERNATIONAL INC  -0.003924
# 132861  2023-12-31   42200   RVTY                       REVVITY INC  -0.023546
# 137007  2023-12-31   43553    VFC                          V F CORP  -0.129168
# 174495  2023-12-31   58683    LUV             SOUTHWEST AIRLINES CO   0.030272
# 186398  2023-12-31   61399    LOW               LOWES COMPANIES INC  -0.043388
# 192287  2023-12-31   64282   BBWI             BATH & BODY WORKS INC  -0.016285
# 195019  2023-12-31   64995    KEY                       KEYCORP NEW   0.004328
# 200816  2023-12-31   67598   PEAK         HEALTHPEAK PROPERTIES INC  -0.070357
# 206279  2023-12-31   71563    TFC             TRUIST FINANCIAL CORP  -0.000908
# 209287  2023-12-31   75186   SCHW           SCHWAB CHARLES CORP NEW  -0.090165
# 215373  2023-12-31   76226   PARA                  PARAMOUNT GLOBAL  -0.018223
# 217786  2023-12-31   76712    AES                        A E S CORP  -0.129245
# 229491  2023-12-31   80191    ALB                    ALBEMARLE CORP  -0.210542
# 233484  2023-12-31   81736    RMD                        RESMED INC   0.100985
# 235343  2023-12-31   82642     EL              LAUDER ESTEE COS INC  -0.102204
# 239571  2023-12-31   84129   ZION          ZIONS BANCORPORATION N A  -0.049605
# 240747  2023-12-31   84767    ARE  ALEXANDRIA REAL EST EQUITIES INC  -0.051004
# 242822  2023-12-31   85348    YUM                    YUM BRANDS INC  -0.013655
# 249715  2023-12-31   86996   SBAC     S B A COMMUNICATIONS CORP NEW  -0.122284
# 253489  2023-12-31   88446   ILMN                      ILLUMINA INC   0.022376
# 260835  2023-12-31   90248    DPZ                 DOMINOS PIZZA INC   0.029237
# 264272  2023-12-31   91152    TDG               TRANSDIGM GROUP INC   0.075450
# 268874  2023-12-31   93096     DG           DOLLAR GENERAL CORP NEW  -0.028900
