# %%
# BUY RULE:
# if (bm > 1.5 AND mom12m > 1.0) OR mve > 1.5:
#     signal = BUY

# SELL RULE:
# if bm < -1.5 OR mom12m < -1.0:
#     signal = SELL

# %%
import pandas as pd
import numpy as np

green_cleaned = pd.read_csv('../green cleaned.csv', dtype={'ncusip': 'string'})
green_cleaned['ret_fwd_1'] = (green_cleaned.groupby('permno')['ret_excess'].shift(-1) )

# %%
variables = ['datadate', 'permno', 'ticker', 'comnam', 'bm', 'mom12m', 'mve', 'ret_fwd_1']

# %%
start_date = '2021-09-30'

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()
    
# BUY RULE:
# if (bm > 1.35 AND mom12m > 1.15) OR (bm > 1.1 AND mom12m > 0.85 AND mve > 0.25):
#     signal = BUY

# SELL RULE:
# if bm < -1.25 OR (mom12m < -1.1 AND mve < -0.2):
#     signal = SELL

conditions = [
    ( (analysis_df['bm'] > 1.35) & (analysis_df['mom12m'] > 1.15) ) | ( (analysis_df['bm'] > 1.1) & (analysis_df['mom12m'] > 0.85) & (analysis_df['mve'] > 0.25) ),
    
    ( (analysis_df['bm'] < -1.25) | ( (analysis_df['mom12m'] < -1.1) & (analysis_df['mve'] < -0.2) ) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2021.csv', index=False)
sells.to_csv('sells_2021.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                            comnam  ret_fwd_1
# 17541   2021-09-30   12369     GM                 GENERAL MOTORS CO   0.032631
# 24070   2021-09-30   13641   FANG            DIAMONDBACK ENERGY INC   0.132249
# 33968   2021-09-30   15069    MRO                 MARATHON OIL CORP   0.193855
# 92175   2021-09-30   25081    CMA                      COMERICA INC   0.057019
# 96460   2021-09-30   25785      F                 FORD MOTOR CO DEL   0.206215
# 115408  2021-09-30   34746   FITB               FIFTH THIRD BANCORP   0.025683
# 121846  2021-09-30   38703    WFC              WELLS FARGO & CO NEW   0.102349
# 126759  2021-09-30   40125    DXC               D X C TECHNOLOGY CO  -0.030943
# 153743  2021-09-30   49015    LNC             LINCOLN NATIONAL CORP   0.055564
# 165432  2021-09-30   53613     MU             MICRON TECHNOLOGY INC  -0.026486
# 182542  2021-09-30   60442    PNC  P N C FINANCIAL SERVICES GRP INC   0.085054
# 202322  2021-09-30   69032     MS   MORGAN STANLEY DEAN WITTER & CO   0.063406
# 221147  2021-09-30   77496    MHK             MOHAWK INDUSTRIES INC  -0.001071
# 231563  2021-09-30   81055    COF        CAPITAL ONE FINANCIAL CORP  -0.067543
# 248964  2021-09-30   86868     GS           GOLDMAN SACHS GROUP INC   0.093432
#
# --- SELL ---
#           datadate  permno ticker                           comnam  ret_fwd_1
# 18196   2021-09-30   12449    FLT        FLEETCOR TECHNOLOGIES INC  -0.053049
# 54129   2021-09-30   19166    FMC                       F M C CORP  -0.006007
# 54529   2021-09-30   19286   OTIS              OTIS WORLDWIDE CORP  -0.023943
# 57367   2021-09-30   19561     BA                        BOEING CO  -0.058698
# 63331   2021-09-30   21020    AAL      AMERICAN AIRLINES GROUP INC  -0.064328
# 77663   2021-09-30   23229    CMS                C M S ENERGY CORP   0.010380
# 78760   2021-09-30   23393    CHD              CHURCH & DWIGHT INC   0.058011
# 79637   2021-09-30   23536    WEC           W E C ENERGY GROUP INC   0.021088
# 93645   2021-09-30   25320    CPB                 CAMPBELL SOUP CO  -0.035637
# 101906  2021-09-30   26825      K                       KELLOGG CO  -0.040989
# 105270  2021-09-30   27828    HPQ                          H P INC   0.108553
# 113525  2021-09-30   32870    HRL                HORMEL FOODS CORP   0.038171
# 113611  2021-09-30   32986    ATO                ATMOS ENERGY CORP   0.044445
# 114686  2021-09-30   34032    MAS                       MASCO CORP   0.180018
# 123849  2021-09-30   39490    APA                       A P A CORP   0.225968
# 138192  2021-09-30   44329    TFX                     TELEFLEX INC  -0.052078
# 143500  2021-09-30   46578    CLX                        CLOROX CO  -0.008695
# 160878  2021-09-30   52090    MKC               MCCORMICK & CO INC  -0.005677
# 169690  2021-09-30   56274    CAG               CONAGRA BRANDS INC  -0.040080
# 183073  2021-09-30   60506   PCAR                       PACCAR INC   0.135580
# 213856  2021-09-30   76082    COG             CABOT OIL & GAS CORP   0.002757
# 228300  2021-09-30   79906   INCY                      INCYTE CORP  -0.026170
# 232451  2021-09-30   81481   DLTR                  DOLLAR TREE INC   0.125784
# 236103  2021-09-30   82686   CTXS               CITRIX SYSTEMS INC  -0.117724
# 240626  2021-09-30   84761   TTWO  TAKE TWO INTERACTIVE SOFTWR INC   0.174791
# 242795  2021-09-30   85348    YUM                   YUM BRANDS INC   0.021503
# 243009  2021-09-30   85459   CHRW        CH ROBINSON WORLDWIDE INC   0.114828
# 244259  2021-09-30   85753   VRSN                     VERISIGN INC   0.086142
# 245140  2021-09-30   85914    BBY             BEST BUY COMPANY INC   0.156371
# 249688  2021-09-30   86996   SBAC    S B A COMMUNICATIONS CORP NEW   0.044650
# 251246  2021-09-30   87299   AKAM          AKAMAI TECHNOLOGIES INC   0.008318
# 260808  2021-09-30   90248    DPZ                DOMINOS PIZZA INC   0.025180
# 261685  2021-09-30   90454   MKTX            MARKETAXESS HLDGS INC  -0.028572
# 264245  2021-09-30   91152    TDG              TRANSDIGM GROUP INC  -0.001201
# 265385  2021-09-30   91461     WU                 WESTERN UNION CO  -0.098912
# 267421  2021-09-30   92602     PM  PHILIP MORRIS INTERNATIONAL INC  -0.002637

# %%
start_date = '2021-12-31'

# BUY RULE:
# if bm > 1.5 AND mom12m > 1.5:
#     signal = BUY

# SELL RULE:
# if mve < -2.0:
#     signal = SELL

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()

conditions = [
    ( (analysis_df['bm'] > 1.0) & (analysis_df['mve'] > 1.0) & (analysis_df['mom12m'] > 1.0) ),
    
    ( (analysis_df['bm'] < -1.0) & (analysis_df['mom12m'] < -1.0) ) 
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2022.csv', index=False)
sells.to_csv('sells_2022.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                           comnam  ret_fwd_1
# 13274   2021-12-31   11850    XOM                 EXXON MOBIL CORP   0.241379
# 27057   2021-12-31   13928    COP                   CONOCOPHILLIPS   0.227764
# 121849  2021-12-31   38703    WFC             WELLS FARGO & CO NEW   0.121301
# 179086  2021-12-31   59408    BAC             BANK OF AMERICA CORP   0.037087
# 202325  2021-12-31   69032     MS  MORGAN STANLEY DEAN WITTER & CO   0.051752
# 248967  2021-12-31   86868     GS          GOLDMAN SACHS GROUP INC  -0.072853
#
# --- SELL ---
#           datadate  permno ticker            comnam  ret_fwd_1
# 57370   2021-12-31   19561     BA         BOEING CO  -0.005365
# 258756  2021-12-31   89533   WYNN  WYNN RESORTS LTD   0.004821

# %%
start_date = '2022-12-31'

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()

# BUY RULE:
# if bm > 1.5 AND mom12m > 1.0:
#     signal = BUY

# SELL RULE:
# if bm < -1.0 OR mom12m < -1.0:
#     signal = SELL

conditions = [
    ( (analysis_df['bm'] > 1.5) & (analysis_df['mom12m'] > 1.0) ),
    
    (analysis_df['bm'] < -1.0) | ( (analysis_df['mom12m'] < -1.0) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2023.csv', index=False)
sells.to_csv('sells_2023.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                         comnam  ret_fwd_1
# 20120   2022-12-31   12558    KMI              KINDER MORGAN INC   0.024017
# 33983   2022-12-31   15069    MRO              MARATHON OIL CORP   0.011277
# 51512   2022-12-31   18592   CTVA                    CORTEVA INC   0.092961
# 180262  2022-12-31   59459    TRV        TRAVELERS COMPANIES INC   0.015861
# 189471  2022-12-31   62308     GL                 GLOBE LIFE INC   0.000710
# 213871  2022-12-31   76082   CTRA             COTERRA ENERGY INC   0.015222
# 234259  2022-12-31   82303     RE           EVEREST RE GROUP LTD   0.052104
# 252691  2022-12-31   87842    MET                    METLIFE INC   0.005482
# 257093  2022-12-31   89195    PFG  PRINCIPAL FINANCIAL GROUP INC   0.099336
#
# --- SELL ---
#           datadate  permno ticker                           comnam  ret_fwd_1
# 813     2022-12-31   10104   ORCL                      ORACLE CORP   0.082627
# 1642    2022-12-31   10138   TROW           T ROWE PRICE GROUP INC   0.064444
# 10177   2022-12-31   11600   XRAY              DENTSPLY SIRONA INC   0.153221
# 12768   2022-12-31   11786   SIVB            S V B FINANCIAL GROUP   0.310657
# 17006   2022-12-31   12308   CHTR   CHARTER COMMUNICATIONS INC NEW   0.129823
# ...            ...     ...    ...                              ...        ...
# 267235  2022-12-31   92402   MSCI                      M S C I INC   0.139222
# 267436  2022-12-31   92602     PM  PHILIP MORRIS INTERNATIONAL INC   0.026438
# 268937  2022-12-31   93132   FTNT                     FORTINET INC   0.067067
# 269027  2022-12-31   93246   GNRC             GENERAC HOLDINGS INC   0.194593
# 269230  2022-12-31   93436   TSLA                        TESLA INC   0.402735
#
# [101 rows x 5 columns]

# %%
start_date = '2023-12-31'

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()

# BUY RULE:
# if (mom12m > 1.8 AND bm > 1.1) OR (mve > 1.2):
#     signal = BUY

# SELL RULE:
# if (mom12m < -1.5) OR (bm < -1.2 AND mve < -1):
#     signal = SELL

conditions = [
    ( (analysis_df['mom12m'] > 1.8) & (analysis_df['bm'] > 1.1) ) | ( (analysis_df['mve'] > 1.2) ),
    
    ( (analysis_df['mom12m'] < -1.5) ) | ( (analysis_df['bm'] < -1.2) & (analysis_df['mve'] < -1) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2024.csv', index=False)
sells.to_csv('sells_2024.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                            comnam  ret_fwd_1
# 825     2023-12-31   10104   ORCL                       ORACLE CORP   0.058565
# 1192    2023-12-31   10107   MSFT                    MICROSOFT CORP   0.052581
# 2194    2023-12-31   10145    HON       HONEYWELL INTERNATIONAL INC  -0.040225
# 8795    2023-12-31   11308     KO                      COCA COLA CO   0.004803
# 13298   2023-12-31   11850    XOM                  EXXON MOBIL CORP   0.023606
# 15325   2023-12-31   12060     GE               GENERAL ELECTRIC CO   0.032830
# 19027   2023-12-31   12490    IBM  INTERNATIONAL BUSINESS MACHS COR   0.118259
# 23691   2023-12-31   13407   META                META PLATFORMS INC   0.097515
# 23753   2023-12-31   13447    NOW                    SERVICENOW INC   0.078684
# 24821   2023-12-31   13721   ABBV                        ABBVIE INC   0.066152
# 25912   2023-12-31   13856    PEP                       PEPSICO INC  -0.012413
# 27081   2023-12-31   13928    COP                    CONOCOPHILLIPS  -0.040885
# 27841   2023-12-31   14008   AMGN                         AMGEN INC   0.086405
# 30305   2023-12-31   14541    CVX                  CHEVRON CORP NEW  -0.016298
# 30968   2023-12-31   14593   AAPL                         APPLE INC  -0.046927
# 31768   2023-12-31   14702   AMAT             APPLIED MATERIALS INC   0.009060
# 36717   2023-12-31   15579    TXN             TEXAS INSTRUMENTS INC  -0.057733
# 44172   2023-12-31   17478   SPGI                  S & P GLOBAL INC   0.013075
# 46264   2023-12-31   17830    RTX                        R T X CORP   0.078257
# 48641   2023-12-31   18163     PG               PROCTER & GAMBLE CO   0.074055
# 51174   2023-12-31   18542    CAT                   CATERPILLAR INC   0.015390
# 51458   2023-12-31   18576   UBER             UBER TECHNOLOGIES INC   0.055394
# 55134   2023-12-31   19350     DE                        DEERE & CO  -0.020430
# 57394   2023-12-31   19561     BA                         BOEING CO  -0.195063
# 61220   2023-12-31   20482    ABT               ABBOTT LABORATORIES   0.028279
# 64132   2023-12-31   21178    LMT              LOCKHEED MARTIN CORP  -0.057277
# 69069   2023-12-31   21936    PFE                        PFIZER INC  -0.049507
# 71157   2023-12-31   22111    JNJ                 JOHNSON & JOHNSON   0.009081
# 74496   2023-12-31   22752    MRK                MERCK & CO INC NEW   0.103170
# 85762   2023-12-31   24205    NEE                NEXTERA ENERGY INC  -0.039438
# 99114   2023-12-31   26403    DIS                    DISNEY WALT CO   0.059095
# 121873  2023-12-31   38703    WFC              WELLS FARGO & CO NEW   0.014804
# 136395  2023-12-31   43449    MCD                    MCDONALDS CORP  -0.017482
# 148522  2023-12-31   47896    JPM               JPMORGAN CHASE & CO   0.026517
# 152913  2023-12-31   48725    UNP                UNION PACIFIC CORP  -0.011581
# 158109  2023-12-31   50876    LLY                    LILLY ELI & CO   0.102845
# 167037  2023-12-31   54148    PHM                   PULTE GROUP INC   0.008282
# 168482  2023-12-31   55976    WMT                       WALMART INC   0.043508
# 172052  2023-12-31   57665    NKE                          NIKE INC  -0.069543
# 176123  2023-12-31   59176    AXP               AMERICAN EXPRESS CO   0.070031
# 178224  2023-12-31   59328   INTC                        INTEL CORP  -0.147387
# 179110  2023-12-31   59408    BAC              BANK OF AMERICA CORP   0.005398
# 181530  2023-12-31   60097    MDT                     MEDTRONIC PLC   0.057937
# 185749  2023-12-31   61241    AMD        ADVANCED MICRO DEVICES INC   0.132875
# 186398  2023-12-31   61399    LOW               LOWES COMPANIES INC  -0.043388
# 188267  2023-12-31   62092    TMO      THERMO FISHER SCIENTIFIC INC   0.010730
# 196836  2023-12-31   65875     VZ        VERIZON COMMUNICATIONS INC   0.136281
# 198249  2023-12-31   66093      T                       A T & T INC   0.066069
# 199490  2023-12-31   66181     HD                    HOME DEPOT INC   0.013797
# 202349  2023-12-31   69032     MS   MORGAN STANLEY DEAN WITTER & CO  -0.060035
# 207157  2023-12-31   73139    SYK                      STRYKER CORP   0.115583
# 209287  2023-12-31   75186   SCHW           SCHWAB CHARLES CORP NEW  -0.090165
# 210700  2023-12-31   75510   ADBE                         ADOBE INC   0.030801
# 213684  2023-12-31   76076   CSCO                 CISCO SYSTEMS INC  -0.003710
# 219500  2023-12-31   77178   QCOM                      QUALCOMM INC   0.022127
# 222985  2023-12-31   77702   SBUX                    STARBUCKS CORP  -0.035739
# 224882  2023-12-31   78975   INTU                        INTUIT INC   0.006819
# 241173  2023-12-31   84788   AMZN                    AMAZON COM INC   0.016756
# 248156  2023-12-31   86580   NVDA                       NVIDIA CORP   0.237718
# 248583  2023-12-31   86783   BKNG              BOOKING HOLDINGS INC  -0.015906
# 248991  2023-12-31   86868     GS           GOLDMAN SACHS GROUP INC  -0.009262
# 250127  2023-12-31   87055   COST         COSTCO WHOLESALE CORP NEW   0.048021
# 250932  2023-12-31   87267    BLK                     BLACKROCK INC  -0.050881
# 251893  2023-12-31   87447    UPS         UNITED PARCEL SERVICE INC  -0.102201
# 253330  2023-12-31   88352   ISRG            INTUITIVE SURGICAL INC   0.116417
# 256835  2023-12-31   89179    ELV               ELEVANCE HEALTH INC   0.041699
# 258001  2023-12-31   89393   NFLX                       NETFLIX INC   0.153922
# 258586  2023-12-31   89525  CMCSA                  COMCAST CORP NEW   0.063259
# 260779  2023-12-31   90215    CRM                    SALESFORCE INC   0.063515
# 264631  2023-12-31   91233     MA                    MASTERCARD INC   0.050117
# 266375  2023-12-31   91937   TMUS                  T MOBILE U S INC   0.000913
# 267448  2023-12-31   92602     PM   PHILIP MORRIS INTERNATIONAL INC  -0.039033
# 267629  2023-12-31   92611      V                          VISA INC   0.044887
# 268218  2023-12-31   92655    UNH            UNITEDHEALTH GROUP INC  -0.032679
# 269242  2023-12-31   93436   TSLA                         TESLA INC  -0.250957
#
# --- SELL ---
#           datadate  permno ticker                            comnam  ret_fwd_1
# 23007   2023-12-31   13210   EPAM                  EPAM SYSTEMS INC  -0.069374
# 23241   2023-12-31   13323   ENPH                ENPHASE ENERGY INC  -0.216672
# 33006   2023-12-31   14889    CFG      CITIZENS FINANCIAL GROUP INC  -0.005303
# 34636   2023-12-31   15291   ETSY                          ETSY INC  -0.183479
# 38328   2023-12-31   15850   MTCH               MATCH GROUP INC NEW   0.046807
# 48818   2023-12-31   18312   MRNA                       MODERNA INC   0.011389
# 54156   2023-12-31   19166    FMC                        F M C CORP  -0.113344
# 56486   2023-12-31   19502    WBA      WALGREENS BOOTS ALLIANCE INC  -0.140280
# 63358   2023-12-31   21020    AAL       AMERICAN AIRLINES GROUP INC   0.030962
# 92202   2023-12-31   25081    CMA                      COMERICA INC  -0.062575
# 105837  2023-12-31   27887    BAX          BAXTER INTERNATIONAL INC  -0.003924
# 114713  2023-12-31   34032    MAS                        MASCO CORP  -0.000072
# 132861  2023-12-31   42200   RVTY                       REVVITY INC  -0.023546
# 137007  2023-12-31   43553    VFC                          V F CORP  -0.129168
# 174495  2023-12-31   58683    LUV             SOUTHWEST AIRLINES CO   0.030272
# 192287  2023-12-31   64282   BBWI             BATH & BODY WORKS INC  -0.016285
# 195019  2023-12-31   64995    KEY                       KEYCORP NEW   0.004328
# 200816  2023-12-31   67598   PEAK         HEALTHPEAK PROPERTIES INC  -0.070357
# 206279  2023-12-31   71563    TFC             TRUIST FINANCIAL CORP  -0.000908
# 215373  2023-12-31   76226   PARA                  PARAMOUNT GLOBAL  -0.018223
# 217786  2023-12-31   76712    AES                        A E S CORP  -0.129245
# 229491  2023-12-31   80191    ALB                    ALBEMARLE CORP  -0.210542
# 233484  2023-12-31   81736    RMD                        RESMED INC   0.100985
# 235343  2023-12-31   82642     EL              LAUDER ESTEE COS INC  -0.102204
# 239571  2023-12-31   84129   ZION          ZIONS BANCORPORATION N A  -0.049605
# 240747  2023-12-31   84767    ARE  ALEXANDRIA REAL EST EQUITIES INC  -0.051004
# 253489  2023-12-31   88446   ILMN                      ILLUMINA INC   0.022376
# 258780  2023-12-31   89533   WYNN                  WYNN RESORTS LTD   0.031740
# 260835  2023-12-31   90248    DPZ                 DOMINOS PIZZA INC   0.029237
# 268874  2023-12-31   93096     DG           DOLLAR GENERAL CORP NEW  -0.028900
