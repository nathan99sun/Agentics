# %%
import pandas as pd
import numpy as np

green_cleaned = pd.read_csv('../green cleaned.csv', dtype={'ncusip': 'string'})
green_cleaned['ret_fwd_1'] = (green_cleaned.groupby('permno')['ret_excess'].shift(-1) )

# %%
variables = ['datadate', 'permno', 'ticker', 'comnam', 'bm', 'mom12m', 'mve', 'roe', 'agr', 'ret_fwd_1']

# %%
start_date = '2019-12-31'

# 3. Create the filtered DataFrame for your analysis
# analysis_df = green_cleaned[
#     (green_cleaned['datadate'] >= start_date) & 
#     (green_cleaned['datadate'] <= end_date)
# ][variables].copy()

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()

conditions = [
    # BUY: bm > 0.75 AND mom12m > 0.35 AND mve > -0.5
    ( (analysis_df['bm'] > 0.8) & (analysis_df['mom12m'] < -0.4) ),
    
    # SELL: bm < -0.5 AND mom12m < -0.75
    ( (analysis_df['bm'] < -0.8) & (analysis_df['mom12m'] > 0.4) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2020.csv', index=False)
sells.to_csv('sells_2020.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                        comnam  ret_fwd_1
# 4957    2019-12-31   10516    ADM     ARCHER DANIELS MIDLAND CO  -0.035604
# 13250   2019-12-31   11850    XOM              EXXON MOBIL CORP  -0.111074
# 15857   2019-12-31   12073   PBCT  PEOPLES UNITED FINANCIAL INC  -0.078371
# 21305   2019-12-31   12872    MPC       MARATHON PETROLEUM CORP  -0.096736
# 24049   2019-12-31   13641   FANG        DIAMONDBACK ENERGY INC  -0.200094
# 27176   2019-12-31   13936    PVH                    P V H CORP  -0.172294
# 30257   2019-12-31   14541    CVX              CHEVRON CORP NEW  -0.112245
# 32958   2019-12-31   14889    CFG  CITIZENS FINANCIAL GROUP INC  -0.073696
# 33947   2019-12-31   15069    MRO             MARATHON OIL CORP  -0.164039
# 34970   2019-12-31   15408    KHC                KRAFT HEINZ CO  -0.092492
# 41484   2019-12-31   16851     DD         DUPONT DE NEMOURS INC  -0.204104
# 42245   2019-12-31   17005    CVS             C V S HEALTH CORP  -0.081661
# 64624   2019-12-31   21186    WRK                   WESTROCK CO  -0.092421
# 67767   2019-12-31   21776    EXC                   EXELON CORP   0.042569
# 92154   2019-12-31   25081    CMA                  COMERICA INC  -0.148896
# 96439   2019-12-31   25785      F             FORD MOTOR CO DEL  -0.036784
# 113357  2019-12-31   32803    HFC            HOLLYFRONTIER CORP  -0.115479
# 116790  2019-12-31   35044     RF    REGIONS FINANCIAL CORP NEW  -0.093957
# 117747  2019-12-31   35554    MTB               M & T BANK CORP  -0.008546
# 121825  2019-12-31   38703    WFC          WELLS FARGO & CO NEW  -0.128809
# 123828  2019-12-31   39490    APA                   APACHE CORP   0.080763
# 126738  2019-12-31   40125    DXC           D X C TECHNOLOGY CO  -0.153202
# 134644  2019-12-31   42906   HBAN     HUNTINGTON BANCSHARES INC  -0.101433
# 153722  2019-12-31   49015    LNC         LINCOLN NATIONAL CORP  -0.071288
# 155329  2019-12-31   49656     BK  BANK OF NEW YORK MELLON CORP  -0.105413
# 177530  2019-12-31   59248    TAP       MOLSON COORS BREWING CO   0.029869
# 183409  2019-12-31   60599    CTL               CENTURYLINK INC   0.032765
# 185010  2019-12-31   60986    NWL             NEWELL BRANDS INC   0.014829
# 187759  2019-12-31   61815    NBL              NOBLE ENERGY INC  -0.205406
# 194971  2019-12-31   64995    KEY                   KEYCORP NEW  -0.076893
# 202550  2019-12-31   69550    MYL                     MYLAN N V   0.064372
# 205842  2019-12-31   71175    UNM                    UNUM GROUP  -0.076231
# 206820  2019-12-31   72726    STT             STATE STREET CORP  -0.045169
# 207959  2019-12-31   75034    BKR               BAKER HUGHES CO  -0.149174
# 219609  2019-12-31   77182   PRGO                PERRIGO CO PLC   0.102842
# 220899  2019-12-31   77462      M                     MACYS INC  -0.063065
# 233789  2019-12-31   81774    FCX          FREEPORT MCMORAN INC  -0.151452
# 239195  2019-12-31   84032    NOV    NATIONAL OILWELL VARCO INC  -0.178545
# 239523  2019-12-31   84129   ZION      ZIONS BANCORPORATION N A  -0.125144
# 250599  2019-12-31   87137    DVN         DEVON ENERGY CORP NEW  -0.164950
# 257449  2019-12-31   89258    PRU      PRUDENTIAL FINANCIAL INC  -0.029890
# 261404  2019-12-31   90386    MOS                 MOSAIC CO NEW  -0.084479
# 266945  2019-12-31   92239    CXO          CONCHO RESOURCES INC  -0.135935
#
# --- SELL ---
#           datadate  permno ticker                            comnam  ret_fwd_1
# 1144    2019-12-31   10107   MSFT                    MICROSOFT CORP   0.078155
# 5706    2019-12-31   10696   FISV                        FISERV INC   0.024472
# 9117    2019-12-31   11403   CDNS        CADENCE DESIGN SYSTEMS INC   0.038348
# 24999   2019-12-31   13788    ZTS                        ZOETIS INC   0.014265
# 29478   2019-12-31   14338    HLT     HILTON WORLDWIDE HOLDINGS INC  -0.029341
# 30920   2019-12-31   14593   AAPL                         APPLE INC   0.052710
# 36669   2019-12-31   15579    TXN             TEXAS INSTRUMENTS INC  -0.053837
# 40580   2019-12-31   16600    HSY                        HERSHEY CO   0.054422
# 44124   2019-12-31   17478   SPGI                  S & P GLOBAL INC   0.074437
# 64084   2019-12-31   21178    LMT              LOCKHEED MARTIN CORP   0.098192
# 75224   2019-12-31   22779    MSI            MOTOROLA SOLUTIONS INC   0.097124
# 93624   2019-12-31   25320    CPB                  CAMPBELL SOUP CO  -0.015060
# 114665  2019-12-31   34032    MAS                        MASCO CORP  -0.008281
# 118520  2019-12-31   36468    SHW               SHERWIN WILLIAMS CO  -0.046798
# 128864  2019-12-31   40539    TJX           T J X COMPANIES INC NEW  -0.034382
# 138647  2019-12-31   44601    AVY               AVERY DENNISON CORP   0.001911
# 145956  2019-12-31   46886   KLAC                        K L A CORP  -0.071065
# 151475  2019-12-31   48506    MCO                       MOODYS CORP   0.080331
# 160523  2019-12-31   52038    SYY                        SYSCO CORP  -0.035787
# 170361  2019-12-31   56573    ITW           ILLINOIS TOOL WORKS INC  -0.027187
# 172004  2019-12-31   57665    NKE                          NIKE INC  -0.050752
# 185701  2019-12-31   61241    AMD        ADVANCED MICRO DEVICES INC   0.023558
# 186350  2019-12-31   61399    LOW               LOWES COMPANIES INC  -0.026100
# 186890  2019-12-31   61621   PAYX                       PAYCHEX INC   0.014336
# 199442  2019-12-31   66181     HD                    HOME DEPOT INC   0.043210
# 216315  2019-12-31   76605    AZO                      AUTOZONE INC  -0.113236
# 217423  2019-12-31   76709   IDXX        I D E X X LABORATORIES INC   0.036536
# 219452  2019-12-31   77178   QCOM                      QUALCOMM INC  -0.034395
# 222937  2019-12-31   77702   SBUX                    STARBUCKS CORP  -0.036446
# 224834  2019-12-31   78975   INTU                        INTUIT INC   0.071162
# 225713  2019-12-31   79103   ORLY       O REILLY AUTOMOTIVE INC NEW  -0.074681
# 229941  2019-12-31   80320   CPRT                        COPART INC   0.114381
# 235295  2019-12-31   82642     EL              LAUDER ESTEE COS INC  -0.056398
# 244238  2019-12-31   85753   VRSN                      VERISIGN INC   0.078937
# 246155  2019-12-31   86111    AMT           AMERICAN TOWER CORP NEW   0.007054
# 248108  2019-12-31   86580   NVDA                       NVIDIA CORP   0.003502
# 249667  2019-12-31   86996   SBAC     S B A COMMUNICATIONS CORP NEW   0.034262
# 250079  2019-12-31   87055   COST         COSTCO WHOLESALE CORP NEW   0.038166
# 252134  2019-12-31   87657     EW         EDWARDS LIFESCIENCES CORP  -0.058868
# 263936  2019-12-31   91068    CMG        CHIPOTLE MEXICAN GRILL INC   0.034120
# 264224  2019-12-31   91152    TDG               TRANSDIGM GROUP INC   0.147414
# 264583  2019-12-31   91233     MA                    MASTERCARD INC   0.058146
# 265364  2019-12-31   91461     WU                  WESTERN UNION CO   0.003181
# 265618  2019-12-31   91556   ROST                   ROSS STORES INC  -0.037634
# 265982  2019-12-31   91849     BR  BROADRIDGE FINANCIAL SOLUTNS INC  -0.036835
# 267199  2019-12-31   92402   MSCI                       M S C I INC   0.105680
# 267581  2019-12-31   92611      V                          VISA INC   0.057614

# %%
start_date = '2020-12-31'

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()


conditions = [
    # BUY: bm > 0.75 AND mom12m > 0.75 AND mve > -0.5
    ( (analysis_df['bm'] < -0.75) & (analysis_df['mve'] >0.75) ) & ((analysis_df['roe'] >0.25) ),
    
    # SELL: bm < -1.0 OR mom12m < -1.0
    ( (analysis_df['bm'] > 1)  ) & ( (analysis_df['mom12m'] < -0.5) )  & ( (analysis_df['roe'] < 0) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2021.csv', index=False)
sells.to_csv('sells_2021.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                         comnam  ret_fwd_1
# 789     2020-12-31   10104   ORCL                    ORACLE CORP  -0.062243
# 1156    2020-12-31   10107   MSFT                 MICROSOFT CORP   0.042792
# 8759    2020-12-31   11308     KO                   COCA COLA CO  -0.122091
# 23717   2020-12-31   13447    NOW                 SERVICENOW INC  -0.013308
# 25011   2020-12-31   13788    ZTS                     ZOETIS INC  -0.066565
# 25876   2020-12-31   13856    PEP                    PEPSICO INC  -0.079196
# 27805   2020-12-31   14008   AMGN                      AMGEN INC   0.049961
# 30932   2020-12-31   14593   AAPL                      APPLE INC  -0.005602
# 36681   2020-12-31   15579    TXN          TEXAS INSTRUMENTS INC   0.015619
# 44136   2020-12-31   17478   SPGI               S & P GLOBAL INC  -0.035783
# 64096   2020-12-31   21178    LMT           LOCKHEED MARTIN CORP  -0.093514
# 73500   2020-12-31   22592    MMM                          3M CO   0.004877
# 74460   2020-12-31   22752    MRK             MERCK & CO INC NEW  -0.057924
# 118532  2020-12-31   36468    SHW            SHERWIN WILLIAMS CO  -0.058760
# 128876  2020-12-31   40539    TJX        T J X COMPANIES INC NEW  -0.062335
# 139186  2020-12-31   44644    ADP  AUTOMATIC DATA PROCESSING INC  -0.062983
# 158073  2020-12-31   50876    LLY                 LILLY ELI & CO   0.231658
# 170373  2020-12-31   56573    ITW        ILLINOIS TOOL WORKS INC  -0.047530
# 172016  2020-12-31   57665    NKE                       NIKE INC  -0.055801
# 185713  2020-12-31   61241    AMD     ADVANCED MICRO DEVICES INC  -0.066287
# 186362  2020-12-31   61399    LOW            LOWES COMPANIES INC   0.043137
# 210664  2020-12-31   75510   ADBE                      ADOBE INC  -0.082780
# 219464  2020-12-31   77178   QCOM                   QUALCOMM INC   0.025763
# 222949  2020-12-31   77702   SBUX                 STARBUCKS CORP  -0.095165
# 224846  2020-12-31   78975   INTU                     INTUIT INC  -0.047566
# 241137  2020-12-31   84788   AMZN                 AMAZON COM INC  -0.015676
# 246167  2020-12-31   86111    AMT        AMERICAN TOWER CORP NEW   0.012820
# 248120  2020-12-31   86580   NVDA                    NVIDIA CORP  -0.005098
# 248547  2020-12-31   86783   BKNG           BOOKING HOLDINGS INC  -0.127134
# 251857  2020-12-31   87447    UPS      UNITED PARCEL SERVICE INC  -0.079672
# 257965  2020-12-31   89393   NFLX                    NETFLIX INC  -0.015524
# 264595  2020-12-31   91233     MA                 MASTERCARD INC  -0.112752
# 267593  2020-12-31   92611      V                       VISA INC  -0.116591
#
# --- SELL ---
#           datadate  permno ticker                      comnam  ret_fwd_1
# 116381  2020-12-31   34833    OXY   OCCIDENTAL PETROLEUM CORP   0.158768
# 126750  2020-12-31   40125    DXC         D X C TECHNOLOGY CO   0.095046
# 183421  2020-12-31   60599   LUMN             CENTURYLINK INC   0.269644
# 199830  2020-12-31   66384    WDC        WESTERN DIGITAL CORP   0.018676
# 239207  2020-12-31   84032    NOV  NATIONAL OILWELL VARCO INC  -0.098425
# 266957  2020-12-31   92239    CXO        CONCHO RESOURCES INC        NaN

# %%
start_date = '2021-12-31'

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()


conditions = [
    # BUY: bm < -0.65 AND mom12m > 0.65 AND mve > -0.5
    ( (analysis_df['bm'] > 0.75) & (analysis_df['mve'] > 0) ) & ((analysis_df['roe'] > 0) ) & ((analysis_df['agr'] < 0) ),
    
    # SELL: bm > 0.65 AND mom12m < -0.65
    ( (analysis_df['roe'] <-0.5)  ) & ( (analysis_df['agr'] >1.0) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2022.csv', index=False)
sells.to_csv('sells_2022.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                      comnam  ret_fwd_1
# 17544   2021-12-31   12369     GM           GENERAL MOTORS CO  -0.100631
# 34994   2021-12-31   15408    KHC              KRAFT HEINZ CO  -0.002786
# 42269   2021-12-31   17005    CVS           C V S HEALTH CORP   0.037805
# 67791   2021-12-31   21776    EXC                 EXELON CORP   0.003290
# 106606  2021-12-31   27959    DUK        DUKE ENERGY CORP NEW   0.001525
# 121849  2021-12-31   38703    WFC        WELLS FARGO & CO NEW   0.121301
# 165435  2021-12-31   53613     MU       MICRON TECHNOLOGY INC  -0.116801
# 191703  2021-12-31   64186     CI              CIGNA CORP NEW   0.003615
# 199024  2021-12-31   66157    USB             U S BANCORP DEL   0.035962
# 206255  2021-12-31   71563    TFC       TRUIST FINANCIAL CORP   0.072929
# 231566  2021-12-31   81055    COF  CAPITAL ONE FINANCIAL CORP   0.011303
# 252679  2021-12-31   87842    MET                 METLIFE INC   0.073132
#
# --- SELL ---
#           datadate  permno ticker                        comnam  ret_fwd_1
# 24797   2021-12-31   13721   ABBV                    ABBVIE INC   0.021418
# 32643   2021-12-31   14882    CZR  CAESARS ENTERTAINMENT INC DE  -0.185930
# 48794   2021-12-31   18312   MRNA                   MODERNA INC  -0.333294
# 199466  2021-12-31   66181     HD                HOME DEPOT INC  -0.115732
# 216339  2021-12-31   76605    AZO                  AUTOZONE INC  -0.052490

# %%
start_date = '2022-12-31'

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()


conditions = [
    # BUY: if (bm > 0.8 AND mom12m > 0.6) OR (mve < 0.2 AND bm > 1.1)
    ( (analysis_df['bm'] > 1.0) & (analysis_df['mve'] < 0) ) & ((analysis_df['mom12m'] > 0.1) & (analysis_df['roe'] > -0.5) & (analysis_df['agr'] < 1.0) ),
    
    # SELL: if mom12m < -1.1 OR bm < -1.1:
    ( (analysis_df['bm'] < -0.6)  ) & ( (analysis_df['mom12m'] < -0.4) ) & ( (analysis_df['roe'] < 1.0) ) & ( (analysis_df['agr'] > -0.5) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2023.csv', index=False)
sells.to_csv('sells_2023.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                           comnam  ret_fwd_1
# 24085   2022-12-31   13641   FANG           DIAMONDBACK ENERGY INC   0.064785
# 33983   2022-12-31   15069    MRO                MARATHON OIL CORP   0.011277
# 37424   2022-12-31   15707    HPE    HEWLETT PACKARD ENTERPRISE CO   0.007152
# 72798   2022-12-31   22517    PPL                       P P L CORP   0.009505
# 101093  2022-12-31   26710      L                       LOEWS CORP   0.050503
# 107415  2022-12-31   27991    PNW       PINNACLE WEST CAPITAL CORP  -0.011719
# 113626  2022-12-31   32986    ATO                ATMOS ENERGY CORP   0.045309
# 116826  2022-12-31   35044     RF       REGIONS FINANCIAL CORP NEW   0.088337
# 117783  2022-12-31   35554    MTB                  M & T BANK CORP   0.071917
# 177566  2022-12-31   59248    TAP         MOLSON COORS BEVERAGE CO   0.017075
# 189471  2022-12-31   62308     GL                   GLOBE LIFE INC   0.000710
# 207995  2022-12-31   75034    BKR                  BAKER HUGHES CO   0.071339
# 227494  2022-12-31   79637    UHS    UNIVERSAL HEALTH SERVICES INC   0.048456
# 233307  2022-12-31   81677    WAB                      WABTEC CORP   0.036576
# 234259  2022-12-31   82303     RE             EVEREST RE GROUP LTD   0.052104
# 236481  2022-12-31   82775    HIG  HARTFORD FINANCIAL SVCS GRP INC   0.019974
# 257093  2022-12-31   89195    PFG    PRINCIPAL FINANCIAL GROUP INC   0.099336
# 261440  2022-12-31   90386    MOS                    MOSAIC CO NEW   0.125746
#
# --- SELL ---
#           datadate  permno ticker                            comnam  ret_fwd_1
# 1180    2022-12-31   10107   MSFT                    MICROSOFT CORP   0.029817
# 22995   2022-12-31   13210   EPAM                  EPAM SYSTEMS INC   0.011481
# 23741   2022-12-31   13447    NOW                    SERVICENOW INC   0.168700
# 25035   2022-12-31   13788    ZTS                        ZOETIS INC   0.128298
# 30353   2022-12-31   14579   PAYC               PAYCOM SOFTWARE INC   0.040424
# 31756   2022-12-31   14702   AMAT             APPLIED MATERIALS INC   0.141396
# 34585   2022-12-31   15272   SEDG        SOLAREDGE TECHNOLOGIES INC   0.123093
# 34624   2022-12-31   15291   ETSY                          ETSY INC   0.145106
# 35732   2022-12-31   15488   PYPL               PAYPAL HOLDINGS INC   0.140701
# 38316   2022-12-31   15850   MTCH               MATCH GROUP INC NEW   0.300911
# 63346   2022-12-31   21020    AAL       AMERICAN AIRLINES GROUP INC   0.265368
# 105285  2022-12-31   27828    HPQ                           H P INC   0.080981
# 118556  2022-12-31   36468    SHW               SHERWIN WILLIAMS CO  -0.006618
# 145992  2022-12-31   46886   KLAC                        K L A CORP   0.037478
# 150971  2022-12-31   48486   LRCX                     LAM RESH CORP   0.186364
# 154282  2022-12-31   49154    TGT                       TARGET CORP   0.151492
# 158997  2022-12-31   51369    TER                      TERADYNE INC   0.160782
# 161182  2022-12-31   52230    RHI     ROBERT HALF INTERNATIONAL INC   0.133707
# 162148  2022-12-31   52476    EFX                       EQUIFAX INC   0.139739
# 171386  2022-12-31   57568   BALL                         BALL CORP   0.135335
# 172040  2022-12-31   57665    NKE                          NIKE INC   0.084698
# 185737  2022-12-31   61241    AMD        ADVANCED MICRO DEVICES INC   0.156759
# 189668  2022-12-31   62498    WST  WEST PHARMACEUTICAL SERVICES INC   0.125839
# 205423  2022-12-31   70578    ECL                        ECOLAB INC   0.060185
# 210688  2022-12-31   75510   ADBE                         ADOBE INC   0.096967
# 212021  2022-12-31   75694   TECH                   BIO TECHNE CORP  -0.042351
# 214731  2022-12-31   76185    TYL            TYLER TECHNOLOGIES INC  -0.002383
# 218091  2022-12-31   76795   ZBRA           ZEBRA TECHNOLOGIES CORP   0.229603
# 218665  2022-12-31   77037   ODFL     OLD DOMINION FREIGHT LINE INC   0.170790
# 222973  2022-12-31   77702   SBUX                    STARBUCKS CORP   0.096702
# 224870  2022-12-31   78975   INTU                        INTUIT INC   0.084445
# 229977  2022-12-31   80320   CPRT                        COPART INC   0.090440
# 235331  2022-12-31   82642     EL              LAUDER ESTEE COS INC   0.113263
# 238142  2022-12-31   83621   ANSS                         ANSYS INC   0.099029
# 241161  2022-12-31   84788   AMZN                    AMAZON COM INC   0.224238
# 246191  2022-12-31   86111    AMT           AMERICAN TOWER CORP NEW   0.050923
# 248144  2022-12-31   86580   NVDA                       NVIDIA CORP   0.333369
# 249703  2022-12-31   86996   SBAC     S B A COMMUNICATIONS CORP NEW   0.057932
# 252170  2022-12-31   87657     EW         EDWARDS LIFESCIENCES CORP   0.024512
# 253318  2022-12-31   88352   ISRG            INTUITIVE SURGICAL INC  -0.077591
# 254860  2022-12-31   88860   ALGN              ALIGN TECHNOLOGY INC   0.275447
# 257989  2022-12-31   89393   NFLX                       NETFLIX INC   0.196513
# 260823  2022-12-31   90248    DPZ                 DOMINOS PIZZA INC   0.015553
# 261700  2022-12-31   90454   MKTX             MARKETAXESS HLDGS INC   0.301136
# 261747  2022-12-31   90455   MPWR            MONOLITHIC PWR SYS INC   0.202801
# 262920  2022-12-31   90808   EXPE                 EXPEDIA GROUP INC   0.301295
# 267235  2022-12-31   92402   MSCI                       M S C I INC   0.139222
# 268717  2022-12-31   93089   VRSK              VERISK ANALYTICS INC   0.026939
# 269027  2022-12-31   93246   GNRC              GENERAC HOLDINGS INC   0.194593
# 269230  2022-12-31   93436   TSLA                         TESLA INC   0.402735

# %%
start_date = '2023-12-31'

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()


conditions = [
    # BUY: if bm > 0.95 AND mve > 0.3 AND mom12m > -0.5:
    ( (analysis_df['bm'] >0.45) & (analysis_df['mve'] > -0.55) ) & ((analysis_df['mom12m'] > -0.25) ) & ((analysis_df['agr'] < 1.25) ) & ((analysis_df['roe'] > -0.75) ),
    
    # SELL: if (bm < -0.75 OR mom12m < -0.55 OR mve < -0.75) AND NOT (mom12m > 1.5):
    ( (analysis_df['bm'] < -0.5) & ( analysis_df['mom12m'] < -0.5 )  )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2024.csv', index=False)
sells.to_csv('sells_2024.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                            comnam  ret_fwd_1
# 5754    2023-12-31   10696     FI                        FISERV INC   0.063277
# 9705    2023-12-31   11404     ED           CONSOLIDATED EDISON INC  -0.005469
# 20132   2023-12-31   12558    KMI                 KINDER MORGAN INC  -0.029502
# 21353   2023-12-31   12872    MPC           MARATHON PETROLEUM CORP   0.111504
# 24097   2023-12-31   13641   FANG            DIAMONDBACK ENERGY INC  -0.013341
# 24678   2023-12-31   13688    PCG                      P G & E CORP  -0.069037
# 37436   2023-12-31   15707    HPE     HEWLETT PACKARD ENTERPRISE CO  -0.104229
# 38029   2023-12-31   15720    EIX              EDISON INTERNATIONAL  -0.060792
# 41532   2023-12-31   16851     DD             DUPONT DE NEMOURS INC  -0.201372
# 50450   2023-12-31   18428    DOW                           DOW INC  -0.027311
# 67815   2023-12-31   21776    EXC                       EXELON CORP  -0.035062
# 106630  2023-12-31   27959    DUK              DUKE ENERGY CORP NEW  -0.017169
# 115912  2023-12-31   34817    NUE                        NUCOR CORP   0.069363
# 125744  2023-12-31   39917     WY                   WEYERHAEUSER CO  -0.062221
# 148522  2023-12-31   47896    JPM               JPMORGAN CHASE & CO   0.026517
# 155377  2023-12-31   49656     BK      BANK OF NEW YORK MELLON CORP   0.068883
# 163074  2023-12-31   52708    LEN                       LENNAR CORP   0.004090
# 165459  2023-12-31   53613     MU             MICRON TECHNOLOGY INC   0.000104
# 172801  2023-12-31   57904    AFL                         AFLAC INC   0.017603
# 178224  2023-12-31   59328   INTC                        INTEL CORP  -0.147387
# 180274  2023-12-31   59459    TRV           TRAVELERS COMPANIES INC   0.104860
# 183965  2023-12-31   60628    FDX                        FEDEX CORP  -0.050872
# 184316  2023-12-31   60871    ADI                ANALOG DEVICES INC  -0.035925
# 196836  2023-12-31   65875     VZ        VERIZON COMMUNICATIONS INC   0.136281
# 200405  2023-12-31   66800    AIG  AMERICAN INTERNATIONAL GROUP INC   0.021278
# 208007  2023-12-31   75034    BKR                   BAKER HUGHES CO  -0.170879
# 222507  2023-12-31   77661    DHI                    D R HORTON INC  -0.064379
# 231590  2023-12-31   81055    COF        CAPITAL ONE FINANCIAL CORP   0.027332
# 233319  2023-12-31   81677    WAB                       WABTEC CORP   0.032101
# 234088  2023-12-31   82276   ACGL        ARCH CAPITAL GROUP LTD NEW   0.105169
# 236493  2023-12-31   82775    HIG   HARTFORD FINANCIAL SVCS GRP INC   0.077161
# 242476  2023-12-31   85269    VLO            VALERO ENERGY CORP NEW   0.071992
# 254977  2023-12-31   88873    GPN               GLOBAL PAYMENTS INC   0.044355
# 258586  2023-12-31   89525  CMCSA                  COMCAST CORP NEW   0.063259
#
# --- SELL ---
#           datadate  permno ticker                            comnam  ret_fwd_1
# 21825   2023-12-31   13035    XYL                         XYLEM INC  -0.021489
# 23007   2023-12-31   13210   EPAM                  EPAM SYSTEMS INC  -0.069374
# 23241   2023-12-31   13323   ENPH                ENPHASE ENERGY INC  -0.216672
# 26541   2023-12-31   13911    IQV                IQVIA HOLDINGS INC  -0.104752
# 30365   2023-12-31   14579   PAYC               PAYCOM SOFTWARE INC  -0.084421
# 33455   2023-12-31   14939   KEYS         KEYSIGHT TECHNOLOGIES INC  -0.041346
# 34636   2023-12-31   15291   ETSY                          ETSY INC  -0.183479
# 36717   2023-12-31   15579    TXN             TEXAS INSTRUMENTS INC  -0.057733
# 38328   2023-12-31   15850   MTCH               MATCH GROUP INC NEW   0.046807
# 40628   2023-12-31   16600    HSY                        HERSHEY CO   0.033382
# 55134   2023-12-31   19350     DE                        DEERE & CO  -0.020430
# 63358   2023-12-31   21020    AAL       AMERICAN AIRLINES GROUP INC   0.030962
# 101933  2023-12-31   26825      K                         KELLANOVA  -0.025269
# 143527  2023-12-31   46578    CLX                         CLOROX CO   0.022371
# 144426  2023-12-31   46674    GPC                  GENUINE PARTS CO   0.007791
# 154294  2023-12-31   49154    TGT                       TARGET CORP  -0.028152
# 160571  2023-12-31   52038    SYY                        SYSCO CORP   0.108797
# 192287  2023-12-31   64282   BBWI             BATH & BODY WORKS INC  -0.016285
# 209287  2023-12-31   75186   SCHW           SCHWAB CHARLES CORP NEW  -0.090165
# 211091  2023-12-31   75591    IEX                         IDEX CORP  -0.027592
# 212033  2023-12-31   75694   TECH                   BIO TECHNE CORP  -0.093347
# 217786  2023-12-31   76712    AES                        A E S CORP  -0.129245
# 233484  2023-12-31   81736    RMD                        RESMED INC   0.100985
# 235343  2023-12-31   82642     EL              LAUDER ESTEE COS INC  -0.102204
# 235829  2023-12-31   82651    WAT                       WATERS CORP  -0.039691
# 243036  2023-12-31   85459   CHRW         CH ROBINSON WORLDWIDE INC  -0.031324
# 243492  2023-12-31   85621    MTD  METTLER TOLEDO INTERNATIONAL INC  -0.017701
# 245167  2023-12-31   85914    BBY              BEST BUY COMPANY INC  -0.078665
# 246203  2023-12-31   86111    AMT           AMERICAN TOWER CORP NEW  -0.098410
# 247579  2023-12-31   86339    CCI                  CROWN CASTLE INC  -0.064948
# 249715  2023-12-31   86996   SBAC     S B A COMMUNICATIONS CORP NEW  -0.122284
# 251568  2023-12-31   87432      A          AGILENT TECHNOLOGIES INC  -0.068931
# 251893  2023-12-31   87447    UPS         UNITED PARCEL SERVICE INC  -0.102201
# 252182  2023-12-31   87657     EW         EDWARDS LIFESCIENCES CORP   0.024415
# 254010  2023-12-31   88664   JKHY            HENRY JACK & ASSOC INC   0.010109
# 261712  2023-12-31   90454   MKTX             MARKETAXESS HLDGS INC  -0.234647
# 262547  2023-12-31   90664   DXCM                        DEXCOM INC  -0.026781
# 267166  2023-12-31   92322   ULTA                   ULTA BEAUTY INC   0.019913
# 268874  2023-12-31   93096     DG           DOLLAR GENERAL CORP NEW  -0.028900
