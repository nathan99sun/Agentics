# %% [markdown]
# # UNION

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Lasso
import warnings
warnings.filterwarnings('ignore')


def naive_nodewise_regression(Y_star, lambda_grid=None):
    """
    Implements Naive Nodewise Regression (Section 5.1.2).
    Uses GIC (Generalized Information Criterion) as in the paper.
    
    Parameters:
    -----------
    Y_star : np.ndarray, shape (n, p)
        Demeaned returns matrix (time x assets)
    lambda_grid : list or None
        Grid of lambda values to try. If None, creates default grid.
    
    Returns:
    --------
    Theta_hat : np.ndarray, shape (p, p)
        Estimated precision matrix
    """
    n, p = Y_star.shape

    # Initialize matrices
    Theta_hat = np.zeros((p, p))
    tau_squared = np.zeros(p)
    
    # Create lambda grid if not provided
    if lambda_grid is None:
        lambda_grid = np.logspace(-3, 1, 50)
    
    # For each asset j
    for j in range(p):
        # Step 1: Get y_j (target) and Y_{-j} (predictors)
        y_j = Y_star[:, j]
        Y_minus_j = np.delete(Y_star, j, axis=1)
        
        # Step 2-3: Estimate gamma_j using Lasso with GIC
        best_gic = np.inf
        best_lambda = lambda_grid[0]
        best_gamma = None
        best_ssr = None
        
        for lam in lambda_grid:
            lasso = Lasso(alpha=2*lam, fit_intercept=False, max_iter=10000)
            lasso.fit(Y_minus_j, y_j)
            gamma_j = lasso.coef_
            
            # Compute SSR and number of non-zero coefficients
            residuals = y_j - Y_minus_j @ gamma_j
            ssr = np.sum(residuals ** 2)
            sigma_sq_lambda = ssr / n
            q_lambda = np.sum(np.abs(gamma_j) > 1e-8)
            
            # Compute GIC
            if sigma_sq_lambda > 1e-10:
                gic = np.log(sigma_sq_lambda) + q_lambda * (np.log(p) / n) * np.log(np.log(n))
            else:
                gic = np.inf
            
            if gic < best_gic:
                best_gic = gic
                best_lambda = lam
                best_gamma = gamma_j.copy()
                best_ssr = ssr
        
        gamma_j_star = best_gamma
        tau_squared[j] = best_ssr / n + best_lambda * np.sum(np.abs(gamma_j_star))

        # Step 5: Form the j-th row of Theta_hat
        Theta_hat[j, j] = 1 / tau_squared[j]
        off_diag = -gamma_j_star / tau_squared[j]
        Theta_hat[j, :j] = off_diag[:j]
        Theta_hat[j, j+1:] = off_diag[j:]
    
    # Step 6: Symmetrize
    Theta_hat_sym = (Theta_hat + Theta_hat.T) / 2
    
    return Theta_hat_sym


def gmv_weights(Theta_hat):
    """
    Compute Global Minimum Variance (GMV) portfolio weights (Section 6.1).
    
    Parameters:
    -----------
    Theta_hat : np.ndarray, shape (p, p)
        Precision matrix
    
    Returns:
    --------
    w_star : np.ndarray, shape (p,)
        Portfolio weights
    """
    p = Theta_hat.shape[0]
    ones_p = np.ones(p)
    
    # w* = (Θ 1_p) / (1_p' Θ 1_p)
    numerator = Theta_hat @ ones_p
    denominator = ones_p @ Theta_hat @ ones_p
    
    if np.abs(denominator) < 1e-10:
        # Fallback to equal weights if precision matrix is near-singular
        return ones_p / p
    
    w_star = numerator / denominator
    
    return w_star


def load_yearly_signals(year, buys_path_template='buys_{}.csv', sells_path_template='sells_{}.csv'):
    """
    Load buy and sell signals for a specific year.
    
    Parameters:
    -----------
    year : int
        Year to load signals for
    buys_path_template : str
        Template for buys file path (use {} for year placeholder)
    sells_path_template : str
        Template for sells file path (use {} for year placeholder)
    
    Returns:
    --------
    permno_set : set
        Set of permnos in the buy and sell signals for this year
    """
    try:
        buys = pd.read_csv(buys_path_template.format(year), index_col=1)
        sells = pd.read_csv(sells_path_template.format(year), index_col=1)
        
        buys.index.name = 'permno'
        sells.index.name = 'permno'
        
        buys_index = buys.index.astype(int)
        sells_index = sells.index.astype(int)
        
        return set(buys_index.union(sells_index))
    except FileNotFoundError as e:
        print(f"  ⚠ Warning: Could not load signals for year {year}: {e}")
        return set()


def load_analyst_recommendations(rec_changes_path):
    """
    Load significant recommendation changes from CSV file.
    
    Parameters:
    -----------
    rec_changes_path : str
        Path to significant_recommendation_changes.csv file
    
    Returns:
    --------
    rec_changes_df : pd.DataFrame
        DataFrame with columns: permno, date, ticker, mean_recommendation, 
        recommendation_change, num_recommendations
    """
    try:
        rec_changes_df = pd.read_csv(rec_changes_path)
        rec_changes_df['date'] = pd.to_datetime(rec_changes_df['date'])
        rec_changes_df['permno'] = rec_changes_df['permno'].astype(int)
        return rec_changes_df
    except FileNotFoundError as e:
        print(f"  ⚠ Warning: Could not load recommendation changes: {e}")
        return pd.DataFrame(columns=['permno', 'date', 'ticker', 'mean_recommendation', 
                                    'recommendation_change', 'num_recommendations'])


def get_analyst_permnos_for_date(rec_changes_df, date):
    """
    Get sets of permnos with upgrades (negative changes) and downgrades (positive changes).
    
    Note: Negative change = upgrade (moving toward Strong Buy)
          Positive change = downgrade (moving toward Sell)
    
    Parameters:
    -----------
    rec_changes_df : pd.DataFrame
        Recommendation changes dataframe
    date : pd.Timestamp
        Date to get changes for
    
    Returns:
    --------
    upgrade_permnos : set
        Set of permnos with negative recommendation changes (upgrades) - BUY these
    downgrade_permnos : set
        Set of permnos with positive recommendation changes (downgrades) - SELL these
    """
    date_changes = rec_changes_df[rec_changes_df['date'] == date]
    
    # Upgrades: negative changes (recommendations getting better)
    upgrades = date_changes[date_changes['recommendation_change'] < 0]
    upgrade_permnos = set(upgrades['permno'].values)
    
    # Downgrades: positive changes (recommendations getting worse)
    downgrades = date_changes[date_changes['recommendation_change'] > 0]
    downgrade_permnos = set(downgrades['permno'].values)
    
    return upgrade_permnos | downgrade_permnos


def backtest_nodewise_gmv_yearly(df, 
                                  test_start_date='2020-01-31', 
                                  test_end_date='2024-11-30',
                                  lookback_window=180,
                                  transaction_cost=0.001,
                                  buys_path_template='buys_{}.csv',
                                  sells_path_template='sells_{}.csv',
                                  analyst_rec_path=None,
                                  verbose=True):
    """
    Backtest Nodewise + GMV strategy with year-specific buy/sell signals 
    and analyst recommendations.
    
    Parameters:
    -----------
    df : pd.DataFrame
        DataFrame with columns: permno, datadate, ret_fwd_1
    test_start_date : str
        First date for out-of-sample returns (format: 'YYYY-MM-DD')
    test_end_date : str
        Last date for out-of-sample returns (format: 'YYYY-MM-DD')
    lookback_window : int
        Number of months in rolling training window (default: 180)
    transaction_cost : float
        Proportional transaction cost (default: 0.001 = 10 bps)
    buys_path_template : str
        Template for buys file path (use {} for year placeholder)
    sells_path_template : str
        Template for sells file path (use {} for year placeholder)
    analyst_rec_path : str or None
        Path to analyst recommendations CSV file. If None, only uses buy/sell signals.
    verbose : bool
        If True, prints detailed log at each time step.
    
    Returns:
    --------
    results_df : pd.DataFrame
        DataFrame with columns: date, portfolio_return, cumulative_return
    metrics : dict
        Overall performance metrics
    """
    # --- 1. Setup ---
    df = df.copy()
    if 'datadate' not in df.columns or 'permno' not in df.columns:
        raise ValueError("DataFrame must have 'datadate' and 'permno' columns")
    df['datadate'] = pd.to_datetime(df['datadate'])
    
    # Load analyst recommendations if provided
    analyst_df = None
    if analyst_rec_path is not None:
        analyst_df = load_analyst_recommendations(analyst_rec_path)
        if verbose and len(analyst_df) > 0:
            print(f"Loaded analyst recommendations: {len(analyst_df)} records")
    
    # Get unique dates
    all_dates = sorted(df['datadate'].unique())
    
    # Convert test dates to datetime
    test_start_dt = pd.to_datetime(test_start_date)
    test_end_dt = pd.to_datetime(test_end_date)
    
    # Find date indices
    try:
        test_start_idx = all_dates.index(test_start_dt)
        test_end_idx = all_dates.index(test_end_dt)
    except ValueError as e:
        raise ValueError(f"Date not found in DataFrame: {e}")
    
    if test_start_idx < lookback_window:
        raise ValueError(f"Not enough data for lookback. Test start date {test_start_date} "
                         f"requires data back to {all_dates[test_start_idx - lookback_window]}, "
                         f"but only {test_start_idx} periods are available.")
    
    # Storage for results
    portfolio_returns = []
    portfolio_dates = []
    portfolio_weights_list = []
    portfolio_turnover_list = []
    portfolio_gross_returns = []
    
    # Track weights by permno
    prev_weights_dict = {}
    prev_oos_returns_dict = {}
    prev_gross_return = 0.0
    
    # Cache for yearly signals
    yearly_signals_cache = {}
    
    # --- 2. Rolling Window Backtest ---
    if verbose:
        print("="*60)
        print("STARTING BACKTEST WITH YEARLY SIGNALS + ANALYST RECS")
        print("="*60)
        
    for t in range(test_start_idx, test_end_idx + 1):
        current_date = all_dates[t]
        current_year = current_date.year
        
        # Load signals for current year if not cached
        if current_year not in yearly_signals_cache:
            yearly_signals_cache[current_year] = load_yearly_signals(
                current_year, buys_path_template, sells_path_template
            )
        
        buysell_permnos = yearly_signals_cache[current_year]
        
        # Get analyst recommendations for current date
        analyst_permnos = set()
        if analyst_df is not None and len(analyst_df) > 0:
            analyst_permnos = get_analyst_permnos_for_date(analyst_df, current_date)
        
        # UNION of buy/sell signals and analyst recommendations
        allowed_permnos = buysell_permnos.union(analyst_permnos)
        
        if len(allowed_permnos) == 0:
            if verbose:
                print(f"\n[{t - test_start_idx + 1}/{test_end_idx - test_start_idx + 1}] "
                      f"Date: {current_date.strftime('%Y-%m-%d')}")
                print(f"  ⚠ No signals or analyst recs for {current_date.strftime('%Y-%m-%d')}, skipping period")
            continue
        
        # Define the lookback window
        window_start_date = all_dates[t - lookback_window]
        window_end_date = all_dates[t - 1]
        
        # Get training data for this window, filtered by allowed permnos
        train_data = df[(df['datadate'] >= window_start_date) & 
                        (df['datadate'] <= window_end_date) &
                        (df['permno'].isin(allowed_permnos))]
        
        # Pivot to get returns matrix (time x assets)
        returns_pivot = train_data.pivot(index='datadate', columns='permno', values='ret_fwd_1')
        
        # Reindex to ensure all dates are present
        window_dates = all_dates[t - lookback_window : t]
        returns_pivot = returns_pivot.reindex(index=window_dates)
        
        # Filter assets with any NaNs in this window
        nan_assets = returns_pivot.columns[returns_pivot.isna().any()]
        filtered_pivot = returns_pivot.drop(columns=nan_assets)
        
        current_assets = filtered_pivot.columns.tolist()
        Y = filtered_pivot.values
        n_train, p_current = Y.shape

        if verbose:
            print(f"\n[{t - test_start_idx + 1}/{test_end_idx - test_start_idx + 1}] "
                  f"Date: {current_date.strftime('%Y-%m-%d')} | Year: {current_year}")
            print(f"  Window: {window_start_date.strftime('%Y-%m-%d')} to "
                  f"{window_end_date.strftime('%Y-%m-%d')}")
            print(f"  Buy/Sell: {len(buysell_permnos)} | Analyst: {len(analyst_permnos)} | "
                  f"Union: {len(allowed_permnos)} | Assets w/ data: {p_current}")

        # Check for valid data
        if n_train < lookback_window or p_current < 2:
            if verbose:
                print(f"  ⚠ Insufficient data (n={n_train}, p={p_current}), using prev weights")
            # Filter previous weights to only allowed permnos
            new_weights_dict = {k: v for k, v in prev_weights_dict.items() if k in allowed_permnos}
        else:
            try:
                # Demean the returns
                Y_bar = Y.mean(axis=0)
                Y_star = Y - Y_bar
                
                if verbose:
                    print(f"  Running Nodewise Regression...")
                Theta_hat = naive_nodewise_regression(Y_star)
                
                if verbose:
                    print(f"  Computing GMV weights...")
                w_star = gmv_weights(Theta_hat)
                
                # Create weights dictionary
                new_weights_dict = {asset: w_star[i] for i, asset in enumerate(current_assets)}
                
            except Exception as e:
                if verbose:
                    print(f"  ✗ Error: {e}")
                    print(f"  Using previous weights")
                # Filter previous weights to only allowed permnos
                new_weights_dict = {k: v for k, v in prev_weights_dict.items() if k in allowed_permnos}

        # Normalize weights to sum to 1
        weight_sum = sum(new_weights_dict.values())
        if weight_sum > 1e-10:
            new_weights_dict = {k: v/weight_sum for k, v in new_weights_dict.items()}
        else:
            if verbose:
                print("  ⚠ Zero weight sum, using previous weights")
            new_weights_dict = {k: v for k, v in prev_weights_dict.items() if k in allowed_permnos}
            weight_sum = sum(new_weights_dict.values())
            if weight_sum > 1e-10:
                new_weights_dict = {k: v/weight_sum for k, v in new_weights_dict.items()}
        
        # --- 3. OOS Returns & Transaction Costs ---
        
        # Get out-of-sample returns for current month (only for allowed permnos)
        oos_data = df[(df['datadate'] == current_date) & (df['permno'].isin(allowed_permnos))]
        oos_returns_series = oos_data.set_index('permno')['ret_fwd_1']
        
        # Filter out NaN returns
        oos_returns_series = oos_returns_series.dropna()
        oos_returns_dict = oos_returns_series.to_dict()
        
        # Find common assets between weights and returns
        common_assets = set(new_weights_dict.keys()) & set(oos_returns_dict.keys())
        
        if len(common_assets) == 0:
            if verbose:
                print("  ⚠ No common assets with valid returns, skipping period")
            continue
        
        # Filter to common assets and renormalize
        common_weights = {a: new_weights_dict[a] for a in common_assets}
        common_weight_sum = sum(common_weights.values())
        if common_weight_sum > 1e-10:
            common_weights = {k: v/common_weight_sum for k, v in common_weights.items()}
        else:
            if verbose:
                print("  ⚠ Zero weight sum after filtering, skipping period")
            continue
        
        # Compute gross portfolio return
        gross_return = sum(common_weights[a] * oos_returns_dict[a] for a in common_assets)
        
        # Sanity check
        if np.isnan(gross_return) or np.isinf(gross_return):
            if verbose:
                print(f"  ⚠ Invalid gross return: {gross_return}, skipping period")
            continue
        
        # Calculate transaction costs
        if len(prev_weights_dict) > 0:
            all_traded_assets = set(common_weights.keys()) | set(prev_weights_dict.keys())
            
            # Adjust previous weights
            adjusted_prev = {}
            for asset in all_traded_assets:
                prev_w = prev_weights_dict.get(asset, 0.0)
                
                if asset in prev_oos_returns_dict:
                    prev_r = prev_oos_returns_dict[asset]
                    if prev_gross_return > -0.99:
                        adjusted_prev[asset] = prev_w * (1 + prev_r) / (1 + prev_gross_return)
                    else:
                        adjusted_prev[asset] = 0.0
                else:
                    adjusted_prev[asset] = 0.0
            
            # Renormalize adjusted weights
            adj_sum = sum(adjusted_prev.get(a, 0.0) for a in common_weights.keys())
            if adj_sum > 1e-10:
                adjusted_prev_normalized = {k: adjusted_prev.get(k, 0.0)/adj_sum 
                                           for k in common_weights.keys()}
            else:
                adjusted_prev_normalized = {k: 0.0 for k in common_weights.keys()}
            
            # Turnover
            turnover = sum(abs(common_weights.get(a, 0.0) - adjusted_prev_normalized.get(a, 0.0)) 
                          for a in all_traded_assets)
            
            # Transaction cost
            tc = transaction_cost * (1 + gross_return) * turnover
        else:
            # First period
            turnover = sum(abs(w) for w in common_weights.values())
            tc = transaction_cost * turnover
        
        # Net return
        net_return = gross_return - tc
        
        # Store results
        portfolio_returns.append(net_return)
        portfolio_dates.append(current_date)
        portfolio_weights_list.append(common_weights.copy())
        portfolio_turnover_list.append(turnover)
        portfolio_gross_returns.append(gross_return)
        
        # Update previous values for next iteration
        prev_weights_dict = common_weights.copy()
        prev_oos_returns_dict = {a: oos_returns_dict[a] for a in common_assets}
        prev_gross_return = gross_return
        
        if verbose:
            print(f"  Gross: {gross_return:>8.5f} | Turnover: {turnover:>6.4f} | "
                  f"TC: {tc:>8.6f} | Net: {net_return:>8.5f}")

    if verbose:
        print("\n" + "="*60)
        print("BACKTEST COMPLETE")
        print("="*60)
    
    # --- 4. Compile Results ---
    results_df = pd.DataFrame({
        'date': portfolio_dates,
        'portfolio_return': portfolio_returns,
        'portfolio_gross_return': portfolio_gross_returns,
        'portfolio_weights': portfolio_weights_list,
        'portfolio_turnover': portfolio_turnover_list
    })
    results_df['cumulative_return'] = (1 + results_df['portfolio_return']).cumprod() - 1
    
    # Compute overall metrics
    if len(portfolio_returns) > 0:
        mean_return = np.mean(portfolio_returns)
        variance = np.var(portfolio_returns, ddof=1)
        sharpe_ratio = mean_return / np.sqrt(variance) if variance > 0 else 0
        
        # Annualized metrics (monthly data)
        annual_return = mean_return * 12
        annual_volatility = np.sqrt(variance * 12)
        annual_sharpe = annual_return / annual_volatility if annual_volatility > 0 else 0
        
        metrics = {
            'mean_return': mean_return,
            'variance': variance,
            'sharpe_ratio': sharpe_ratio,
            'annual_return': annual_return,
            'annual_volatility': annual_volatility,
            'annual_sharpe_ratio': annual_sharpe,
            'total_return': results_df['cumulative_return'].iloc[-1],
            'avg_turnover': np.mean(portfolio_turnover_list),
            'n_periods': len(portfolio_returns)
        }
    else:
        metrics = {
            'mean_return': 0,
            'variance': 0,
            'sharpe_ratio': 0,
            'annual_return': 0,
            'annual_volatility': 0,
            'annual_sharpe_ratio': 0,
            'total_return': 0,
            'avg_turnover': 0,
            'n_periods': 0
        }
    
    return results_df, metrics

# %%
df = pd.read_csv('../green cleaned.csv', dtype={'ncusip': 'string'})
df['ret_fwd_1'] = df.groupby('permno')['ret_excess'].shift(-1)

results_df, metrics = backtest_nodewise_gmv_yearly(
    df=df,
    test_start_date='2020-01-31',
    test_end_date='2024-11-30',
    lookback_window=180,
    transaction_cost=0.001,
    buys_path_template='../AI Portfolio Selection/buys_{}.csv',
    sells_path_template='../AI Portfolio Selection/sells_{}.csv',
    analyst_rec_path='monthly_mean_recommendations.csv',  # <-- Add this
    verbose=True
)

print(f"\nSharpe Ratio: {metrics['sharpe_ratio']:.4f}")
print(f"Annualized Sharpe Ratio: {metrics['annual_sharpe_ratio']:.4f}")
print(f"Total Return: {metrics['total_return']:.4f}")
print(f"Average Turnover: {metrics['avg_turnover']:.4f}")
# Out:
# Loaded analyst recommendations: 17055 records
# ============================================================
# STARTING BACKTEST WITH YEARLY SIGNALS + ANALYST RECS
# ============================================================
#
# [1/59] Date: 2020-01-31 | Year: 2020
#   Window: 2005-01-31 to 2019-12-31
#   Buy/Sell: 40 | Analyst: 120 | Union: 156 | Assets w/ data: 80
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.09724 | Turnover: 1.1128 | TC: 0.001113 | Net: -0.09835
#
# [2/59] Date: 2020-02-29 | Year: 2020
#   Window: 2005-02-28 to 2020-01-31
#   Buy/Sell: 40 | Analyst: 89 | Union: 125 | Assets w/ data: 68
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.13675 | Turnover: 0.9365 | TC: 0.000808 | Net: -0.13756
#
# [3/59] Date: 2020-03-31 | Year: 2020
#   Window: 2005-03-31 to 2020-02-29
#   Buy/Sell: 40 | Analyst: 163 | Union: 190 | Assets w/ data: 99
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.11130 | Turnover: 1.1856 | TC: 0.001318 | Net:  0.10998
#
# [4/59] Date: 2020-04-30 | Year: 2020
#   Window: 2005-04-30 to 2020-03-31
#   Buy/Sell: 40 | Analyst: 152 | Union: 181 | Assets w/ data: 88
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03003 | Turnover: 1.0345 | TC: 0.001066 | Net:  0.02897
#
# [5/59] Date: 2020-05-31 | Year: 2020
#   Window: 2005-05-31 to 2020-04-30
#   Buy/Sell: 40 | Analyst: 118 | Union: 152 | Assets w/ data: 73
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.00412 | Turnover: 1.3355 | TC: 0.001330 | Net: -0.00545
#
# [6/59] Date: 2020-06-30 | Year: 2020
#   Window: 2005-06-30 to 2020-05-31
#   Buy/Sell: 40 | Analyst: 136 | Union: 163 | Assets w/ data: 85
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03262 | Turnover: 1.4051 | TC: 0.001451 | Net:  0.03117
#
# [7/59] Date: 2020-07-31 | Year: 2020
#   Window: 2005-07-31 to 2020-06-30
#   Buy/Sell: 40 | Analyst: 162 | Union: 192 | Assets w/ data: 97
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02679 | Turnover: 1.0171 | TC: 0.001044 | Net:  0.02574
#
# [8/59] Date: 2020-08-31 | Year: 2020
#   Window: 2005-08-31 to 2020-07-31
#   Buy/Sell: 40 | Analyst: 89 | Union: 122 | Assets w/ data: 57
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.01161 | Turnover: 1.2010 | TC: 0.001187 | Net: -0.01280
#
# [9/59] Date: 2020-09-30 | Year: 2020
#   Window: 2005-09-30 to 2020-08-31
#   Buy/Sell: 40 | Analyst: 150 | Union: 180 | Assets w/ data: 89
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.01433 | Turnover: 1.4702 | TC: 0.001449 | Net: -0.01578
#
# [10/59] Date: 2020-10-31 | Year: 2020
#   Window: 2005-10-31 to 2020-09-30
#   Buy/Sell: 40 | Analyst: 134 | Union: 166 | Assets w/ data: 86
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.11678 | Turnover: 1.2606 | TC: 0.001408 | Net:  0.11538
#
# [11/59] Date: 2020-11-30 | Year: 2020
#   Window: 2005-11-30 to 2020-10-31
#   Buy/Sell: 40 | Analyst: 134 | Union: 159 | Assets w/ data: 85
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02886 | Turnover: 1.5671 | TC: 0.001612 | Net:  0.02725
#
# [12/59] Date: 2020-12-31 | Year: 2020
#   Window: 2005-12-31 to 2020-11-30
#   Buy/Sell: 40 | Analyst: 145 | Union: 174 | Assets w/ data: 75
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.00135 | Turnover: 1.3861 | TC: 0.001384 | Net: -0.00273
#
# [13/59] Date: 2021-01-31 | Year: 2021
#   Window: 2006-01-31 to 2020-12-31
#   Buy/Sell: 123 | Analyst: 181 | Union: 256 | Assets w/ data: 129
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03229 | Turnover: 1.4669 | TC: 0.001514 | Net:  0.03078
#
# [14/59] Date: 2021-02-28 | Year: 2021
#   Window: 2006-02-28 to 2021-01-31
#   Buy/Sell: 123 | Analyst: 107 | Union: 201 | Assets w/ data: 98
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.07772 | Turnover: 0.6144 | TC: 0.000662 | Net:  0.07706
#
# [15/59] Date: 2021-03-31 | Year: 2021
#   Window: 2006-03-31 to 2021-02-28
#   Buy/Sell: 123 | Analyst: 128 | Union: 225 | Assets w/ data: 107
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03205 | Turnover: 0.9000 | TC: 0.000929 | Net:  0.03112
#
# [16/59] Date: 2021-04-30 | Year: 2021
#   Window: 2006-04-30 to 2021-03-31
#   Buy/Sell: 123 | Analyst: 123 | Union: 221 | Assets w/ data: 118
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02055 | Turnover: 0.9819 | TC: 0.001002 | Net:  0.01955
#
# [17/59] Date: 2021-05-31 | Year: 2021
#   Window: 2006-05-31 to 2021-04-30
#   Buy/Sell: 123 | Analyst: 122 | Union: 222 | Assets w/ data: 117
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.00034 | Turnover: 0.7916 | TC: 0.000791 | Net: -0.00113
#
# [18/59] Date: 2021-06-30 | Year: 2021
#   Window: 2006-06-30 to 2021-05-31
#   Buy/Sell: 123 | Analyst: 111 | Union: 213 | Assets w/ data: 113
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.01116 | Turnover: 0.6346 | TC: 0.000642 | Net:  0.01052
#
# [19/59] Date: 2021-07-31 | Year: 2021
#   Window: 2006-07-31 to 2021-06-30
#   Buy/Sell: 123 | Analyst: 131 | Union: 220 | Assets w/ data: 117
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.00826 | Turnover: 0.8978 | TC: 0.000905 | Net:  0.00735
#
# [20/59] Date: 2021-08-31 | Year: 2021
#   Window: 2006-08-31 to 2021-07-31
#   Buy/Sell: 123 | Analyst: 110 | Union: 209 | Assets w/ data: 105
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.03103 | Turnover: 0.8640 | TC: 0.000837 | Net: -0.03187
#
# [21/59] Date: 2021-09-30 | Year: 2021
#   Window: 2006-09-30 to 2021-08-31
#   Buy/Sell: 123 | Analyst: 118 | Union: 218 | Assets w/ data: 106
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03982 | Turnover: 0.8937 | TC: 0.000929 | Net:  0.03889
#
# [22/59] Date: 2021-10-31 | Year: 2021
#   Window: 2006-10-31 to 2021-09-30
#   Buy/Sell: 123 | Analyst: 178 | Union: 258 | Assets w/ data: 128
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.01498 | Turnover: 1.0259 | TC: 0.001011 | Net: -0.01599
#
# [23/59] Date: 2021-11-30 | Year: 2021
#   Window: 2006-11-30 to 2021-10-31
#   Buy/Sell: 123 | Analyst: 161 | Union: 248 | Assets w/ data: 125
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.07508 | Turnover: 0.8173 | TC: 0.000879 | Net:  0.07420
#
# [24/59] Date: 2021-12-31 | Year: 2021
#   Window: 2006-12-31 to 2021-11-30
#   Buy/Sell: 123 | Analyst: 127 | Union: 218 | Assets w/ data: 117
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.01625 | Turnover: 0.7060 | TC: 0.000695 | Net: -0.01695
#
# [25/59] Date: 2022-01-31 | Year: 2022
#   Window: 2007-01-31 to 2021-12-31
#   Buy/Sell: 34 | Analyst: 150 | Union: 174 | Assets w/ data: 89
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.02821 | Turnover: 1.1165 | TC: 0.001085 | Net: -0.02930
#
# [26/59] Date: 2022-02-28 | Year: 2022
#   Window: 2007-02-28 to 2022-01-31
#   Buy/Sell: 34 | Analyst: 102 | Union: 124 | Assets w/ data: 57
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.04178 | Turnover: 1.0121 | TC: 0.001054 | Net:  0.04072
#
# [27/59] Date: 2022-03-31 | Year: 2022
#   Window: 2007-03-31 to 2022-02-28
#   Buy/Sell: 34 | Analyst: 138 | Union: 165 | Assets w/ data: 83
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.03849 | Turnover: 1.2222 | TC: 0.001175 | Net: -0.03966
#
# [28/59] Date: 2022-04-30 | Year: 2022
#   Window: 2007-04-30 to 2022-03-31
#   Buy/Sell: 34 | Analyst: 132 | Union: 156 | Assets w/ data: 77
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.01964 | Turnover: 1.0025 | TC: 0.001022 | Net:  0.01862
#
# [29/59] Date: 2022-05-31 | Year: 2022
#   Window: 2007-05-31 to 2022-04-30
#   Buy/Sell: 34 | Analyst: 117 | Union: 143 | Assets w/ data: 62
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.05165 | Turnover: 0.6967 | TC: 0.000661 | Net: -0.05231
#
# [30/59] Date: 2022-06-30 | Year: 2022
#   Window: 2007-06-30 to 2022-05-31
#   Buy/Sell: 34 | Analyst: 127 | Union: 151 | Assets w/ data: 71
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.06947 | Turnover: 1.1988 | TC: 0.001282 | Net:  0.06819
#
# [31/59] Date: 2022-07-31 | Year: 2022
#   Window: 2007-07-31 to 2022-06-30
#   Buy/Sell: 34 | Analyst: 152 | Union: 174 | Assets w/ data: 79
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.04208 | Turnover: 1.1941 | TC: 0.001144 | Net: -0.04322
#
# [32/59] Date: 2022-08-31 | Year: 2022
#   Window: 2007-08-31 to 2022-07-31
#   Buy/Sell: 34 | Analyst: 123 | Union: 148 | Assets w/ data: 60
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.08451 | Turnover: 0.8545 | TC: 0.000782 | Net: -0.08529
#
# [33/59] Date: 2022-09-30 | Year: 2022
#   Window: 2007-09-30 to 2022-08-31
#   Buy/Sell: 34 | Analyst: 117 | Union: 147 | Assets w/ data: 67
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.08418 | Turnover: 1.2447 | TC: 0.001350 | Net:  0.08283
#
# [34/59] Date: 2022-10-31 | Year: 2022
#   Window: 2007-10-31 to 2022-09-30
#   Buy/Sell: 34 | Analyst: 140 | Union: 164 | Assets w/ data: 76
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.06274 | Turnover: 1.1599 | TC: 0.001233 | Net:  0.06151
#
# [35/59] Date: 2022-11-30 | Year: 2022
#   Window: 2007-11-30 to 2022-10-31
#   Buy/Sell: 34 | Analyst: 112 | Union: 138 | Assets w/ data: 72
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.02789 | Turnover: 1.1315 | TC: 0.001100 | Net: -0.02899
#
# [36/59] Date: 2022-12-31 | Year: 2022
#   Window: 2007-12-31 to 2022-11-30
#   Buy/Sell: 34 | Analyst: 125 | Union: 151 | Assets w/ data: 74
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02407 | Turnover: 1.0042 | TC: 0.001028 | Net:  0.02304
#
# [37/59] Date: 2023-01-31 | Year: 2023
#   Window: 2008-01-31 to 2022-12-31
#   Buy/Sell: 137 | Analyst: 166 | Union: 258 | Assets w/ data: 124
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.03699 | Turnover: 1.6301 | TC: 0.001570 | Net: -0.03856
#
# [38/59] Date: 2023-02-28 | Year: 2023
#   Window: 2008-02-29 to 2023-01-31
#   Buy/Sell: 137 | Analyst: 112 | Union: 217 | Assets w/ data: 108
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.00189 | Turnover: 0.6248 | TC: 0.000626 | Net:  0.00126
#
# [39/59] Date: 2023-03-31 | Year: 2023
#   Window: 2008-03-31 to 2023-02-28
#   Buy/Sell: 137 | Analyst: 134 | Union: 235 | Assets w/ data: 108
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.01525 | Turnover: 0.7828 | TC: 0.000795 | Net:  0.01445
#
# [40/59] Date: 2023-04-30 | Year: 2023
#   Window: 2008-04-30 to 2023-03-31
#   Buy/Sell: 137 | Analyst: 141 | Union: 240 | Assets w/ data: 116
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.05908 | Turnover: 1.1033 | TC: 0.001038 | Net: -0.06011
#
# [41/59] Date: 2023-05-31 | Year: 2023
#   Window: 2008-05-31 to 2023-04-30
#   Buy/Sell: 137 | Analyst: 112 | Union: 223 | Assets w/ data: 109
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.05943 | Turnover: 0.8786 | TC: 0.000931 | Net:  0.05850
#
# [42/59] Date: 2023-06-30 | Year: 2023
#   Window: 2008-06-30 to 2023-05-31
#   Buy/Sell: 137 | Analyst: 113 | Union: 219 | Assets w/ data: 107
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.01800 | Turnover: 0.9103 | TC: 0.000927 | Net:  0.01707
#
# [43/59] Date: 2023-07-31 | Year: 2023
#   Window: 2008-07-31 to 2023-06-30
#   Buy/Sell: 137 | Analyst: 140 | Union: 250 | Assets w/ data: 117
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.03420 | Turnover: 0.7761 | TC: 0.000750 | Net: -0.03495
#
# [44/59] Date: 2023-08-31 | Year: 2023
#   Window: 2008-08-31 to 2023-07-31
#   Buy/Sell: 137 | Analyst: 143 | Union: 254 | Assets w/ data: 121
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.04405 | Turnover: 0.9216 | TC: 0.000881 | Net: -0.04493
#
# [45/59] Date: 2023-09-30 | Year: 2023
#   Window: 2008-09-30 to 2023-08-31
#   Buy/Sell: 137 | Analyst: 139 | Union: 243 | Assets w/ data: 123
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.02378 | Turnover: 0.8761 | TC: 0.000855 | Net: -0.02463
#
# [46/59] Date: 2023-10-31 | Year: 2023
#   Window: 2008-10-31 to 2023-09-30
#   Buy/Sell: 137 | Analyst: 158 | Union: 255 | Assets w/ data: 124
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.07224 | Turnover: 0.9410 | TC: 0.001009 | Net:  0.07123
#
# [47/59] Date: 2023-11-30 | Year: 2023
#   Window: 2008-11-30 to 2023-10-31
#   Buy/Sell: 137 | Analyst: 127 | Union: 234 | Assets w/ data: 115
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03148 | Turnover: 0.6976 | TC: 0.000720 | Net:  0.03076
#
# [48/59] Date: 2023-12-31 | Year: 2023
#   Window: 2008-12-31 to 2023-11-30
#   Buy/Sell: 137 | Analyst: 160 | Union: 259 | Assets w/ data: 132
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.00530 | Turnover: 0.7894 | TC: 0.000785 | Net: -0.00608
#
# [49/59] Date: 2024-01-31 | Year: 2024
#   Window: 2009-01-31 to 2023-12-31
#   Buy/Sell: 281 | Analyst: 145 | Union: 357 | Assets w/ data: 192
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02239 | Turnover: 1.2145 | TC: 0.001242 | Net:  0.02115
#
# [50/59] Date: 2024-02-29 | Year: 2024
#   Window: 2009-02-28 to 2024-01-31
#   Buy/Sell: 281 | Analyst: 126 | Union: 340 | Assets w/ data: 181
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03888 | Turnover: 0.2407 | TC: 0.000250 | Net:  0.03863
#
# [51/59] Date: 2024-03-31 | Year: 2024
#   Window: 2009-03-31 to 2024-02-29
#   Buy/Sell: 281 | Analyst: 114 | Union: 335 | Assets w/ data: 184
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.03907 | Turnover: 0.3161 | TC: 0.000304 | Net: -0.03937
#
# [52/59] Date: 2024-04-30 | Year: 2024
#   Window: 2009-04-30 to 2024-03-31
#   Buy/Sell: 281 | Analyst: 146 | Union: 359 | Assets w/ data: 198
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.01805 | Turnover: 0.3981 | TC: 0.000405 | Net:  0.01764
#
# [53/59] Date: 2024-05-31 | Year: 2024
#   Window: 2009-05-31 to 2024-04-30
#   Buy/Sell: 281 | Analyst: 118 | Union: 337 | Assets w/ data: 178
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.01553 | Turnover: 0.2028 | TC: 0.000200 | Net: -0.01573
#
# [54/59] Date: 2024-06-30 | Year: 2024
#   Window: 2009-06-30 to 2024-05-31
#   Buy/Sell: 281 | Analyst: 122 | Union: 340 | Assets w/ data: 178
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.05979 | Turnover: 0.2295 | TC: 0.000243 | Net:  0.05955
#
# [55/59] Date: 2024-07-31 | Year: 2024
#   Window: 2009-07-31 to 2024-06-30
#   Buy/Sell: 281 | Analyst: 172 | Union: 356 | Assets w/ data: 192
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03728 | Turnover: 0.3696 | TC: 0.000383 | Net:  0.03690
#
# [56/59] Date: 2024-08-31 | Year: 2024
#   Window: 2009-08-31 to 2024-07-31
#   Buy/Sell: 281 | Analyst: 109 | Union: 323 | Assets w/ data: 174
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.01605 | Turnover: 0.2052 | TC: 0.000209 | Net:  0.01584
#
# [57/59] Date: 2024-09-30 | Year: 2024
#   Window: 2009-09-30 to 2024-08-31
#   Buy/Sell: 281 | Analyst: 140 | Union: 350 | Assets w/ data: 191
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.02127 | Turnover: 0.3669 | TC: 0.000359 | Net: -0.02163
#
# [58/59] Date: 2024-10-31 | Year: 2024
#   Window: 2009-10-31 to 2024-09-30
#   Buy/Sell: 281 | Analyst: 156 | Union: 355 | Assets w/ data: 189
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.04650 | Turnover: 0.3549 | TC: 0.000371 | Net:  0.04613
#
# [59/59] Date: 2024-11-30 | Year: 2024
#   Window: 2009-11-30 to 2024-10-31
#   Buy/Sell: 281 | Analyst: 121 | Union: 341 | Assets w/ data: 173
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.06946 | Turnover: 0.2162 | TC: 0.000201 | Net: -0.06966
#
# ============================================================
# BACKTEST COMPLETE
# ============================================================
#
# Sharpe Ratio: 0.1304
# Annualized Sharpe Ratio: 0.4516
# Total Return: 0.3598
# Average Turnover: 0.9049

# %%
with pd.option_context("display.max_rows", None):
    print(results_df['portfolio_weights'][0])
# Out:
# {34817: 0.005277215479814984, 20482: 0.014034144699150864, 87055: 0.01288889083697854, 59408: -0.007586663723323442, 34833: 0.007602547288775705, 72726: 0.005458418602220206, 60442: 0.011150252089831125, 76841: 0.003653776031360526, 24109: 0.01727639851960214, 66093: 0.014911476563791055, 57904: 0.007865980348370046, 75825: 0.004380455470766707, 86580: -0.0015164269246696607, 59459: 0.015251696230171556, 78916: 0.00621563348861194, 17478: 0.007145168166880065, 11850: 0.016097556095209038, 48725: 0.011025166751601515, 26710: 0.016710060210123837, 22103: 0.013084884518753613, 60506: 0.0071937825748797125, 87137: -0.00023895331640971882, 13928: 0.009988837267777523, 89195: -0.009777613655372927, 66157: 0.013976038619921518, 18542: 0.0024237898322542464, 36468: 0.010910354974340428, 86136: 0.017304294336858796, 41080: -0.0013445045578453984, 85631: 0.0006001120044699923, 66181: 0.01221301151202606, 11404: 0.01987756470597568, 24205: 0.015992647837646524, 77462: 0.0007334194791185639, 81055: 0.005330263605831362, 84129: -0.001637922848948079, 82598: 0.0026480473696502064, 89258: 0.005817256586196674, 11955: 0.018739181351996186, 45751: 0.015374168707645703, 14008: 0.006806271830088838, 79547: 0.011019116953440808, 23229: 0.013815073980884088, 60097: 0.010537248384733132, 21186: 0.0054435827497042516, 62148: 0.006333686375716814, 26825: 0.01728192790640984, 14541: 0.014739654856814211, 37584: 0.009123910304695037, 21207: 0.003025541417759771, 39642: 0.01311873232165382, 82651: 0.006802426406553605, 15069: -0.002152297624720763, 49373: 0.005321261219352936, 22752: 0.010037163934627166, 57568: 0.010256836533036278, 35554: 0.011806317288939031, 35044: -0.0002673768969649645, 27887: 0.011243988622686392, 34032: -0.0003674666715841067, 66800: -0.0040227703068646875, 75510: 0.005789093004963352, 17144: 0.01878909916350755, 52476: 0.009155953900370538, 82686: 0.004442720285121931, 14593: 0.004451203293457085, 23819: 0.0003051183966877751, 38156: 0.004932321496281071, 85269: 0.0029106998661068526, 47896: 0.010156741058402753, 64282: 0.0029052021442147417, 75034: 0.002302689772818303, 12060: 0.006263818588336968, 21792: 0.011645424115123877, 87842: 0.009993038027423854, 59176: 0.005112932718746443, 76076: 0.0075822996547516164, 38703: 0.00914555872453593, 27959: 0.02246703854054382, 64311: 0.005918950782829511, 76605: 0.01032655446142973, 28484: 0.0009715613274251597, 52038: 0.014980553277135827, 80711: 0.0033871530726793868, 86356: 0.004397805806687107, 86868: 0.00590703513552669, 75607: 0.004590180944246737, 82775: -0.0043077381815836025, 25953: 0.010347912752695566, 85348: 0.01048979788943205, 38762: 0.013255820278571692, 53613: 0.0006269857582908638, 14702: 0.00525015235023817, 81774: -0.0069236969410051835, 49015: -0.006716607457461117, 70519: -0.004831506535574065, 52090: 0.01610909113842406, 48506: 0.003979465781554633, 23931: 0.019984456485173337, 77178: 0.004156074841258313, 54148: 0.0008667835996479013, 64390: 0.01078971747812848, 41355: 0.0072435977156533925, 71563: 0.008695234224162823, 75154: 0.006628237584348203, 84373: 0.011659014777831128, 19350: 0.006914753351858585, 24985: 0.014365575278664373, 11674: 0.017499366680082097, 10138: 0.009267583266637245, 42906: -0.0013308263316293124, 84381: 0.00024063901791721877, 69032: 0.002851716678334551, 76201: 0.006614187542219526, 21936: 0.012578815597496068, 73139: 0.009010976873068146, 89525: 0.007824605729890449, 43449: 0.018960891096433535, 34746: -0.0038192413287092735, 59328: 0.008382113284260865, 76226: 0.0015465538621201704, 14277: 0.005223335912801767, 10696: 0.012860538852903622, 57817: 0.00262430148368465, 79323: 0.011424976785825304, 64995: 0.005557049477839799, 89070: 0.00796851768259106, 11762: 0.008574217773876083, 46578: 0.017223061043924893, 22517: 0.014874795014464193, 49656: 0.011009154027045748, 25081: 0.008665563528261993}

# %%
metrics['total_return']
# Out:
# 0.32500401603096774

# %%
metrics['variance']
# Out:
# 0.0023791989338631018

# %%
results_df['portfolio_turnover'].mean()
# Out:
# 0.8711773118769293

# %% [markdown]
# # INTERSECTON

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Lasso
import warnings
warnings.filterwarnings('ignore')


def naive_nodewise_regression(Y_star, lambda_grid=None):
    """
    Implements Naive Nodewise Regression (Section 5.1.2).
    Uses GIC (Generalized Information Criterion) as in the paper.
    
    Parameters:
    -----------
    Y_star : np.ndarray, shape (n, p)
        Demeaned returns matrix (time x assets)
    lambda_grid : list or None
        Grid of lambda values to try. If None, creates default grid.
    
    Returns:
    --------
    Theta_hat : np.ndarray, shape (p, p)
        Estimated precision matrix
    """
    n, p = Y_star.shape

    # Initialize matrices
    Theta_hat = np.zeros((p, p))
    tau_squared = np.zeros(p)
    
    # Create lambda grid if not provided
    if lambda_grid is None:
        lambda_grid = np.logspace(-3, 1, 50)
    
    # For each asset j
    for j in range(p):
        # Step 1: Get y_j (target) and Y_{-j} (predictors)
        y_j = Y_star[:, j]
        Y_minus_j = np.delete(Y_star, j, axis=1)
        
        # Step 2-3: Estimate gamma_j using Lasso with GIC
        best_gic = np.inf
        best_lambda = lambda_grid[0]
        best_gamma = None
        best_ssr = None
        
        for lam in lambda_grid:
            lasso = Lasso(alpha=2*lam, fit_intercept=False, max_iter=10000)
            lasso.fit(Y_minus_j, y_j)
            gamma_j = lasso.coef_
            
            # Compute SSR and number of non-zero coefficients
            residuals = y_j - Y_minus_j @ gamma_j
            ssr = np.sum(residuals ** 2)
            sigma_sq_lambda = ssr / n
            q_lambda = np.sum(np.abs(gamma_j) > 1e-8)
            
            # Compute GIC
            if sigma_sq_lambda > 1e-10:
                gic = np.log(sigma_sq_lambda) + q_lambda * (np.log(p) / n) * np.log(np.log(n))
            else:
                gic = np.inf
            
            if gic < best_gic:
                best_gic = gic
                best_lambda = lam
                best_gamma = gamma_j.copy()
                best_ssr = ssr
        
        gamma_j_star = best_gamma
        tau_squared[j] = best_ssr / n + best_lambda * np.sum(np.abs(gamma_j_star))

        # Step 5: Form the j-th row of Theta_hat
        Theta_hat[j, j] = 1 / tau_squared[j]
        off_diag = -gamma_j_star / tau_squared[j]
        Theta_hat[j, :j] = off_diag[:j]
        Theta_hat[j, j+1:] = off_diag[j:]
    
    # Step 6: Symmetrize
    Theta_hat_sym = (Theta_hat + Theta_hat.T) / 2
    
    return Theta_hat_sym


def gmv_weights(Theta_hat):
    """
    Compute Global Minimum Variance (GMV) portfolio weights (Section 6.1).
    
    Parameters:
    -----------
    Theta_hat : np.ndarray, shape (p, p)
        Precision matrix
    
    Returns:
    --------
    w_star : np.ndarray, shape (p,)
        Portfolio weights
    """
    p = Theta_hat.shape[0]
    ones_p = np.ones(p)
    
    # w* = (Θ 1_p) / (1_p' Θ 1_p)
    numerator = Theta_hat @ ones_p
    denominator = ones_p @ Theta_hat @ ones_p
    
    if np.abs(denominator) < 1e-10:
        # Fallback to equal weights if precision matrix is near-singular
        return ones_p / p
    
    w_star = numerator / denominator
    
    return w_star


def load_yearly_signals(year, buys_path_template='buys_{}.csv', sells_path_template='sells_{}.csv'):
    """
    Load buy and sell signals for a specific year.
    
    Parameters:
    -----------
    year : int
        Year to load signals for
    buys_path_template : str
        Template for buys file path (use {} for year placeholder)
    sells_path_template : str
        Template for sells file path (use {} for year placeholder)
    
    Returns:
    --------
    permno_set : set
        Set of permnos in the buy and sell signals for this year
    """
    try:
        buys = pd.read_csv(buys_path_template.format(year), index_col=1)
        sells = pd.read_csv(sells_path_template.format(year), index_col=1)
        
        buys.index.name = 'permno'
        sells.index.name = 'permno'
        
        buys_index = buys.index.astype(int)
        sells_index = sells.index.astype(int)
        
        return set(buys_index.union(sells_index))
    except FileNotFoundError as e:
        print(f"  ⚠ Warning: Could not load signals for year {year}: {e}")
        return set()


def load_analyst_recommendations(rec_changes_path):
    """
    Load significant recommendation changes from CSV file.
    
    Parameters:
    -----------
    rec_changes_path : str
        Path to significant_recommendation_changes.csv file
    
    Returns:
    --------
    rec_changes_df : pd.DataFrame
        DataFrame with columns: permno, date, ticker, mean_recommendation, 
        recommendation_change, num_recommendations
    """
    try:
        rec_changes_df = pd.read_csv(rec_changes_path)
        rec_changes_df['date'] = pd.to_datetime(rec_changes_df['date'])
        rec_changes_df['permno'] = rec_changes_df['permno'].astype(int)
        return rec_changes_df
    except FileNotFoundError as e:
        print(f"  ⚠ Warning: Could not load recommendation changes: {e}")
        return pd.DataFrame(columns=['permno', 'date', 'ticker', 'mean_recommendation', 
                                    'recommendation_change', 'num_recommendations'])


def get_analyst_permnos_for_date(rec_changes_df, date):
    """
    Get sets of permnos with upgrades (negative changes) and downgrades (positive changes).
    
    Note: Negative change = upgrade (moving toward Strong Buy)
          Positive change = downgrade (moving toward Sell)
    
    Parameters:
    -----------
    rec_changes_df : pd.DataFrame
        Recommendation changes dataframe
    date : pd.Timestamp
        Date to get changes for
    
    Returns:
    --------
    upgrade_permnos : set
        Set of permnos with negative recommendation changes (upgrades) - BUY these
    downgrade_permnos : set
        Set of permnos with positive recommendation changes (downgrades) - SELL these
    """
    date_changes = rec_changes_df[rec_changes_df['date'] == date]
    
    # Upgrades: negative changes (recommendations getting better)
    upgrades = date_changes[date_changes['recommendation_change'] < 0]
    upgrade_permnos = set(upgrades['permno'].values)
    
    # Downgrades: positive changes (recommendations getting worse)
    downgrades = date_changes[date_changes['recommendation_change'] > 0]
    downgrade_permnos = set(downgrades['permno'].values)
    
    return upgrade_permnos | downgrade_permnos


def backtest_nodewise_gmv_yearly(df, 
                                  test_start_date='2020-01-31', 
                                  test_end_date='2024-11-30',
                                  lookback_window=180,
                                  transaction_cost=0.001,
                                  buys_path_template='buys_{}.csv',
                                  sells_path_template='sells_{}.csv',
                                  analyst_rec_path=None,
                                  verbose=True):
    """
    Backtest Nodewise + GMV strategy with year-specific buy/sell signals 
    and analyst recommendations.
    
    Parameters:
    -----------
    df : pd.DataFrame
        DataFrame with columns: permno, datadate, ret_fwd_1
    test_start_date : str
        First date for out-of-sample returns (format: 'YYYY-MM-DD')
    test_end_date : str
        Last date for out-of-sample returns (format: 'YYYY-MM-DD')
    lookback_window : int
        Number of months in rolling training window (default: 180)
    transaction_cost : float
        Proportional transaction cost (default: 0.001 = 10 bps)
    buys_path_template : str
        Template for buys file path (use {} for year placeholder)
    sells_path_template : str
        Template for sells file path (use {} for year placeholder)
    analyst_rec_path : str or None
        Path to analyst recommendations CSV file. If None, only uses buy/sell signals.
    verbose : bool
        If True, prints detailed log at each time step.
    
    Returns:
    --------
    results_df : pd.DataFrame
        DataFrame with columns: date, portfolio_return, cumulative_return
    metrics : dict
        Overall performance metrics
    """
    # --- 1. Setup ---
    df = df.copy()
    if 'datadate' not in df.columns or 'permno' not in df.columns:
        raise ValueError("DataFrame must have 'datadate' and 'permno' columns")
    df['datadate'] = pd.to_datetime(df['datadate'])
    
    # Load analyst recommendations if provided
    analyst_df = None
    if analyst_rec_path is not None:
        analyst_df = load_analyst_recommendations(analyst_rec_path)
        if verbose and len(analyst_df) > 0:
            print(f"Loaded analyst recommendations: {len(analyst_df)} records")
    
    # Get unique dates
    all_dates = sorted(df['datadate'].unique())
    
    # Convert test dates to datetime
    test_start_dt = pd.to_datetime(test_start_date)
    test_end_dt = pd.to_datetime(test_end_date)
    
    # Find date indices
    try:
        test_start_idx = all_dates.index(test_start_dt)
        test_end_idx = all_dates.index(test_end_dt)
    except ValueError as e:
        raise ValueError(f"Date not found in DataFrame: {e}")
    
    if test_start_idx < lookback_window:
        raise ValueError(f"Not enough data for lookback. Test start date {test_start_date} "
                         f"requires data back to {all_dates[test_start_idx - lookback_window]}, "
                         f"but only {test_start_idx} periods are available.")
    
    # Storage for results
    portfolio_returns = []
    portfolio_dates = []
    portfolio_weights_list = []
    portfolio_turnover_list = []
    portfolio_gross_returns = []
    
    # Track weights by permno
    prev_weights_dict = {}
    prev_oos_returns_dict = {}
    prev_gross_return = 0.0
    
    # Cache for yearly signals
    yearly_signals_cache = {}
    
    # --- 2. Rolling Window Backtest ---
    if verbose:
        print("="*60)
        print("STARTING BACKTEST WITH YEARLY SIGNALS + ANALYST RECS")
        print("="*60)
        
    for t in range(test_start_idx, test_end_idx + 1):
        current_date = all_dates[t]
        current_year = current_date.year
        
        # Load signals for current year if not cached
        if current_year not in yearly_signals_cache:
            yearly_signals_cache[current_year] = load_yearly_signals(
                current_year, buys_path_template, sells_path_template
            )
        
        buysell_permnos = yearly_signals_cache[current_year]
        
        # Get analyst recommendations for current date
        analyst_permnos = set()
        if analyst_df is not None and len(analyst_df) > 0:
            analyst_permnos = get_analyst_permnos_for_date(analyst_df, current_date)
        
        # INTERSECTION of buy/sell signals and analyst recommendations
        allowed_permnos = buysell_permnos.intersection(analyst_permnos)
        
        if len(allowed_permnos) == 0:
            if verbose:
                print(f"\n[{t - test_start_idx + 1}/{test_end_idx - test_start_idx + 1}] "
                      f"Date: {current_date.strftime('%Y-%m-%d')}")
                print(f"  ⚠ No signals or analyst recs for {current_date.strftime('%Y-%m-%d')}, skipping period")
            continue
        
        # Define the lookback window
        window_start_date = all_dates[t - lookback_window]
        window_end_date = all_dates[t - 1]
        
        # Get training data for this window, filtered by allowed permnos
        train_data = df[(df['datadate'] >= window_start_date) & 
                        (df['datadate'] <= window_end_date) &
                        (df['permno'].isin(allowed_permnos))]
        
        # Pivot to get returns matrix (time x assets)
        returns_pivot = train_data.pivot(index='datadate', columns='permno', values='ret_fwd_1')
        
        # Reindex to ensure all dates are present
        window_dates = all_dates[t - lookback_window : t]
        returns_pivot = returns_pivot.reindex(index=window_dates)
        
        # Filter assets with any NaNs in this window
        nan_assets = returns_pivot.columns[returns_pivot.isna().any()]
        filtered_pivot = returns_pivot.drop(columns=nan_assets)
        
        current_assets = filtered_pivot.columns.tolist()
        Y = filtered_pivot.values
        n_train, p_current = Y.shape

        if verbose:
            print(f"\n[{t - test_start_idx + 1}/{test_end_idx - test_start_idx + 1}] "
                  f"Date: {current_date.strftime('%Y-%m-%d')} | Year: {current_year}")
            print(f"  Window: {window_start_date.strftime('%Y-%m-%d')} to "
                  f"{window_end_date.strftime('%Y-%m-%d')}")
            print(f"  Buy/Sell: {len(buysell_permnos)} | Analyst: {len(analyst_permnos)} | "
                  f"Union: {len(allowed_permnos)} | Assets w/ data: {p_current}")

        # Check for valid data
        if n_train < lookback_window or p_current < 2:
            if verbose:
                print(f"  ⚠ Insufficient data (n={n_train}, p={p_current}), using prev weights")
            # Filter previous weights to only allowed permnos
            new_weights_dict = {k: v for k, v in prev_weights_dict.items() if k in allowed_permnos}
        else:
            try:
                # Demean the returns
                Y_bar = Y.mean(axis=0)
                Y_star = Y - Y_bar
                
                if verbose:
                    print(f"  Running Nodewise Regression...")
                Theta_hat = naive_nodewise_regression(Y_star)
                
                if verbose:
                    print(f"  Computing GMV weights...")
                w_star = gmv_weights(Theta_hat)
                
                # Create weights dictionary
                new_weights_dict = {asset: w_star[i] for i, asset in enumerate(current_assets)}
                
            except Exception as e:
                if verbose:
                    print(f"  ✗ Error: {e}")
                    print(f"  Using previous weights")
                # Filter previous weights to only allowed permnos
                new_weights_dict = {k: v for k, v in prev_weights_dict.items() if k in allowed_permnos}

        # Normalize weights to sum to 1
        weight_sum = sum(new_weights_dict.values())
        if weight_sum > 1e-10:
            new_weights_dict = {k: v/weight_sum for k, v in new_weights_dict.items()}
        else:
            if verbose:
                print("  ⚠ Zero weight sum, using previous weights")
            new_weights_dict = {k: v for k, v in prev_weights_dict.items() if k in allowed_permnos}
            weight_sum = sum(new_weights_dict.values())
            if weight_sum > 1e-10:
                new_weights_dict = {k: v/weight_sum for k, v in new_weights_dict.items()}
        
        # --- 3. OOS Returns & Transaction Costs ---
        
        # Get out-of-sample returns for current month (only for allowed permnos)
        oos_data = df[(df['datadate'] == current_date) & (df['permno'].isin(allowed_permnos))]
        oos_returns_series = oos_data.set_index('permno')['ret_fwd_1']
        
        # Filter out NaN returns
        oos_returns_series = oos_returns_series.dropna()
        oos_returns_dict = oos_returns_series.to_dict()
        
        # Find common assets between weights and returns
        common_assets = set(new_weights_dict.keys()) & set(oos_returns_dict.keys())
        
        if len(common_assets) == 0:
            if verbose:
                print("  ⚠ No common assets with valid returns, skipping period")
            continue
        
        # Filter to common assets and renormalize
        common_weights = {a: new_weights_dict[a] for a in common_assets}
        common_weight_sum = sum(common_weights.values())
        if common_weight_sum > 1e-10:
            common_weights = {k: v/common_weight_sum for k, v in common_weights.items()}
        else:
            if verbose:
                print("  ⚠ Zero weight sum after filtering, skipping period")
            continue
        
        # Compute gross portfolio return
        gross_return = sum(common_weights[a] * oos_returns_dict[a] for a in common_assets)
        
        # Sanity check
        if np.isnan(gross_return) or np.isinf(gross_return):
            if verbose:
                print(f"  ⚠ Invalid gross return: {gross_return}, skipping period")
            continue
        
        # Calculate transaction costs
        if len(prev_weights_dict) > 0:
            all_traded_assets = set(common_weights.keys()) | set(prev_weights_dict.keys())
            
            # Adjust previous weights
            adjusted_prev = {}
            for asset in all_traded_assets:
                prev_w = prev_weights_dict.get(asset, 0.0)
                
                if asset in prev_oos_returns_dict:
                    prev_r = prev_oos_returns_dict[asset]
                    if prev_gross_return > -0.99:
                        adjusted_prev[asset] = prev_w * (1 + prev_r) / (1 + prev_gross_return)
                    else:
                        adjusted_prev[asset] = 0.0
                else:
                    adjusted_prev[asset] = 0.0
            
            # Renormalize adjusted weights
            adj_sum = sum(adjusted_prev.get(a, 0.0) for a in common_weights.keys())
            if adj_sum > 1e-10:
                adjusted_prev_normalized = {k: adjusted_prev.get(k, 0.0)/adj_sum 
                                           for k in common_weights.keys()}
            else:
                adjusted_prev_normalized = {k: 0.0 for k in common_weights.keys()}
            
            # Turnover
            turnover = sum(abs(common_weights.get(a, 0.0) - adjusted_prev_normalized.get(a, 0.0)) 
                          for a in all_traded_assets)
            
            # Transaction cost
            tc = transaction_cost * (1 + gross_return) * turnover
        else:
            # First period
            turnover = sum(abs(w) for w in common_weights.values())
            tc = transaction_cost * turnover
        
        # Net return
        net_return = gross_return - tc
        
        # Store results
        portfolio_returns.append(net_return)
        portfolio_dates.append(current_date)
        portfolio_weights_list.append(common_weights.copy())
        portfolio_turnover_list.append(turnover)
        portfolio_gross_returns.append(gross_return)
        
        # Update previous values for next iteration
        prev_weights_dict = common_weights.copy()
        prev_oos_returns_dict = {a: oos_returns_dict[a] for a in common_assets}
        prev_gross_return = gross_return
        
        if verbose:
            print(f"  Gross: {gross_return:>8.5f} | Turnover: {turnover:>6.4f} | "
                  f"TC: {tc:>8.6f} | Net: {net_return:>8.5f}")

    if verbose:
        print("\n" + "="*60)
        print("BACKTEST COMPLETE")
        print("="*60)
    
    # --- 4. Compile Results ---
    results_df = pd.DataFrame({
        'date': portfolio_dates,
        'portfolio_return': portfolio_returns,
        'portfolio_gross_return': portfolio_gross_returns,
        'portfolio_weights': portfolio_weights_list,
        'portfolio_turnover': portfolio_turnover_list
    })
    results_df['cumulative_return'] = (1 + results_df['portfolio_return']).cumprod() - 1
    
    # Compute overall metrics
    if len(portfolio_returns) > 0:
        mean_return = np.mean(portfolio_returns)
        variance = np.var(portfolio_returns, ddof=1)
        sharpe_ratio = mean_return / np.sqrt(variance) if variance > 0 else 0
        
        # Annualized metrics (monthly data)
        annual_return = mean_return * 12
        annual_volatility = np.sqrt(variance * 12)
        annual_sharpe = annual_return / annual_volatility if annual_volatility > 0 else 0
        
        metrics = {
            'mean_return': mean_return,
            'variance': variance,
            'sharpe_ratio': sharpe_ratio,
            'annual_return': annual_return,
            'annual_volatility': annual_volatility,
            'annual_sharpe_ratio': annual_sharpe,
            'total_return': results_df['cumulative_return'].iloc[-1],
            'avg_turnover': np.mean(portfolio_turnover_list),
            'n_periods': len(portfolio_returns)
        }
    else:
        metrics = {
            'mean_return': 0,
            'variance': 0,
            'sharpe_ratio': 0,
            'annual_return': 0,
            'annual_volatility': 0,
            'annual_sharpe_ratio': 0,
            'total_return': 0,
            'avg_turnover': 0,
            'n_periods': 0
        }
    
    return results_df, metrics

# %%
df = pd.read_csv('../green cleaned.csv', dtype={'ncusip': 'string'})
df['ret_fwd_1'] = df.groupby('permno')['ret_excess'].shift(-1)

results_df, metrics = backtest_nodewise_gmv_yearly(
    df=df,
    test_start_date='2020-01-31',
    test_end_date='2024-11-30',
    lookback_window=180,
    transaction_cost=0.001,
    buys_path_template='../AI Portfolio Selection/buys_{}.csv',
    sells_path_template='../AI Portfolio Selection/sells_{}.csv',
    analyst_rec_path='monthly_mean_recommendations.csv',  # <-- Add this
    verbose=True
)

print(f"\nSharpe Ratio: {metrics['sharpe_ratio']:.4f}")
print(f"Annualized Sharpe Ratio: {metrics['annual_sharpe_ratio']:.4f}")
print(f"Total Return: {metrics['total_return']:.4f}")
print(f"Average Turnover: {metrics['avg_turnover']:.4f}")
# Out:
# Loaded analyst recommendations: 17055 records
# ============================================================
# STARTING BACKTEST WITH YEARLY SIGNALS + ANALYST RECS
# ============================================================
#
# [1/59] Date: 2020-01-31 | Year: 2020
#   Window: 2005-01-31 to 2019-12-31
#   Buy/Sell: 40 | Analyst: 234 | Union: 19 | Assets w/ data: 16
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.10165 | Turnover: 1.0884 | TC: 0.001088 | Net: -0.10274
#
# [2/59] Date: 2020-02-29 | Year: 2020
#   Window: 2005-02-28 to 2020-01-31
#   Buy/Sell: 40 | Analyst: 150 | Union: 8 | Assets w/ data: 7
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.14184 | Turnover: 1.1718 | TC: 0.001006 | Net: -0.14285
#
# [3/59] Date: 2020-03-31 | Year: 2020
#   Window: 2005-03-31 to 2020-02-29
#   Buy/Sell: 40 | Analyst: 276 | Union: 23 | Assets w/ data: 17
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.10089 | Turnover: 1.5072 | TC: 0.001659 | Net:  0.09923
#
# [4/59] Date: 2020-04-30 | Year: 2020
#   Window: 2005-04-30 to 2020-03-31
#   Buy/Sell: 40 | Analyst: 333 | Union: 26 | Assets w/ data: 17
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03262 | Turnover: 0.7412 | TC: 0.000765 | Net:  0.03185
#
# [5/59] Date: 2020-05-31 | Year: 2020
#   Window: 2005-05-31 to 2020-04-30
#   Buy/Sell: 40 | Analyst: 213 | Union: 12 | Assets w/ data: 9
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.04357 | Turnover: 0.2584 | TC: 0.000247 | Net: -0.04382
#
# [6/59] Date: 2020-06-30 | Year: 2020
#   Window: 2005-06-30 to 2020-05-31
#   Buy/Sell: 40 | Analyst: 219 | Union: 18 | Assets w/ data: 13
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03632 | Turnover: 1.6786 | TC: 0.001740 | Net:  0.03459
#
# [7/59] Date: 2020-07-31 | Year: 2020
#   Window: 2005-07-31 to 2020-06-30
#   Buy/Sell: 40 | Analyst: 246 | Union: 15 | Assets w/ data: 10
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03008 | Turnover: 1.2318 | TC: 0.001269 | Net:  0.02881
#
# [8/59] Date: 2020-08-31 | Year: 2020
#   Window: 2005-08-31 to 2020-07-31
#   Buy/Sell: 40 | Analyst: 139 | Union: 8 | Assets w/ data: 4
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.01935 | Turnover: 1.0144 | TC: 0.001034 | Net:  0.01832
#
# [9/59] Date: 2020-09-30 | Year: 2020
#   Window: 2005-09-30 to 2020-08-31
#   Buy/Sell: 40 | Analyst: 194 | Union: 14 | Assets w/ data: 9
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.04083 | Turnover: 1.6810 | TC: 0.001750 | Net:  0.03908
#
# [10/59] Date: 2020-10-31 | Year: 2020
#   Window: 2005-10-31 to 2020-09-30
#   Buy/Sell: 40 | Analyst: 191 | Union: 11 | Assets w/ data: 8
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03713 | Turnover: 0.9225 | TC: 0.000957 | Net:  0.03617
#
# [11/59] Date: 2020-11-30 | Year: 2020
#   Window: 2005-11-30 to 2020-10-31
#   Buy/Sell: 40 | Analyst: 204 | Union: 21 | Assets w/ data: 16
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.04731 | Turnover: 0.9389 | TC: 0.000983 | Net:  0.04633
#
# [12/59] Date: 2020-12-31 | Year: 2020
#   Window: 2005-12-31 to 2020-11-30
#   Buy/Sell: 40 | Analyst: 220 | Union: 15 | Assets w/ data: 11
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.00968 | Turnover: 1.2484 | TC: 0.001261 | Net:  0.00842
#
# [13/59] Date: 2021-01-31 | Year: 2021
#   Window: 2006-01-31 to 2020-12-31
#   Buy/Sell: 123 | Analyst: 278 | Union: 73 | Assets w/ data: 43
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.06144 | Turnover: 1.9835 | TC: 0.002105 | Net:  0.05934
#
# [14/59] Date: 2021-02-28 | Year: 2021
#   Window: 2006-02-28 to 2021-01-31
#   Buy/Sell: 123 | Analyst: 166 | Union: 44 | Assets w/ data: 22
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.06752 | Turnover: 0.7662 | TC: 0.000818 | Net:  0.06670
#
# [15/59] Date: 2021-03-31 | Year: 2021
#   Window: 2006-03-31 to 2021-02-28
#   Buy/Sell: 123 | Analyst: 196 | Union: 42 | Assets w/ data: 24
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03216 | Turnover: 1.2753 | TC: 0.001316 | Net:  0.03084
#
# [16/59] Date: 2021-04-30 | Year: 2021
#   Window: 2006-04-30 to 2021-03-31
#   Buy/Sell: 123 | Analyst: 190 | Union: 43 | Assets w/ data: 33
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03604 | Turnover: 0.7037 | TC: 0.000729 | Net:  0.03531
#
# [17/59] Date: 2021-05-31 | Year: 2021
#   Window: 2006-05-31 to 2021-04-30
#   Buy/Sell: 123 | Analyst: 177 | Union: 36 | Assets w/ data: 22
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.00716 | Turnover: 1.4752 | TC: 0.001486 | Net:  0.00568
#
# [18/59] Date: 2021-06-30 | Year: 2021
#   Window: 2006-06-30 to 2021-05-31
#   Buy/Sell: 123 | Analyst: 180 | Union: 36 | Assets w/ data: 19
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.01089 | Turnover: 2.6697 | TC: 0.002699 | Net:  0.00819
#
# [19/59] Date: 2021-07-31 | Year: 2021
#   Window: 2006-07-31 to 2021-06-30
#   Buy/Sell: 123 | Analyst: 176 | Union: 44 | Assets w/ data: 32
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.00406 | Turnover: 1.4369 | TC: 0.001431 | Net: -0.00549
#
# [20/59] Date: 2021-08-31 | Year: 2021
#   Window: 2006-08-31 to 2021-07-31
#   Buy/Sell: 123 | Analyst: 157 | Union: 34 | Assets w/ data: 22
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.01856 | Turnover: 0.7437 | TC: 0.000730 | Net: -0.01929
#
# [21/59] Date: 2021-09-30 | Year: 2021
#   Window: 2006-09-30 to 2021-08-31
#   Buy/Sell: 123 | Analyst: 174 | Union: 36 | Assets w/ data: 20
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.04558 | Turnover: 1.6549 | TC: 0.001730 | Net:  0.04385
#
# [22/59] Date: 2021-10-31 | Year: 2021
#   Window: 2006-10-31 to 2021-09-30
#   Buy/Sell: 123 | Analyst: 260 | Union: 66 | Assets w/ data: 36
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.01720 | Turnover: 1.2698 | TC: 0.001248 | Net: -0.01845
#
# [23/59] Date: 2021-11-30 | Year: 2021
#   Window: 2006-11-30 to 2021-10-31
#   Buy/Sell: 123 | Analyst: 264 | Union: 62 | Assets w/ data: 36
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.05571 | Turnover: 1.0238 | TC: 0.001081 | Net:  0.05463
#
# [24/59] Date: 2021-12-31 | Year: 2021
#   Window: 2006-12-31 to 2021-11-30
#   Buy/Sell: 123 | Analyst: 209 | Union: 46 | Assets w/ data: 22
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.02624 | Turnover: 1.9523 | TC: 0.001901 | Net: -0.02814
#
# [25/59] Date: 2022-01-31 | Year: 2022
#   Window: 2007-01-31 to 2021-12-31
#   Buy/Sell: 34 | Analyst: 257 | Union: 18 | Assets w/ data: 14
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.02529 | Turnover: 1.7185 | TC: 0.001675 | Net: -0.02697
#
# [26/59] Date: 2022-02-28 | Year: 2022
#   Window: 2007-02-28 to 2022-01-31
#   Buy/Sell: 34 | Analyst: 166 | Union: 17 | Assets w/ data: 11
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.07329 | Turnover: 1.0213 | TC: 0.001096 | Net:  0.07220
#
# [27/59] Date: 2022-03-31 | Year: 2022
#   Window: 2007-03-31 to 2022-02-28
#   Buy/Sell: 34 | Analyst: 206 | Union: 13 | Assets w/ data: 6
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.04388 | Turnover: 0.7381 | TC: 0.000706 | Net: -0.04458
#
# [28/59] Date: 2022-04-30 | Year: 2022
#   Window: 2007-04-30 to 2022-03-31
#   Buy/Sell: 34 | Analyst: 211 | Union: 15 | Assets w/ data: 9
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.06399 | Turnover: 1.3096 | TC: 0.001393 | Net:  0.06260
#
# [29/59] Date: 2022-05-31 | Year: 2022
#   Window: 2007-05-31 to 2022-04-30
#   Buy/Sell: 34 | Analyst: 180 | Union: 15 | Assets w/ data: 10
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.05795 | Turnover: 0.8969 | TC: 0.000845 | Net: -0.05879
#
# [30/59] Date: 2022-06-30 | Year: 2022
#   Window: 2007-06-30 to 2022-05-31
#   Buy/Sell: 34 | Analyst: 164 | Union: 14 | Assets w/ data: 9
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.10868 | Turnover: 1.1494 | TC: 0.001274 | Net:  0.10740
#
# [31/59] Date: 2022-07-31 | Year: 2022
#   Window: 2007-07-31 to 2022-06-30
#   Buy/Sell: 34 | Analyst: 213 | Union: 17 | Assets w/ data: 10
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.04909 | Turnover: 1.6347 | TC: 0.001554 | Net: -0.05065
#
# [32/59] Date: 2022-08-31 | Year: 2022
#   Window: 2007-08-31 to 2022-07-31
#   Buy/Sell: 34 | Analyst: 165 | Union: 12 | Assets w/ data: 7
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.08393 | Turnover: 0.6649 | TC: 0.000609 | Net: -0.08454
#
# [33/59] Date: 2022-09-30 | Year: 2022
#   Window: 2007-09-30 to 2022-08-31
#   Buy/Sell: 34 | Analyst: 156 | Union: 8 | Assets w/ data: 6
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.12826 | Turnover: 1.4214 | TC: 0.001604 | Net:  0.12665
#
# [34/59] Date: 2022-10-31 | Year: 2022
#   Window: 2007-10-31 to 2022-09-30
#   Buy/Sell: 34 | Analyst: 223 | Union: 23 | Assets w/ data: 14
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.09247 | Turnover: 1.5252 | TC: 0.001666 | Net:  0.09080
#
# [35/59] Date: 2022-11-30 | Year: 2022
#   Window: 2007-11-30 to 2022-10-31
#   Buy/Sell: 34 | Analyst: 178 | Union: 9 | Assets w/ data: 8
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.03153 | Turnover: 0.6555 | TC: 0.000635 | Net: -0.03217
#
# [36/59] Date: 2022-12-31 | Year: 2022
#   Window: 2007-12-31 to 2022-11-30
#   Buy/Sell: 34 | Analyst: 205 | Union: 18 | Assets w/ data: 12
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02637 | Turnover: 1.3851 | TC: 0.001422 | Net:  0.02494
#
# [37/59] Date: 2023-01-31 | Year: 2023
#   Window: 2008-01-31 to 2022-12-31
#   Buy/Sell: 137 | Analyst: 266 | Union: 73 | Assets w/ data: 36
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.04105 | Turnover: 2.0097 | TC: 0.001927 | Net: -0.04298
#
# [38/59] Date: 2023-02-28 | Year: 2023
#   Window: 2008-02-29 to 2023-01-31
#   Buy/Sell: 137 | Analyst: 174 | Union: 49 | Assets w/ data: 16
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.05514 | Turnover: 0.8128 | TC: 0.000768 | Net: -0.05590
#
# [39/59] Date: 2023-03-31 | Year: 2023
#   Window: 2008-03-31 to 2023-02-28
#   Buy/Sell: 137 | Analyst: 207 | Union: 55 | Assets w/ data: 20
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02618 | Turnover: 1.7409 | TC: 0.001786 | Net:  0.02440
#
# [40/59] Date: 2023-04-30 | Year: 2023
#   Window: 2008-04-30 to 2023-03-31
#   Buy/Sell: 137 | Analyst: 198 | Union: 53 | Assets w/ data: 24
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.05778 | Turnover: 1.8696 | TC: 0.001762 | Net: -0.05954
#
# [41/59] Date: 2023-05-31 | Year: 2023
#   Window: 2008-05-31 to 2023-04-30
#   Buy/Sell: 137 | Analyst: 162 | Union: 43 | Assets w/ data: 19
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.07342 | Turnover: 2.1194 | TC: 0.002275 | Net:  0.07115
#
# [42/59] Date: 2023-06-30 | Year: 2023
#   Window: 2008-06-30 to 2023-05-31
#   Buy/Sell: 137 | Analyst: 166 | Union: 50 | Assets w/ data: 27
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02518 | Turnover: 1.3367 | TC: 0.001370 | Net:  0.02381
#
# [43/59] Date: 2023-07-31 | Year: 2023
#   Window: 2008-07-31 to 2023-06-30
#   Buy/Sell: 137 | Analyst: 187 | Union: 45 | Assets w/ data: 23
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.03985 | Turnover: 1.0956 | TC: 0.001052 | Net: -0.04091
#
# [44/59] Date: 2023-08-31 | Year: 2023
#   Window: 2008-08-31 to 2023-07-31
#   Buy/Sell: 137 | Analyst: 217 | Union: 55 | Assets w/ data: 23
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.06644 | Turnover: 1.2286 | TC: 0.001147 | Net: -0.06758
#
# [45/59] Date: 2023-09-30 | Year: 2023
#   Window: 2008-09-30 to 2023-08-31
#   Buy/Sell: 137 | Analyst: 190 | Union: 39 | Assets w/ data: 18
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.01995 | Turnover: 1.1406 | TC: 0.001118 | Net: -0.02106
#
# [46/59] Date: 2023-10-31 | Year: 2023
#   Window: 2008-10-31 to 2023-09-30
#   Buy/Sell: 137 | Analyst: 238 | Union: 57 | Assets w/ data: 27
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.07215 | Turnover: 1.4032 | TC: 0.001504 | Net:  0.07065
#
# [47/59] Date: 2023-11-30 | Year: 2023
#   Window: 2008-11-30 to 2023-10-31
#   Buy/Sell: 137 | Analyst: 197 | Union: 46 | Assets w/ data: 23
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03755 | Turnover: 1.2050 | TC: 0.001250 | Net:  0.03630
#
# [48/59] Date: 2023-12-31 | Year: 2023
#   Window: 2008-12-31 to 2023-11-30
#   Buy/Sell: 137 | Analyst: 233 | Union: 59 | Assets w/ data: 27
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.00465 | Turnover: 1.6028 | TC: 0.001595 | Net: -0.00624
#
# [49/59] Date: 2024-01-31 | Year: 2024
#   Window: 2009-01-31 to 2023-12-31
#   Buy/Sell: 281 | Analyst: 248 | Union: 122 | Assets w/ data: 71
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02373 | Turnover: 1.9405 | TC: 0.001987 | Net:  0.02174
#
# [50/59] Date: 2024-02-29 | Year: 2024
#   Window: 2009-02-28 to 2024-01-31
#   Buy/Sell: 281 | Analyst: 216 | Union: 113 | Assets w/ data: 62
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02680 | Turnover: 1.0266 | TC: 0.001054 | Net:  0.02575
#
# [51/59] Date: 2024-03-31 | Year: 2024
#   Window: 2009-03-31 to 2024-02-29
#   Buy/Sell: 281 | Analyst: 188 | Union: 92 | Assets w/ data: 58
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.04263 | Turnover: 1.1397 | TC: 0.001091 | Net: -0.04372
#
# [52/59] Date: 2024-04-30 | Year: 2024
#   Window: 2009-04-30 to 2024-03-31
#   Buy/Sell: 281 | Analyst: 222 | Union: 106 | Assets w/ data: 61
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02916 | Turnover: 1.3837 | TC: 0.001424 | Net:  0.02774
#
# [53/59] Date: 2024-05-31 | Year: 2024
#   Window: 2009-05-31 to 2024-04-30
#   Buy/Sell: 281 | Analyst: 185 | Union: 99 | Assets w/ data: 44
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.02262 | Turnover: 1.3276 | TC: 0.001298 | Net: -0.02392
#
# [54/59] Date: 2024-06-30 | Year: 2024
#   Window: 2009-06-30 to 2024-05-31
#   Buy/Sell: 281 | Analyst: 167 | Union: 85 | Assets w/ data: 45
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.05151 | Turnover: 1.4041 | TC: 0.001476 | Net:  0.05003
#
# [55/59] Date: 2024-07-31 | Year: 2024
#   Window: 2009-07-31 to 2024-06-30
#   Buy/Sell: 281 | Analyst: 275 | Union: 149 | Assets w/ data: 80
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02721 | Turnover: 1.3804 | TC: 0.001418 | Net:  0.02579
#
# [56/59] Date: 2024-08-31 | Year: 2024
#   Window: 2009-08-31 to 2024-07-31
#   Buy/Sell: 281 | Analyst: 185 | Union: 109 | Assets w/ data: 62
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02036 | Turnover: 1.2933 | TC: 0.001320 | Net:  0.01904
#
# [57/59] Date: 2024-09-30 | Year: 2024
#   Window: 2009-09-30 to 2024-08-31
#   Buy/Sell: 281 | Analyst: 206 | Union: 100 | Assets w/ data: 60
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.02471 | Turnover: 1.2080 | TC: 0.001178 | Net: -0.02589
#
# [58/59] Date: 2024-10-31 | Year: 2024
#   Window: 2009-10-31 to 2024-09-30
#   Buy/Sell: 281 | Analyst: 230 | Union: 116 | Assets w/ data: 66
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.04212 | Turnover: 1.1653 | TC: 0.001214 | Net:  0.04090
#
# [59/59] Date: 2024-11-30 | Year: 2024
#   Window: 2009-11-30 to 2024-10-31
#   Buy/Sell: 281 | Analyst: 170 | Union: 83 | Assets w/ data: 46
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.06639 | Turnover: 1.0283 | TC: 0.000960 | Net: -0.06735
#
# ============================================================
# BACKTEST COMPLETE
# ============================================================
#
# Sharpe Ratio: 0.1429
# Annualized Sharpe Ratio: 0.4950
# Total Return: 0.4467
# Average Turnover: 1.2953
