# %%
# if (bm > 0.72 AND mom12m > 0.78) OR mve > 1.15:
#     signal = BUY

# SELL RULE:
# if (bm < -0.68 AND mom12m < -0.68) OR (mve < -1.6 AND mom12m < 0.1):
#     signal = SELL

# %%
import pandas as pd
import numpy as np

green_cleaned = pd.read_csv('../green cleaned.csv', dtype={'ncusip': 'string'})
green_cleaned['ret_fwd_1'] = (green_cleaned.groupby('permno')['ret_excess'].shift(-1) )

# %%
variables = ['datadate', 'ticker', 'comnam', 'bm', 'mom12m', 'mve', 'ret_fwd_1']

# %%
start_date = '2019-12-31'
end_date = '2024-11-30'

target_date = '2019-12-31'

# 3. Create the filtered DataFrame for your analysis
# analysis_df = green_cleaned[
#     (green_cleaned['datadate'] >= start_date) & 
#     (green_cleaned['datadate'] <= end_date)
# ][variables].copy()

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == target_date)
][variables].copy()

conditions = [
    # BUY: bm > 0.75 AND mom12m > 0.35 AND mve > -0.5
    ( (analysis_df['bm'] > 0.72) & (analysis_df['mom12m'] > 0.78) ) | ((analysis_df['mve'] > 1.15) ),
    
    # SELL: bm < -0.5 AND mom12m < -0.75
    ( (analysis_df['bm'] < -0.68) & (analysis_df['mom12m'] < -0.68) ) | ( (analysis_df['mve'] < -1.6) & (analysis_df['mom12m'] < 0.1) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(analysis_df[analysis_df['signal'] == 'BUY'])

print("\n--- SELL ---")
print(analysis_df[analysis_df['signal'] == 'SELL'])
# Out:
# --- BUY ---
#           datadate ticker                            comnam        bm  \
# 777     2019-12-31   ORCL                       ORACLE CORP -0.792391
# 1144    2019-12-31   MSFT                    MICROSOFT CORP -0.850270
# 2146    2019-12-31    HON       HONEYWELL INTERNATIONAL INC -0.607406
# 5706    2019-12-31   FISV                        FISERV INC -0.941413
# 8747    2019-12-31     KO                      COCA COLA CO -0.927537
# 13250   2019-12-31    XOM                  EXXON MOBIL CORP  0.847430
# 15277   2019-12-31     GE               GENERAL ELECTRIC CO  0.254676
# 16970   2019-12-31   CHTR    CHARTER COMMUNICATIONS INC NEW  0.544940
# 18979   2019-12-31    IBM  INTERNATIONAL BUSINESS MACHS COR -0.677930
# 23510   2019-12-31    PSX                       PHILLIPS 66  0.735680
# 23643   2019-12-31     FB                      FACEBOOK INC -0.496401
# 24773   2019-12-31   ABBV                        ABBVIE INC -1.374426
# 25864   2019-12-31    PEP                       PEPSICO INC -0.899261
# 26404   2019-12-31     MO                  ALTRIA GROUP INC -0.695704
# 27449   2019-12-31   COTY                          COTY INC  1.374721
# 27793   2019-12-31   AMGN                         AMGEN INC -0.872555
# 30257   2019-12-31    CVX                  CHEVRON CORP NEW  1.100829
# 30920   2019-12-31   AAPL                         APPLE INC -0.879186
# 32297   2019-12-31    SYF               SYNCHRONY FINANCIAL  1.480040
# 35696   2019-12-31   PYPL               PAYPAL HOLDINGS INC -0.707656
# 36669   2019-12-31    TXN             TEXAS INSTRUMENTS INC -0.876502
# 42245   2019-12-31    CVS                 C V S HEALTH CORP  0.915990
# 46216   2019-12-31    UTX          UNITED TECHNOLOGIES CORP  0.098291
# 48593   2019-12-31     PG               PROCTER & GAMBLE CO -0.360100
# 51126   2019-12-31    CAT                   CATERPILLAR INC -0.597112
# 55848   2019-12-31    BMY           BRISTOL MYERS SQUIBB CO -0.678431
# 57346   2019-12-31     BA                         BOEING CO -1.179103
# 61172   2019-12-31    ABT               ABBOTT LABORATORIES -0.448898
# 64084   2019-12-31    LMT              LOCKHEED MARTIN CORP -1.126772
# 69021   2019-12-31    PFE                        PFIZER INC -0.407155
# 71109   2019-12-31    JNJ                 JOHNSON & JOHNSON -0.652364
# 73488   2019-12-31    MMM                             3M CO -0.911800
# 74448   2019-12-31    MRK                MERCK & CO INC NEW -0.772143
# 85714   2019-12-31    NEE                NEXTERA ENERGY INC  0.073277
# 88618   2019-12-31   ARNC                       ARCONIC INC  0.888443
# 99066   2019-12-31    DIS                    DISNEY WALT CO -0.326699
# 107122  2019-12-31    XRX               XEROX HOLDINGS CORP  2.192086
# 121825  2019-12-31    WFC              WELLS FARGO & CO NEW  1.345080
# 136347  2019-12-31    MCD                    MCDONALDS CORP -1.325427
# 140832  2019-12-31    JCI         JOHNSON CONTROLS INTL PLC  0.816452
# 148474  2019-12-31    JPM               JPMORGAN CHASE & CO  1.021354
# 152865  2019-12-31    UNP                UNION PACIFIC CORP -0.560957
# 158061  2019-12-31    LLY                    LILLY ELI & CO -0.926574
# 163026  2019-12-31    LEN                       LENNAR CORP  2.037168
# 166989  2019-12-31    PHM                   PULTE GROUP INC  0.863085
# 168434  2019-12-31    WMT                       WALMART INC -0.380075
# 172004  2019-12-31    NKE                          NIKE INC -0.955973
# 176075  2019-12-31    AXP               AMERICAN EXPRESS CO -0.339584
# 178176  2019-12-31   INTC                        INTEL CORP -0.107737
# 179062  2019-12-31    BAC              BANK OF AMERICA CORP  1.937569
# 181482  2019-12-31    MDT                     MEDTRONIC PLC  0.103115
# 186350  2019-12-31    LOW               LOWES COMPANIES INC -1.039941
# 188219  2019-12-31    TMO      THERMO FISHER SCIENTIFIC INC -0.246344
# 196788  2019-12-31     VZ        VERIZON COMMUNICATIONS INC -0.484416
# 198201  2019-12-31      T                       A T & T INC  1.527020
# 199000  2019-12-31    USB                   U S BANCORP DEL  0.691366
# 199442  2019-12-31     HD                    HOME DEPOT INC -1.213121
# 202301  2019-12-31     MS   MORGAN STANLEY DEAN WITTER & CO  2.073139
# 204701  2019-12-31      C                     CITIGROUP INC  3.228631
# 210652  2019-12-31   ADBE                         ADOBE INC -0.950521
# 213636  2019-12-31   CSCO                 CISCO SYSTEMS INC -0.506944
# 219452  2019-12-31   QCOM                      QUALCOMM INC -1.152417
# 219815  2019-12-31   GILD               GILEAD SCIENCES INC -0.368292
# 222937  2019-12-31   SBUX                    STARBUCKS CORP -1.136657
# 236445  2019-12-31    HIG   HARTFORD FINANCIAL SVCS GRP INC  1.263451
# 241125  2019-12-31   AMZN                    AMAZON COM INC -1.003994
# 246155  2019-12-31    AMT           AMERICAN TOWER CORP NEW -0.950642
# 248108  2019-12-31   NVDA                       NVIDIA CORP -0.856473
# 248535  2019-12-31   BKNG              BOOKING HOLDINGS INC -0.842600
# 248943  2019-12-31     GS           GOLDMAN SACHS GROUP INC  2.615211
# 250079  2019-12-31   COST         COSTCO WHOLESALE CORP NEW -0.801217
# 251845  2019-12-31    UPS         UNITED PARCEL SERVICE INC -1.074253
# 255357  2019-12-31    FIS   FIDELITY NATIONAL INFO SVCS INC -0.252235
# 257953  2019-12-31   NFLX                       NETFLIX INC -1.047534
# 258538  2019-12-31  CMCSA                  COMCAST CORP NEW  0.237802
# 259868  2019-12-31    AIZ                      ASSURANT INC  1.639912
# 260731  2019-12-31    CRM                SALESFORCE COM INC -0.776522
# 264583  2019-12-31     MA                    MASTERCARD INC -1.099807
# 267400  2019-12-31     PM   PHILIP MORRIS INTERNATIONAL INC -1.527340
# 267581  2019-12-31      V                          VISA INC -0.922001
# 268170  2019-12-31    UNH            UNITEDHEALTH GROUP INC -0.523031
#
#           mom12m       mve  ret_fwd_1 signal
# 777     0.141083  1.863881  -0.006774    BUY
# 1144    0.932007  1.863881   0.078155    BUY
# 2146    0.412806  1.691759  -0.022656    BUY
# 5706    1.089111  1.167411   0.024472    BUY
# 8747   -0.000303  1.863881   0.053804    BUY
# 13250  -1.043016  1.863881  -0.111074    BUY
# 15277   1.302918  1.407714   0.114291    BUY
# 16970   1.458320  1.435411   0.065452    BUY
# 18979   0.044096  1.616213   0.070992    BUY
# 23510   0.828633  0.687332  -0.181176    BUY
# 23643   1.189228  1.863881  -0.017573    BUY
# 24773  -0.987527  1.710116  -0.072906    BUY
# 25864   0.249305  1.863881   0.037845    BUY
# 26404  -1.074880  1.343800  -0.048986    BUY
# 27449   1.580116 -1.242711  -0.089300    BUY
# 27793  -0.268135  1.789297  -0.105087    BUY
# 30257  -0.459352  1.863881  -0.112245    BUY
# 30920   1.407099  1.863881   0.052710    BUY
# 32297   1.306066 -0.129557  -0.101272    BUY
# 35696   0.496275  1.685257   0.051580    BUY
# 36669   0.509754  1.552760  -0.053837    BUY
# 42245  -1.157170  1.402098  -0.081661    BUY
# 46216   0.430215  1.695632   0.001638    BUY
# 48593   1.143294  1.863881   0.002430    BUY
# 51126  -0.284878  1.180565  -0.104902    BUY
# 55848   0.016540  1.741241  -0.013607    BUY
# 57346  -0.506937  1.863881  -0.024293    BUY
# 61172   0.190970  1.863881   0.006068    BUY
# 64084   0.797043  1.532391   0.098192    BUY
# 69021  -1.170176  1.863881  -0.041116    BUY
# 71109  -0.868667  1.863881   0.019266    BUY
# 73488  -1.352565  1.398771  -0.101969    BUY
# 74448   0.074113  1.863881  -0.061883    BUY
# 85714   1.065799  1.571274   0.106232    BUY
# 88618   0.828800 -0.775259  -0.027949    BUY
# 99066   0.162349  1.863881  -0.044998    BUY
# 107122  0.925270 -1.284806  -0.036559    BUY
# 121825 -0.581048  1.863881  -0.128809    BUY
# 136347 -0.203750  1.842876   0.081489    BUY
# 140832  0.810512  0.212527  -0.032251    BUY
# 148474  0.232095  1.863881  -0.045346    BUY
# 152865 -0.055720  1.644338  -0.008878    BUY
# 158061 -0.599420  1.555699   0.061167    BUY
# 163026  1.356487 -0.534863   0.190401    BUY
# 166989  1.829943 -1.017327   0.149473    BUY
# 168434  0.556062  1.863881  -0.037904    BUY
# 172004  0.443271  1.592203  -0.050752    BUY
# 176075 -0.215682  1.406196   0.045370    BUY
# 178176  0.292301  1.863881   0.066871    BUY
# 179062  0.093352  1.863881  -0.069159    BUY
# 181482  0.160056  1.863881   0.016241    BUY
# 186350  0.462584  1.310858  -0.026100    BUY
# 188219  0.497248  1.677169  -0.037253    BUY
# 196788 -0.276315  1.863881  -0.023206    BUY
# 198201  0.943223  1.863881  -0.025353    BUY
# 199000 -0.123403  1.354508  -0.103678    BUY
# 199442  1.020087  1.863881   0.043210    BUY
# 202301 -0.177575  1.181960   0.027847    BUY
# 204701  0.129181  1.863881  -0.063511    BUY
# 210652  0.008791  1.863881   0.063374    BUY
# 213636 -0.399584  1.863881  -0.035495    BUY
# 219452  1.515900  1.373525  -0.034395    BUY
# 219815 -0.860539  1.248012  -0.028693    BUY
# 222937  0.827154  1.434805  -0.036446    BUY
# 236445  0.961230 -0.218123  -0.025819    BUY
# 241125 -0.253037  1.863881   0.085764    BUY
# 246155  1.132978  1.366632   0.007054    BUY
# 248108  0.590420  1.734386   0.003502    BUY
# 248535 -0.106433  1.176572  -0.109971    BUY
# 248943  0.137662  1.158315   0.032710    BUY
# 250079  0.884475  1.732772   0.038166    BUY
# 251845 -0.368449  1.232888  -0.116967    BUY
# 255357  0.596983  1.245932   0.031557    BUY
# 257953 -0.469153  1.776927   0.065208    BUY
# 258538  0.305895  1.863881  -0.036212    BUY
# 259868  0.982283 -1.332602  -0.005267    BUY
# 260731 -0.044956  1.815574   0.119642    BUY
# 264583  1.286408  1.863881   0.058146    BUY
# 267400 -0.495699  1.704123  -0.029388    BUY
# 267581  0.749781  1.863881   0.057614    BUY
# 268170 -0.906463  1.863881  -0.074536    BUY
#
# --- SELL ---
#           datadate ticker                         comnam        bm    mom12m  \
# 20587   2019-12-31    HCA           H C A HEALTHCARE INC -1.527340 -0.784558
# 27350   2019-12-31   NWSA                  NEWS CORP NEW  1.962701 -0.155304
# 63310   2019-12-31    AAL    AMERICAN AIRLINES GROUP INC -1.219753 -1.617358
# 105249  2019-12-31    HPQ                        H P INC -1.236709 -1.507295
# 113291  2019-12-31     HP          HELMERICH & PAYNE INC  0.605234 -2.116855
# 117822  2019-12-31    ROL                    ROLLINS INC -1.000325 -0.919211
# 143479  2019-12-31    CLX                      CLOROX CO -1.056374 -0.881271
# 154704  2019-12-31    HRB                BLOCK H & R INC -0.883099 -0.704524
# 161146  2019-12-31    RHI  ROBERT HALF INTERNATIONAL INC -0.706916 -0.761474
# 172500  2019-12-31    JWN                  NORDSTROM INC -0.819382 -1.869590
# 175570  2019-12-31    GPS                        GAP INC -0.053682 -2.228981
# 192239  2019-12-31     LB                   L BRANDS INC -1.527340 -2.629635
# 203179  2019-12-31    HOG            HARLEY DAVIDSON INC -0.187870 -0.672703
# 208286  2019-12-31   ABMD                    ABIOMED INC -0.962206 -2.228065
# 220899  2019-12-31      M                      MACYS INC  1.251344 -2.647209
# 234946  2019-12-31   NTAP                     NETAPP INC -0.993920 -1.138388
# 241808  2019-12-31     RL              RALPH LAUREN CORP -0.191169 -1.029724
# 242988  2019-12-31   CHRW      CH ROBINSON WORLDWIDE INC -0.761781 -1.236378
# 249290  2019-12-31   FFIV               F 5 NETWORKS INC -0.857049 -1.239778
# 252806  2019-12-31   MNST      MONSTER BEVERAGE CORP NEW -0.771682 -0.764800
# 253441  2019-12-31   ILMN                   ILLUMINA INC -0.923838 -1.065253
# 255194  2019-12-31    ADS     ALLIANCE DATA SYSTEMS CORP -0.293944 -2.647209
# 258331  2019-12-31    XEC              CIMAREX ENERGY CO  0.541973 -2.647209
# 265183  2019-12-31    HBI                HANESBRANDS INC -0.528696 -0.564002
# 267118  2019-12-31   ULTA                ULTA BEAUTY INC -0.858942 -1.493466
#
#              mve  ret_fwd_1 signal
# 20587   0.599110  -0.062257   SELL
# 27350  -1.853930  -0.038075   SELL
# 63310  -0.843861  -0.065456   SELL
# 105249  0.097938   0.036170   SELL
# 113291 -1.863906  -0.108718   SELL
# 117822 -0.920489   0.143151   SELL
# 143479 -0.416356   0.030158   SELL
# 154704 -1.863906  -0.013225   SELL
# 161146 -1.511527  -0.080160   SELL
# 172500 -1.669277  -0.100738   SELL
# 175570 -1.619328  -0.002855   SELL
# 192239 -1.793180   0.276846   SELL
# 203179 -1.728290  -0.103209   SELL
# 208286 -1.228725   0.090734   SELL
# 220899 -1.863906  -0.063065   SELL
# 234946 -0.741133  -0.135758   SELL
# 241808 -1.783206  -0.033035   SELL
# 242988 -1.053710  -0.077771   SELL
# 249290 -1.228752  -0.126828   SELL
# 252806  0.183113   0.046694   SELL
# 253441  0.601931  -0.126910   SELL
# 255194 -1.863906  -0.085168   SELL
# 258331 -1.863906  -0.165141   SELL
# 265183 -1.760429  -0.074701   SELL
# 267118 -0.775884   0.057047   SELL
