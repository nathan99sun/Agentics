# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Lasso
import warnings
warnings.filterwarnings('ignore')


def naive_nodewise_regression(Y_star, lambda_grid=None):
    """
    Implements Naive Nodewise Regression (Section 5.1.2).
    Uses GIC (Generalized Information Criterion) as in the paper.
    
    Parameters:
    -----------
    Y_star : np.ndarray, shape (n, p)
        Demeaned returns matrix (time x assets)
    lambda_grid : list or None
        Grid of lambda values to try. If None, creates default grid.
    
    Returns:
    --------
    Theta_hat : np.ndarray, shape (p, p)
        Estimated precision matrix
    """
    n, p = Y_star.shape

    # Initialize matrices
    Theta_hat = np.zeros((p, p))
    tau_squared = np.zeros(p)
    
    # Create lambda grid if not provided
    if lambda_grid is None:
        lambda_grid = np.logspace(-3, 1, 50)
    
    # For each asset j
    for j in range(p):
        # Step 1: Get y_j (target) and Y_{-j} (predictors)
        y_j = Y_star[:, j]
        Y_minus_j = np.delete(Y_star, j, axis=1)
        
        # Step 2-3: Estimate gamma_j using Lasso with GIC
        # GIC(λ) = log(σ²_λ) + |S_λ| * (log(p-1) / n) * log(log(n))
        best_gic = np.inf
        best_lambda = lambda_grid[0]
        best_gamma = None
        best_ssr = None
        
        for lam in lambda_grid:
            lasso = Lasso(alpha=2*lam, fit_intercept=False, max_iter=10000)
            lasso.fit(Y_minus_j, y_j)
            gamma_j = lasso.coef_
            
            # Compute SSR and number of non-zero coefficients
            residuals = y_j - Y_minus_j @ gamma_j
            ssr = np.sum(residuals ** 2)
            sigma_sq_lambda = ssr / n
            q_lambda = np.sum(gamma_j != 0)
            
            # Compute GIC
            if sigma_sq_lambda > 1e-10: # Check for non-zero variance
                # GIC formula from paper
                gic = np.log(sigma_sq_lambda) + q_lambda * (np.log(p - 1) / n) * np.log(np.log(n))
            else:
                gic = np.inf
            
            if gic < best_gic:
                best_gic = gic
                best_lambda = lam
                best_gamma = gamma_j.copy()
                best_ssr = ssr
        
        gamma_j_star = best_gamma
        

        tau_squared[j] = best_ssr / n + best_lambda * np.sum(np.abs(gamma_j_star))

        # [cite_start]Step 5: Form the j-th row of Theta_hat [cite: 579, 543-547]
        Theta_hat[j, j] = 1 / tau_squared[j]
        off_diag = -gamma_j_star / tau_squared[j]
        Theta_hat[j, :j] = off_diag[:j]
        Theta_hat[j, j+1:] = off_diag[j:]
    
    # Step 6: Symmetrize
    #Theta_hat_sym = (Theta_hat + Theta_hat.T) / 2
    
    return Theta_hat


def gmv_weights(Theta_hat, p):
    """
    Compute Global Minimum Variance (GMV) portfolio weights (Section 6.1).
    """
    ones_p = np.ones(p)
    
    # [cite_start]w* = (Θ 1_p) / (1_p' Θ 1_p) [cite: 818-819]
    numerator = Theta_hat @ ones_p
    denominator = ones_p @ Theta_hat @ ones_p
    
    w_star = numerator / denominator
    
    return w_star


def compute_portfolio_metrics(returns, weights):
    """
    Compute portfolio return, variance, and Sharpe ratio.
    """

    portfolio_returns = returns @ weights
    mean_return = np.mean(portfolio_returns)
    variance = np.var(portfolio_returns, ddof=1)
    sharpe_ratio = mean_return / np.sqrt(variance) if variance > 0 else 0
    
    return {
        'return': mean_return,
        'variance': variance,
        'sharpe_ratio': sharpe_ratio
    }


def backtest_nodewise_gmv(df, test_start_date='2000-01-31', test_end_date='2003-12-31',
                          lookback_window=180,
                          transaction_cost=0.001,
                          verbose=True): # <-- Added verbose parameter
    """
    Backtest Nodewise + GMV strategy with monthly rebalancing,
    180-month rolling window, and NaN filtering as per the paper.
    
    Parameters:
    -----------
    df : pd.DataFrame
        DataFrame with columns: permno, datadate, ret_fwd_1
    test_start_date : str
        First date for *out-of-sample* returns (format: 'YYYY-MM-DD')
    test_end_date : str
        Last date for *out-of-sample* returns (format: 'YYYY-MM-DD')
    lookback_window : int
        Number of months in rolling training window (default: 180)
    transaction_cost : float
        Proportional transaction cost (default: 0.005 = 50 bps)
    verbose : bool
        If True, prints detailed log at each time step.
    
    Returns:
    --------
    results_df : pd.DataFrame
        DataFrame with columns: date, portfolio_return, cumulative_return
    metrics : dict
        Overall performance metrics
    """
    # --- 1. Setup ---
    df = df.copy()
    if 'datadate' not in df.columns or 'permno' not in df.columns:
        raise ValueError("DataFrame must have 'datadate' and 'permno' columns")
    df['datadate'] = pd.to_datetime(df['datadate'])
    
    # Get unique dates and all assets
    all_dates = sorted(df['datadate'].unique())
    all_assets = sorted(df['permno'].unique())
    p_full = len(all_assets)
    
    # Convert test dates to datetime
    test_start_dt = pd.to_datetime(test_start_date)
    test_end_dt = pd.to_datetime(test_end_date)
    
    # Find date indices
    try:
        test_start_idx = all_dates.index(test_start_dt)
        test_end_idx = all_dates.index(test_end_dt)
    except ValueError as e:
        raise ValueError(f"Date not found in DataFrame: {e}")
    
    if test_start_idx < lookback_window:
        raise ValueError(f"Not enough data for lookback. Test start date {test_start_date} "
                         f"requires data back to {all_dates[test_start_idx - lookback_window]}, "
                         f"but only {test_start_idx} periods are available.")
    
    # Storage for results
    portfolio_returns = []
    portfolio_dates = []
    portfolio_weights = []
    portfolio_turnover= []
    
    # Initial weights (full universe, equal-weighted)
    prev_weights = np.ones(p_full) / p_full
    last_oos_returns = np.zeros(p_full)
    last_gross_return = 0.0
    
    # --- 2. Rolling Window Backtest ---
    if verbose:
        print("--- Starting Backtest ---")
        
    for t in range(test_start_idx, test_end_idx + 1):
        current_date = all_dates[t]
        
        # Define the 180-month (or lookback_window) in-sample period
        window_start_date = all_dates[t - lookback_window]
        window_end_date = all_dates[t - 1]
        
        # Get training data for this window
        train_data = df[(df['datadate'] >= window_start_date) & 
                        (df['datadate'] <= window_end_date)]
        
        # Pivot to get returns matrix (time x assets)
        returns_pivot = train_data.pivot(index='datadate', columns='permno', values='ret_fwd_1')
        
        # Reindex to ensure all dates are present (fills missing dates with NaNs)
        window_dates = all_dates[t - lookback_window : t]
        returns_pivot = returns_pivot.reindex(index=window_dates, columns=all_assets)
        
        # **Filter assets with any NaNs in this window**
        nan_assets = returns_pivot.columns[returns_pivot.isna().any()]
        filtered_pivot = returns_pivot.drop(columns=nan_assets)
        
        current_assets = filtered_pivot.columns.tolist()
        Y = filtered_pivot.values
        n_train, p_current = Y.shape
        
        new_weights = np.zeros(p_full) # Start with 0 weights for all assets

        if verbose:
            print("\n" + "="*50)
            print(f"Processing Date: {current_date.strftime('%Y-%m-%d')}")
            print(f"  In-Sample Window: {window_start_date.strftime('%Y-%m-%d')} to {window_end_date.strftime('%Y-%m-%d')}")
            print(f"  Asset Universe: {p_full} total, {p_current} with complete data in window")

        # Check for valid data panel
        if n_train < lookback_window or p_current < 2:
            if verbose:
                print(f"  Skipping estimation: insufficient data (n={n_train}, p={p_current}). Carrying forward weights.")
            new_weights = prev_weights 
        else:
            try:
                # Demean the returns
                Y_bar = Y.mean(axis=0)
                Y_star = Y - Y_bar
                
                if verbose: print(f"  Running Naive Nodewise for {p_current} assets...")
                Theta_hat = naive_nodewise_regression(Y_star)
                
                if verbose: print("  Calculating GMV weights...")
                w_star_filtered = gmv_weights(Theta_hat, p_current)
                
                # Map weights back to full asset universe
                new_weights_series = pd.Series(0.0, index=all_assets)
                new_weights_series.loc[current_assets] = w_star_filtered
                new_weights = new_weights_series.values
                
            except Exception as e:
                if verbose:
                    print(f"  Error at {current_date}: {e}. Carrying forward weights.")
                new_weights = prev_weights

        # Normalize weights to sum to 1
        weight_sum = np.sum(new_weights)
        if np.abs(weight_sum) > 1e-6:
            new_weights = new_weights / weight_sum
        else:
            if verbose: print("  Warning: Zero weight sum, carrying forward weights.")
            new_weights = prev_weights
        
        # --- 3. OOS Calculation & Transaction Costs ---
        
        # Get out-of-sample returns for current month (full universe)
        oos_data = df[df['datadate'] == current_date]
        oos_returns_pivot = oos_data.pivot(index='datadate', columns='permno', values='ret_fwd_1')
        oos_returns_pivot = oos_returns_pivot.reindex(columns=all_assets)
        oos_returns = oos_returns_pivot.values[0]
        valid = ~np.isnan(oos_returns)
        oos_returns = np.nan_to_num(oos_returns, nan=0.0)
        
        # Set weights of missing-return stocks to 0 and re-normalize
        new_weights = new_weights * valid
        if new_weights.sum() != 0:
            new_weights /= new_weights.sum()
                
        # Compute gross portfolio return (y_P,t+1)
        gross_return = new_weights @ oos_returns
        
        # Adjust previous weights (w_t,j+) as per paper
        adj_prev_weights = prev_weights * (1 + last_oos_returns) / (1 + last_gross_return)
        
        # Compute turnover and transaction costs
        turnover = np.sum(np.abs(new_weights - adj_prev_weights))
        tc = transaction_cost * (1 + gross_return) * turnover
        
        # Net return (after transaction costs)
        net_return = gross_return - tc
        
        # Store results
        portfolio_returns.append(net_return)
        portfolio_dates.append(current_date)
        w_temp = pd.Series(new_weights, index=all_assets)
        w_temp = w_temp[w_temp != 0]
        portfolio_weights.append(w_temp)
        portfolio_turnover.append(turnover)
        
        # Update "previous" variables for next loop
        prev_weights = new_weights.copy()
        last_oos_returns = oos_returns.copy()
        last_gross_return = gross_return
        
        if verbose:
            print(f"  Gross Return: {gross_return: .6f}")
            print(f"  Turnover:     {turnover: .6f}")
            print(f"  Trans. Cost:  {tc: .6f}")
            print(f"  Net Return:   {net_return: .6f}")
            
            print(portfolio_weights[-1])

    if verbose:
        print("="*50)
        print("--- Backtest Complete ---")
    
    # --- 4. Final Metrics ---
    results_df = pd.DataFrame({
        'date': portfolio_dates,
        'portfolio_return': portfolio_returns,
        'portfolio_weights': portfolio_weights,
        'portfolio_turnover': portfolio_turnover
    })
    results_df['cumulative_return'] = (1 + results_df['portfolio_return']).cumprod() - 1
    
    # Compute overall metrics
    mean_return = np.mean(portfolio_returns)
    variance = np.var(portfolio_returns, ddof=1)
    sharpe_ratio = mean_return / np.sqrt(variance) if variance > 0 else 0
    
    # Annualized metrics (monthly data)
    annual_return = mean_return * 12
    annual_volatility = np.sqrt(variance * 12)
    annual_sharpe = annual_return / annual_volatility if annual_volatility > 0 else 0
    
    metrics = {
        'mean_return': mean_return,
        'variance': variance,
        'sharpe_ratio': sharpe_ratio,
        'annual_return': annual_return,
        'annual_volatility': annual_volatility,
        'annual_sharpe_ratio': annual_sharpe,
        'total_return': results_df['cumulative_return'].iloc[-1] if len(results_df) > 0 else 0
    }
    
    return results_df, metrics

# %%
# Assuming you have loaded your dataframe as 'df'
df = pd.read_csv('../green cleaned.csv', dtype={'ncusip': 'string'})
df['ret_fwd_1'] = (df.groupby('permno')['ret_excess'].shift(-1) )

# %%
buys = pd.read_csv('buys.csv', index_col=1)
sells = pd.read_csv('sells.csv', index_col=1)
buys.index.name='permno'
sells.index.name='permno'

# %%
buys_index = buys.index.astype(int)
sells_index = sells.index.astype(int)

index = buys_index #.union(sells_index)
index
# Out:
# Index([11404, 12369, 12558, 14776, 15707, 24053, 26710, 27959, 28484, 34746,
#        47896, 52708, 57904, 59408, 59459, 60442, 66093, 66800, 69032, 70519,
#        71563, 78916, 79323, 81055, 82775, 85269, 86868, 87842, 89195],
#       dtype='int64', name='permno')

# %%
df_filtered = df[df['permno'].isin(index)]

# %%
df_filtered
# Out:
#           datadate  permno                         comnam    ncusip  shrcd  \
# 9178    1980-01-31   11404  CONSOLIDATED EDISON CO NY INC  20911110     11
# 9179    1980-02-29   11404  CONSOLIDATED EDISON CO NY INC  20911110     11
# 9180    1980-03-31   11404  CONSOLIDATED EDISON CO NY INC  20911110     11
# 9181    1980-04-30   11404  CONSOLIDATED EDISON CO NY INC  20911110     11
# 9182    1980-05-31   11404  CONSOLIDATED EDISON CO NY INC  20911110     11
# ...            ...     ...                            ...       ...    ...
# 257113  2024-08-31   89195  PRINCIPAL FINANCIAL GROUP INC  74251V10     11
# 257114  2024-09-30   89195  PRINCIPAL FINANCIAL GROUP INC  74251V10     11
# 257115  2024-10-31   89195  PRINCIPAL FINANCIAL GROUP INC  74251V10     11
# 257116  2024-11-30   89195  PRINCIPAL FINANCIAL GROUP INC  74251V10     11
# 257117  2024-12-31   89195  PRINCIPAL FINANCIAL GROUP INC  74251V10     11
#
#         exchcd  siccd industry ticker  gvkey_x  ...      BETA    betasq  \
# 9178         1   4932    Utils     ED     3413  ... -1.566032  0.223568
# 9179         1   4932    Utils     ED     3413  ... -1.660300  0.195325
# 9180         1   4932    Utils     ED     3413  ... -1.677291  0.182257
# 9181         1   4932    Utils     ED     3413  ... -1.751379  0.161145
# 9182         1   4932    Utils     ED     3413  ... -1.739403  0.137143
# ...        ...    ...      ...    ...      ...  ...       ...       ...
# 257113       3   6321    Money    PFG   145701  ...  0.498810  1.267343
# 257114       3   6321    Money    PFG   145701  ...  0.522321  1.285254
# 257115       3   6321    Money    PFG   145701  ...  0.597026  1.325183
# 257116       3   6321    Money    PFG   145701  ...  0.638789  1.362859
# 257117       3   6321    Money    PFG   145701  ...  0.712944  1.447813
#
#             rsq1  pricedelay   idiovol  year      mom6    indmom  \
# 9178    0.177811   -1.690356 -1.343182  1980       NaN  0.000000
# 9179    0.166120   -0.019633 -1.398064  1980       NaN  0.000000
# 9180    0.164222   -0.152879 -1.427993  1980       NaN  0.000000
# 9181    0.131506    0.849219 -1.362464  1980       NaN  0.000000
# 9182    0.126378    1.555308 -1.363175  1980       NaN  0.000000
# ...          ...         ...       ...   ...       ...       ...
# 257113  0.468943   -0.405290 -0.787679  2024  0.021091  1.093926
# 257114  0.465807   -0.071802 -0.771478  2024 -0.002934  1.438417
# 257115  0.483067   -0.030404 -0.810549  2024 -0.013883  0.950104
# 257116  0.505670    0.054618 -0.836565  2024  0.032738  0.975252
# 257117  0.515015    0.085128 -0.809136  2024  0.053421  1.134609
#
#         industry_return  ret_fwd_1
# 9178          -0.001083  -0.069674
# 9179          -0.040298  -0.006218
# 9180          -0.060439   0.127751
# 9181           0.108856   0.034772
# 9182           0.037701   0.034304
# ...                 ...        ...
# 257113         0.038455   0.059866
# 257114         0.004272  -0.044645
# 257115        -0.001965   0.052917
# 257116         0.081336  -0.106467
# 257117        -0.078148        NaN
#
# [9956 rows x 166 columns]

# %%
results_df, metrics = backtest_nodewise_gmv(
    df_filtered,
    test_start_date='2020-01-31',  # Last date of training period
    test_end_date='2024-11-30',   # Last date of testing period
    lookback_window=180,
    transaction_cost=0.001
)
print(f"Sharpe Ratio: {metrics['sharpe_ratio']:.4f}")
print(f"Annualized Sharpe Ratio: {metrics['annual_sharpe_ratio']:.4f}")
# Out:
# --- Starting Backtest ---
#
# ==================================================
# Processing Date: 2020-01-31
#   In-Sample Window: 2005-01-31 to 2019-12-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return: -0.103981
#   Turnover:      0.901052
#   Trans. Cost:   0.000807
#   Net Return:   -0.104788
# 11404    0.126851
# 26710    0.093014
# 27959    0.143376
# 28484    0.016323
# 34746    0.006899
# 47896    0.049573
# 57904    0.036617
# 59408    0.009008
# 59459    0.093313
# 60442    0.050682
# 66093    0.095159
# 66800   -0.000696
# 69032    0.017454
# 70519    0.011435
# 71563    0.036523
# 78916    0.039666
# 79323    0.059619
# 81055    0.023652
# 82775    0.005366
# 85269    0.012565
# 86868    0.030313
# 87842    0.039927
# 89195    0.003361
# dtype: float64
#
# ==================================================
# Processing Date: 2020-02-29
#   In-Sample Window: 2005-02-28 to 2020-01-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return: -0.182392
#   Turnover:      0.035262
#   Trans. Cost:   0.000029
#   Net Return:   -0.182421
# 11404    0.119740
# 26710    0.093368
# 27959    0.144482
# 28484    0.016904
# 34746    0.006840
# 47896    0.049711
# 57904    0.036478
# 59408    0.009048
# 59459    0.093590
# 60442    0.050396
# 66093    0.095925
# 66800   -0.000708
# 69032    0.017481
# 70519    0.011534
# 71563    0.036945
# 78916    0.040565
# 79323    0.060486
# 81055    0.024010
# 82775    0.005625
# 85269    0.013558
# 86868    0.030277
# 87842    0.040351
# 89195    0.003392
# dtype: float64
#
# ==================================================
# Processing Date: 2020-03-31
#   In-Sample Window: 2005-03-31 to 2020-02-29
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.085446
#   Turnover:      0.083230
#   Trans. Cost:   0.000090
#   Net Return:    0.085356
# 11404    0.125396
# 26710    0.091355
# 27959    0.143623
# 28484    0.015423
# 34746    0.006124
# 47896    0.049898
# 57904    0.037552
# 59408    0.009687
# 59459    0.094055
# 60442    0.050781
# 66093    0.093493
# 66800   -0.000767
# 69032    0.017439
# 70519    0.010713
# 71563    0.034364
# 78916    0.042254
# 79323    0.063104
# 81055    0.022732
# 82775    0.005548
# 85269    0.013148
# 86868    0.030494
# 87842    0.040273
# 89195    0.003312
# dtype: float64
#
# ==================================================
# Processing Date: 2020-04-30
#   In-Sample Window: 2005-04-30 to 2020-03-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.010496
#   Turnover:      0.136889
#   Trans. Cost:   0.000138
#   Net Return:    0.010357
# 11404    0.132411
# 26710    0.096256
# 27959    0.151287
# 28484    0.014131
# 34746    0.006042
# 47896    0.052796
# 57904    0.039933
# 59408    0.010242
# 59459    0.099577
# 60442    0.053432
# 66093    0.099063
# 66800   -0.000775
# 69032    0.018241
# 70519    0.010729
# 71563    0.035072
# 79323    0.065875
# 81055    0.021789
# 82775    0.006146
# 85269    0.012463
# 86868    0.031105
# 87842    0.041001
# 89195    0.003181
# dtype: float64
#
# ==================================================
# Processing Date: 2020-05-31
#   In-Sample Window: 2005-05-31 to 2020-04-30
#   Asset Universe: 29 total, 22 with complete data in window
#   Running Naive Nodewise for 22 assets...
#   Calculating GMV weights...
#   Gross Return: -0.012104
#   Turnover:      0.033079
#   Trans. Cost:   0.000033
#   Net Return:   -0.012136
# 11404    0.132424
# 26710    0.096146
# 27959    0.152419
# 28484    0.014146
# 34746    0.005997
# 47896    0.052662
# 57904    0.039758
# 59408    0.010212
# 59459    0.099282
# 60442    0.052992
# 66093    0.098903
# 66800   -0.000783
# 69032    0.018042
# 70519    0.010488
# 71563    0.034989
# 79323    0.065448
# 81055    0.021834
# 82775    0.006013
# 85269    0.012362
# 86868    0.031233
# 87842    0.042346
# 89195    0.003087
# dtype: float64
#
# ==================================================
# Processing Date: 2020-06-30
#   In-Sample Window: 2005-06-30 to 2020-05-31
#   Asset Universe: 29 total, 22 with complete data in window
#   Running Naive Nodewise for 22 assets...
#   Calculating GMV weights...
#   Gross Return:  0.027219
#   Turnover:      0.039484
#   Trans. Cost:   0.000041
#   Net Return:    0.027179
# 11404    0.132185
# 26710    0.096527
# 27959    0.152914
# 28484    0.014244
# 34746    0.006194
# 47896    0.052683
# 57904    0.039833
# 59408    0.010088
# 59459    0.099143
# 60442    0.052162
# 66093    0.098023
# 66800   -0.000825
# 69032    0.018073
# 70519    0.010465
# 71563    0.035234
# 79323    0.065679
# 81055    0.021795
# 82775    0.005961
# 85269    0.012594
# 86868    0.031362
# 87842    0.042453
# 89195    0.003212
# dtype: float64
#
# ==================================================
# Processing Date: 2020-07-31
#   In-Sample Window: 2005-07-31 to 2020-06-30
#   Asset Universe: 29 total, 22 with complete data in window
#   Running Naive Nodewise for 22 assets...
#   Calculating GMV weights...
#   Gross Return: -0.002203
#   Turnover:      0.034513
#   Trans. Cost:   0.000034
#   Net Return:   -0.002237
# 11404    0.130751
# 26710    0.096888
# 27959    0.151392
# 28484    0.014322
# 34746    0.006220
# 47896    0.052603
# 57904    0.039794
# 59408    0.010012
# 59459    0.101694
# 60442    0.052090
# 66093    0.098158
# 66800   -0.000824
# 69032    0.018040
# 70519    0.010325
# 71563    0.035368
# 79323    0.065196
# 81055    0.021792
# 82775    0.006083
# 85269    0.012558
# 86868    0.031451
# 87842    0.042954
# 89195    0.003135
# dtype: float64
#
# ==================================================
# Processing Date: 2020-08-31
#   In-Sample Window: 2005-08-31 to 2020-07-31
#   Asset Universe: 29 total, 22 with complete data in window
#   Running Naive Nodewise for 22 assets...
#   Calculating GMV weights...
#   Gross Return:  0.002075
#   Turnover:      0.032190
#   Trans. Cost:   0.000032
#   Net Return:    0.002043
# 11404    0.129090
# 26710    0.097331
# 27959    0.150251
# 28484    0.014251
# 34746    0.006211
# 47896    0.052801
# 57904    0.039885
# 59408    0.009987
# 59459    0.101796
# 60442    0.052002
# 66093    0.098161
# 66800   -0.000798
# 69032    0.017868
# 70519    0.010287
# 71563    0.035346
# 79323    0.065782
# 81055    0.022666
# 82775    0.006600
# 85269    0.013143
# 86868    0.031496
# 87842    0.042834
# 89195    0.003009
# dtype: float64
#
# ==================================================
# Processing Date: 2020-09-30
#   In-Sample Window: 2005-09-30 to 2020-08-31
#   Asset Universe: 29 total, 22 with complete data in window
#   Running Naive Nodewise for 22 assets...
#   Calculating GMV weights...
#   Gross Return:  0.012394
#   Turnover:      0.064943
#   Trans. Cost:   0.000066
#   Net Return:    0.012329
# 11404    0.127588
# 26710    0.098346
# 27959    0.146798
# 28484    0.014370
# 34746    0.006234
# 47896    0.053086
# 57904    0.040226
# 59408    0.010094
# 59459    0.102006
# 60442    0.052472
# 66093    0.099432
# 66800   -0.000772
# 69032    0.017834
# 70519    0.010051
# 71563    0.035581
# 79323    0.066253
# 81055    0.022792
# 82775    0.006608
# 85269    0.012862
# 86868    0.031970
# 87842    0.043143
# 89195    0.003024
# dtype: float64
#
# ==================================================
# Processing Date: 2020-10-31
#   In-Sample Window: 2005-10-31 to 2020-09-30
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.125523
#   Turnover:      0.052726
#   Trans. Cost:   0.000059
#   Net Return:    0.125464
# 11404    0.127281
# 26710    0.096688
# 27959    0.148812
# 28484    0.014086
# 34746    0.006170
# 47896    0.052803
# 52708    0.014193
# 57904    0.039251
# 59408    0.009964
# 59459    0.097629
# 60442    0.051666
# 66093    0.097453
# 66800   -0.000771
# 69032    0.017597
# 70519    0.009883
# 71563    0.034798
# 79323    0.065050
# 81055    0.022182
# 82775    0.006581
# 85269    0.011992
# 86868    0.031198
# 87842    0.042492
# 89195    0.003002
# dtype: float64
#
# ==================================================
# Processing Date: 2020-11-30
#   In-Sample Window: 2005-11-30 to 2020-10-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.037944
#   Turnover:      0.110452
#   Trans. Cost:   0.000115
#   Net Return:    0.037830
# 11404    0.129598
# 26710    0.093425
# 27959    0.151875
# 28484    0.013979
# 34746    0.006707
# 47896    0.052381
# 52708    0.014592
# 57904    0.037156
# 59408    0.010294
# 59459    0.099380
# 60442    0.050031
# 66093    0.099277
# 66800   -0.000641
# 69032    0.016778
# 70519    0.008061
# 71563    0.035382
# 79323    0.065293
# 81055    0.020915
# 82775    0.009582
# 85269    0.010587
# 86868    0.031115
# 87842    0.042060
# 89195    0.002173
# dtype: float64
#
# ==================================================
# Processing Date: 2020-12-31
#   In-Sample Window: 2005-12-31 to 2020-11-30
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.002971
#   Turnover:      0.054082
#   Trans. Cost:   0.000054
#   Net Return:    0.002917
# 11404    0.129174
# 26710    0.093496
# 27959    0.152695
# 28484    0.013827
# 34746    0.006900
# 47896    0.052652
# 52708    0.014776
# 57904    0.037434
# 59408    0.010393
# 59459    0.099349
# 60442    0.050249
# 66093    0.100039
# 66800   -0.000574
# 69032    0.016797
# 70519    0.007798
# 71563    0.035628
# 79323    0.065577
# 81055    0.020804
# 82775    0.006894
# 85269    0.010715
# 86868    0.030681
# 87842    0.042412
# 89195    0.002283
# dtype: float64
#
# ==================================================
# Processing Date: 2021-01-31
#   In-Sample Window: 2006-01-31 to 2020-12-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.046925
#   Turnover:      0.021049
#   Trans. Cost:   0.000022
#   Net Return:    0.046903
# 11404    0.128667
# 26710    0.093605
# 27959    0.152448
# 28484    0.014183
# 34746    0.006928
# 47896    0.052532
# 52708    0.014677
# 57904    0.037344
# 59408    0.010389
# 59459    0.098914
# 60442    0.050291
# 66093    0.100515
# 66800   -0.000581
# 69032    0.016782
# 70519    0.007794
# 71563    0.035619
# 79323    0.065533
# 81055    0.020715
# 82775    0.006939
# 85269    0.011082
# 86868    0.030974
# 87842    0.042356
# 89195    0.002295
# dtype: float64
#
# ==================================================
# Processing Date: 2021-02-28
#   In-Sample Window: 2006-02-28 to 2021-01-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.082962
#   Turnover:      0.090127
#   Trans. Cost:   0.000098
#   Net Return:    0.082865
# 11404    0.128292
# 26710    0.095483
# 27959    0.150033
# 28484    0.014207
# 34746    0.006641
# 47896    0.052203
# 52708    0.015295
# 57904    0.037728
# 59408    0.010248
# 59459    0.100371
# 60442    0.050036
# 66093    0.101781
# 66800   -0.000619
# 69032    0.016948
# 70519    0.007979
# 71563    0.034654
# 79323    0.066047
# 81055    0.020628
# 82775    0.006834
# 85269    0.009841
# 86868    0.030355
# 87842    0.040671
# 89195    0.004345
# dtype: float64
#
# ==================================================
# Processing Date: 2021-03-31
#   In-Sample Window: 2006-03-31 to 2021-02-28
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.052947
#   Turnover:      0.056719
#   Trans. Cost:   0.000060
#   Net Return:    0.052888
# 11404    0.125238
# 26710    0.098644
# 27959    0.145374
# 28484    0.014266
# 34746    0.006606
# 47896    0.052874
# 52708    0.015107
# 57904    0.038265
# 59408    0.010370
# 59459    0.102015
# 60442    0.051091
# 66093    0.102026
# 66800   -0.000585
# 69032    0.017136
# 70519    0.007967
# 71563    0.035143
# 79323    0.067238
# 81055    0.021220
# 82775    0.005573
# 85269    0.010135
# 86868    0.031111
# 87842    0.041360
# 89195    0.001826
# dtype: float64
#
# ==================================================
# Processing Date: 2021-04-30
#   In-Sample Window: 2006-04-30 to 2021-03-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.029077
#   Turnover:      0.026973
#   Trans. Cost:   0.000028
#   Net Return:    0.029049
# 11404    0.125448
# 26710    0.097291
# 27959    0.145282
# 28484    0.014269
# 34746    0.006593
# 47896    0.053416
# 52708    0.014936
# 57904    0.038367
# 59408    0.010551
# 59459    0.102470
# 60442    0.051149
# 66093    0.101980
# 66800   -0.000666
# 69032    0.017129
# 70519    0.008192
# 71563    0.035597
# 79323    0.066366
# 81055    0.020966
# 82775    0.006150
# 85269    0.010207
# 86868    0.031107
# 87842    0.041512
# 89195    0.001688
# dtype: float64
#
# ==================================================
# Processing Date: 2021-05-31
#   In-Sample Window: 2006-05-31 to 2021-04-30
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return: -0.042665
#   Turnover:      0.032546
#   Trans. Cost:   0.000031
#   Net Return:   -0.042696
# 11404    0.125410
# 26710    0.097418
# 27959    0.145473
# 28484    0.014057
# 34746    0.006670
# 47896    0.053770
# 52708    0.015315
# 57904    0.038261
# 59408    0.010572
# 59459    0.102257
# 60442    0.051192
# 66093    0.100585
# 66800   -0.000617
# 69032    0.017077
# 70519    0.007923
# 71563    0.035592
# 79323    0.065739
# 81055    0.022408
# 82775    0.006414
# 85269    0.010286
# 86868    0.031095
# 87842    0.041506
# 89195    0.001600
# dtype: float64
#
# ==================================================
# Processing Date: 2021-06-30
#   In-Sample Window: 2006-06-30 to 2021-05-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.003611
#   Turnover:      0.022990
#   Trans. Cost:   0.000023
#   Net Return:    0.003588
# 11404    0.124008
# 26710    0.097602
# 27959    0.146327
# 28484    0.014110
# 34746    0.006612
# 47896    0.053843
# 52708    0.015520
# 57904    0.038356
# 59408    0.010708
# 59459    0.102042
# 60442    0.051481
# 66093    0.101696
# 66800   -0.000615
# 69032    0.017207
# 70519    0.007758
# 71563    0.035279
# 79323    0.065940
# 81055    0.021058
# 82775    0.006463
# 85269    0.010294
# 86868    0.031247
# 87842    0.041383
# 89195    0.001679
# dtype: float64
#
# ==================================================
# Processing Date: 2021-07-31
#   In-Sample Window: 2006-07-31 to 2021-06-30
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.036467
#   Turnover:      0.035628
#   Trans. Cost:   0.000037
#   Net Return:    0.036430
# 11404    0.123984
# 26710    0.097614
# 27959    0.144482
# 28484    0.013946
# 34746    0.006499
# 47896    0.054329
# 52708    0.015482
# 57904    0.038357
# 59408    0.010835
# 59459    0.101647
# 60442    0.051172
# 66093    0.102682
# 66800   -0.000591
# 69032    0.017172
# 70519    0.007784
# 71563    0.035152
# 79323    0.065795
# 81055    0.020792
# 82775    0.006451
# 85269    0.010078
# 86868    0.031023
# 87842    0.041135
# 89195    0.004182
# dtype: float64
#
# ==================================================
# Processing Date: 2021-08-31
#   In-Sample Window: 2006-08-31 to 2021-07-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return: -0.030254
#   Turnover:      0.027328
#   Trans. Cost:   0.000027
#   Net Return:   -0.030280
# 11404    0.123828
# 26710    0.097760
# 27959    0.144570
# 28484    0.014134
# 34746    0.006459
# 47896    0.054323
# 52708    0.015485
# 57904    0.038364
# 59408    0.010799
# 59459    0.101838
# 60442    0.051199
# 66093    0.102852
# 66800   -0.001200
# 69032    0.017091
# 70519    0.007760
# 71563    0.035094
# 79323    0.065791
# 81055    0.021026
# 82775    0.006475
# 85269    0.010173
# 86868    0.030931
# 87842    0.041087
# 89195    0.004161
# dtype: float64
#
# ==================================================
# Processing Date: 2021-09-30
#   In-Sample Window: 2006-09-30 to 2021-08-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.033299
#   Turnover:      0.034401
#   Trans. Cost:   0.000036
#   Net Return:    0.033263
# 11404    0.123637
# 26710    0.097789
# 27959    0.142586
# 28484    0.014142
# 34746    0.006397
# 47896    0.054475
# 52708    0.017069
# 57904    0.038060
# 59408    0.010867
# 59459    0.102409
# 60442    0.051390
# 66093    0.103463
# 66800   -0.000612
# 69032    0.017192
# 70519    0.007823
# 71563    0.035215
# 79323    0.065984
# 81055    0.021173
# 82775    0.006659
# 85269    0.010233
# 86868    0.031260
# 87842    0.041242
# 89195    0.001547
# dtype: float64
#
# ==================================================
# Processing Date: 2021-10-31
#   In-Sample Window: 2006-10-31 to 2021-09-30
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return: -0.051460
#   Turnover:      0.031132
#   Trans. Cost:   0.000030
#   Net Return:   -0.051489
# 11404    0.123977
# 26710    0.097809
# 27959    0.142829
# 28484    0.014162
# 34746    0.006356
# 47896    0.054548
# 52708    0.015413
# 57904    0.038242
# 59408    0.010521
# 59459    0.103552
# 60442    0.051218
# 66093    0.103716
# 66800   -0.000633
# 69032    0.017188
# 70519    0.007752
# 71563    0.034917
# 79323    0.066006
# 81055    0.021209
# 82775    0.006719
# 85269    0.010193
# 86868    0.031513
# 87842    0.041351
# 89195    0.001440
# dtype: float64
#
# ==================================================
# Processing Date: 2021-11-30
#   In-Sample Window: 2006-11-30 to 2021-10-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.062997
#   Turnover:      0.036100
#   Trans. Cost:   0.000038
#   Net Return:    0.062959
# 11404    0.124294
# 26710    0.098139
# 27959    0.142667
# 28484    0.014410
# 34746    0.006452
# 47896    0.054701
# 52708    0.015725
# 57904    0.038525
# 59408    0.010479
# 59459    0.102357
# 60442    0.051108
# 66093    0.102411
# 66800   -0.000667
# 69032    0.017212
# 70519    0.007754
# 71563    0.034997
# 79323    0.065050
# 81055    0.021158
# 82775    0.006179
# 85269    0.009999
# 86868    0.031507
# 87842    0.041410
# 89195    0.004132
# dtype: float64
#
# ==================================================
# Processing Date: 2021-12-31
#   In-Sample Window: 2006-12-31 to 2021-11-30
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.028493
#   Turnover:      0.032539
#   Trans. Cost:   0.000033
#   Net Return:    0.028459
# 11404    0.122757
# 26710    0.097473
# 27959    0.142150
# 28484    0.014535
# 34746    0.006579
# 47896    0.055218
# 52708    0.015764
# 57904    0.038659
# 59408    0.010656
# 59459    0.102350
# 60442    0.051577
# 66093    0.102591
# 66800   -0.001263
# 69032    0.017419
# 70519    0.007932
# 71563    0.035303
# 79323    0.065011
# 81055    0.021422
# 82775    0.006333
# 85269    0.009972
# 86868    0.031799
# 87842    0.041599
# 89195    0.004165
# dtype: float64
#
# ==================================================
# Processing Date: 2022-01-31
#   In-Sample Window: 2007-01-31 to 2021-12-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return: -0.011391
#   Turnover:      0.034963
#   Trans. Cost:   0.000035
#   Net Return:   -0.011425
# 11404    0.122313
# 26710    0.097458
# 27959    0.141861
# 28484    0.015390
# 34746    0.006571
# 47896    0.054523
# 52708    0.016949
# 57904    0.038337
# 59408    0.010537
# 59459    0.102461
# 60442    0.051382
# 66093    0.102415
# 66800   -0.001244
# 69032    0.017305
# 70519    0.007631
# 71563    0.035243
# 79323    0.065907
# 81055    0.021482
# 82775    0.006321
# 85269    0.009928
# 86868    0.031651
# 87842    0.041337
# 89195    0.004241
# dtype: float64
#
# ==================================================
# Processing Date: 2022-02-28
#   In-Sample Window: 2007-02-28 to 2022-01-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.039358
#   Turnover:      0.034569
#   Trans. Cost:   0.000036
#   Net Return:    0.039322
# 11404    0.122766
# 26710    0.097494
# 27959    0.141635
# 28484    0.014386
# 34746    0.006628
# 47896    0.054603
# 52708    0.017113
# 57904    0.038466
# 59408    0.010518
# 59459    0.102622
# 60442    0.051410
# 66093    0.101546
# 66800   -0.001229
# 69032    0.017272
# 70519    0.007794
# 71563    0.035359
# 79323    0.066069
# 81055    0.021734
# 82775    0.006344
# 85269    0.009956
# 86868    0.031796
# 87842    0.041461
# 89195    0.004256
# dtype: float64
#
# ==================================================
# Processing Date: 2022-03-31
#   In-Sample Window: 2007-03-31 to 2022-02-28
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return: -0.045720
#   Turnover:      0.069323
#   Trans. Cost:   0.000066
#   Net Return:   -0.045786
# 11404    0.121631
# 26710    0.098025
# 27959    0.138786
# 28484    0.014527
# 34746    0.006698
# 47896    0.055288
# 52708    0.017367
# 57904    0.038833
# 59408    0.010646
# 59459    0.102665
# 60442    0.051669
# 66093    0.103478
# 66800   -0.001226
# 69032    0.017448
# 70519    0.007845
# 71563    0.035612
# 79323    0.064871
# 81055    0.021419
# 82775    0.006442
# 85269    0.009835
# 86868    0.032114
# 87842    0.041736
# 89195    0.004290
# dtype: float64
#
# ==================================================
# Processing Date: 2022-04-30
#   In-Sample Window: 2007-04-30 to 2022-03-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.067087
#   Turnover:      0.040998
#   Trans. Cost:   0.000044
#   Net Return:    0.067044
# 11404    0.122088
# 26710    0.098657
# 27959    0.139383
# 28484    0.014477
# 34746    0.006585
# 47896    0.055200
# 52708    0.017424
# 57904    0.038765
# 59408    0.010183
# 59459    0.102397
# 60442    0.051615
# 66093    0.103367
# 66800   -0.001234
# 69032    0.017499
# 70519    0.007953
# 71563    0.034764
# 79323    0.064458
# 81055    0.021544
# 82775    0.006603
# 85269    0.010040
# 86868    0.032173
# 87842    0.041834
# 89195    0.004226
# dtype: float64
#
# ==================================================
# Processing Date: 2022-05-31
#   In-Sample Window: 2007-05-31 to 2022-04-30
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return: -0.073306
#   Turnover:      0.034874
#   Trans. Cost:   0.000032
#   Net Return:   -0.073338
# 11404    0.121607
# 26710    0.100227
# 27959    0.140539
# 28484    0.014233
# 34746    0.006573
# 47896    0.054656
# 52708    0.017520
# 57904    0.038889
# 59408    0.010380
# 59459    0.102542
# 60442    0.051750
# 66093    0.101372
# 66800   -0.001210
# 69032    0.017513
# 70519    0.007702
# 71563    0.034844
# 79323    0.064235
# 81055    0.021707
# 82775    0.006659
# 85269    0.009940
# 86868    0.032118
# 87842    0.042050
# 89195    0.004153
# dtype: float64
#
# ==================================================
# Processing Date: 2022-06-30
#   In-Sample Window: 2007-06-30 to 2022-05-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.009039
#   Turnover:      0.029664
#   Trans. Cost:   0.000030
#   Net Return:    0.009009
# 11404    0.123439
# 26710    0.099235
# 27959    0.141876
# 28484    0.014115
# 34746    0.006648
# 47896    0.054064
# 52708    0.017883
# 57904    0.038725
# 59408    0.010011
# 59459    0.102344
# 60442    0.051473
# 66093    0.101556
# 66800   -0.001209
# 69032    0.017310
# 70519    0.007772
# 71563    0.035135
# 79323    0.064124
# 81055    0.020598
# 82775    0.006588
# 85269    0.009623
# 86868    0.032245
# 87842    0.042223
# 89195    0.004222
# dtype: float64
#
# ==================================================
# Processing Date: 2022-07-31
#   In-Sample Window: 2007-07-31 to 2022-06-30
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return: -0.015483
#   Turnover:      0.048064
#   Trans. Cost:   0.000047
#   Net Return:   -0.015530
# 11404    0.123183
# 26710    0.099492
# 27959    0.143968
# 28484    0.013874
# 34746    0.006735
# 47896    0.054586
# 52708    0.017687
# 57904    0.038540
# 59408    0.009836
# 59459    0.100991
# 60442    0.051368
# 66093    0.099754
# 66800   -0.001181
# 69032    0.017114
# 70519    0.007705
# 71563    0.035195
# 79323    0.065087
# 81055    0.020830
# 82775    0.006687
# 85269    0.009775
# 86868    0.032380
# 87842    0.042202
# 89195    0.004191
# dtype: float64
#
# ==================================================
# Processing Date: 2022-08-31
#   In-Sample Window: 2007-08-31 to 2022-07-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return: -0.088297
#   Turnover:      0.031402
#   Trans. Cost:   0.000029
#   Net Return:   -0.088326
# 11404    0.124250
# 26710    0.098918
# 27959    0.146562
# 28484    0.013901
# 34746    0.006763
# 47896    0.054699
# 52708    0.016258
# 57904    0.038634
# 59408    0.009888
# 59459    0.101300
# 60442    0.051428
# 66093    0.098892
# 66800   -0.001179
# 69032    0.017154
# 70519    0.007674
# 71563    0.035195
# 79323    0.065367
# 81055    0.021021
# 82775    0.006630
# 85269    0.009809
# 86868    0.032693
# 87842    0.042629
# 89195    0.001515
# dtype: float64
#
# ==================================================
# Processing Date: 2022-09-30
#   In-Sample Window: 2007-09-30 to 2022-08-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.112849
#   Turnover:      0.028480
#   Trans. Cost:   0.000032
#   Net Return:    0.112818
# 11404    0.120786
# 26710    0.098833
# 27959    0.140668
# 28484    0.015340
# 34746    0.007049
# 47896    0.055276
# 52708    0.017209
# 57904    0.039149
# 59408    0.010022
# 59459    0.102430
# 60442    0.052293
# 66093    0.097810
# 66800   -0.001178
# 69032    0.017070
# 70519    0.007499
# 71563    0.035579
# 79323    0.066204
# 81055    0.020793
# 82775    0.006814
# 85269    0.009812
# 86868    0.035331
# 87842    0.043453
# 89195    0.001759
# dtype: float64
#
# ==================================================
# Processing Date: 2022-10-31
#   In-Sample Window: 2007-10-31 to 2022-09-30
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.065960
#   Turnover:      0.096159
#   Trans. Cost:   0.000103
#   Net Return:    0.065857
# 11404    0.123267
# 26710    0.098615
# 27959    0.143700
# 28484    0.013683
# 34746    0.007158
# 47896    0.054309
# 52708    0.017582
# 57904    0.039918
# 59408    0.009301
# 59459    0.097851
# 60442    0.053967
# 66093    0.093229
# 66800   -0.001226
# 69032    0.017713
# 70519    0.008240
# 71563    0.036503
# 79323    0.068866
# 81055    0.020696
# 82775    0.006882
# 85269    0.009957
# 86868    0.035350
# 87842    0.042931
# 89195    0.001509
# dtype: float64
#
# ==================================================
# Processing Date: 2022-11-30
#   In-Sample Window: 2007-11-30 to 2022-10-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return: -0.026621
#   Turnover:      0.039118
#   Trans. Cost:   0.000038
#   Net Return:   -0.026659
# 11404    0.120100
# 26710    0.098839
# 27959    0.142309
# 28484    0.013701
# 34746    0.007181
# 47896    0.053663
# 52708    0.018779
# 57904    0.039502
# 59408    0.009354
# 59459    0.098151
# 60442    0.054230
# 66093    0.094476
# 66800   -0.001269
# 69032    0.018587
# 70519    0.008970
# 71563    0.036359
# 79323    0.068794
# 81055    0.022018
# 82775    0.006780
# 85269    0.010031
# 86868    0.034920
# 87842    0.042953
# 89195    0.001572
# dtype: float64
#
# ==================================================
# Processing Date: 2022-12-31
#   In-Sample Window: 2007-12-31 to 2022-11-30
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.042346
#   Turnover:      0.037923
#   Trans. Cost:   0.000040
#   Net Return:    0.042307
# 11404    0.119204
# 26710    0.098987
# 27959    0.141634
# 28484    0.014622
# 34746    0.007341
# 47896    0.053519
# 52708    0.018310
# 57904    0.039355
# 59408    0.009145
# 59459    0.097786
# 60442    0.054403
# 66093    0.094289
# 66800   -0.001298
# 69032    0.018380
# 70519    0.009073
# 71563    0.036746
# 79323    0.068586
# 81055    0.021893
# 82775    0.006700
# 85269    0.009954
# 86868    0.034442
# 87842    0.042901
# 89195    0.004028
# dtype: float64
#
# ==================================================
# Processing Date: 2023-01-31
#   In-Sample Window: 2008-01-31 to 2022-12-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return: -0.042091
#   Turnover:      0.055504
#   Trans. Cost:   0.000053
#   Net Return:   -0.042144
# 11404    0.122092
# 26710    0.098828
# 27959    0.143111
# 28484    0.014544
# 34746    0.007439
# 47896    0.053873
# 52708    0.018784
# 57904    0.039080
# 59408    0.009346
# 59459    0.099598
# 60442    0.053876
# 66093    0.091848
# 66800   -0.001239
# 69032    0.017853
# 70519    0.008405
# 71563    0.038045
# 79323    0.067335
# 81055    0.023116
# 82775    0.006507
# 85269    0.010020
# 86868    0.034138
# 87842    0.042345
# 89195    0.001057
# dtype: float64
#
# ==================================================
# Processing Date: 2023-02-28
#   In-Sample Window: 2008-02-29 to 2023-01-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return: -0.056701
#   Turnover:      0.023612
#   Trans. Cost:   0.000022
#   Net Return:   -0.056723
# 11404    0.121376
# 26710    0.099873
# 27959    0.141259
# 28484    0.014149
# 34746    0.007652
# 47896    0.055216
# 52708    0.018759
# 57904    0.038701
# 59408    0.009145
# 59459    0.099014
# 60442    0.053418
# 66093    0.092376
# 66800   -0.001246
# 69032    0.018173
# 70519    0.008659
# 71563    0.038512
# 79323    0.067102
# 81055    0.023158
# 82775    0.006612
# 85269    0.009971
# 86868    0.034860
# 87842    0.042273
# 89195    0.000989
# dtype: float64
#
# ==================================================
# Processing Date: 2023-03-31
#   In-Sample Window: 2008-03-31 to 2023-02-28
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.018800
#   Turnover:      0.066181
#   Trans. Cost:   0.000067
#   Net Return:    0.018733
# 11404    0.121753
# 26710    0.100712
# 27959    0.142293
# 28484    0.014200
# 34746    0.006378
# 47896    0.055629
# 52708    0.020737
# 57904    0.039168
# 59408    0.008978
# 59459    0.098979
# 60442    0.052617
# 66093    0.094857
# 66800   -0.001277
# 69032    0.018188
# 70519    0.008974
# 71563    0.035491
# 79323    0.066001
# 81055    0.022551
# 82775    0.006814
# 85269    0.010416
# 86868    0.035111
# 87842    0.040916
# 89195    0.000514
# dtype: float64
#
# ==================================================
# Processing Date: 2023-04-30
#   In-Sample Window: 2008-04-30 to 2023-03-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return: -0.070761
#   Turnover:      0.032463
#   Trans. Cost:   0.000030
#   Net Return:   -0.070791
# 11404    0.121986
# 26710    0.100687
# 27959    0.142222
# 28484    0.014640
# 34746    0.006359
# 47896    0.056600
# 52708    0.019523
# 57904    0.038842
# 59408    0.008640
# 59459    0.098718
# 60442    0.052616
# 66093    0.093602
# 66800   -0.001296
# 69032    0.018082
# 70519    0.009833
# 71563    0.035660
# 79323    0.066232
# 81055    0.022582
# 82775    0.006730
# 85269    0.010253
# 86868    0.036407
# 87842    0.040611
# 89195    0.000469
# dtype: float64
#
# ==================================================
# Processing Date: 2023-05-31
#   In-Sample Window: 2008-05-31 to 2023-04-30
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.031296
#   Turnover:      0.034024
#   Trans. Cost:   0.000035
#   Net Return:    0.031261
# 11404    0.120572
# 26710    0.110732
# 27959    0.138005
# 28484    0.017341
# 34746    0.006102
# 47896    0.057096
# 52708    0.020750
# 57904    0.038600
# 59408    0.008574
# 59459    0.097177
# 60442    0.051660
# 66093    0.091192
# 66800   -0.001261
# 69032    0.017945
# 70519    0.009757
# 71563    0.035641
# 79323    0.065627
# 81055    0.022435
# 82775    0.006812
# 85269    0.010282
# 86868    0.036380
# 87842    0.038492
# 89195    0.000088
# dtype: float64
#
# ==================================================
# Processing Date: 2023-06-30
#   In-Sample Window: 2008-06-30 to 2023-05-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.039681
#   Turnover:      0.048674
#   Trans. Cost:   0.000051
#   Net Return:    0.039630
# 11404    0.119597
# 26710    0.108857
# 27959    0.137933
# 28484    0.015454
# 34746    0.007254
# 47896    0.057800
# 52708    0.020631
# 57904    0.037922
# 59408    0.008894
# 59459    0.098310
# 60442    0.050490
# 66093    0.094657
# 66800   -0.001236
# 69032    0.018376
# 70519    0.009718
# 71563    0.036986
# 79323    0.065283
# 81055    0.022131
# 82775    0.006297
# 85269    0.010593
# 86868    0.035969
# 87842    0.037371
# 89195    0.000712
# dtype: float64
#
# ==================================================
# Processing Date: 2023-07-31
#   In-Sample Window: 2008-07-31 to 2023-06-30
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return: -0.045397
#   Turnover:      0.035022
#   Trans. Cost:   0.000033
#   Net Return:   -0.045431
# 11404    0.118139
# 26710    0.108707
# 27959    0.136299
# 28484    0.015261
# 34746    0.008465
# 47896    0.057902
# 52708    0.020430
# 57904    0.039048
# 59408    0.011082
# 59459    0.097289
# 60442    0.052751
# 66093    0.093186
# 66800   -0.001254
# 69032    0.018282
# 70519    0.009825
# 71563    0.038190
# 79323    0.064634
# 81055    0.021841
# 82775    0.006253
# 85269    0.010726
# 86868    0.035363
# 87842    0.036777
# 89195    0.000802
# dtype: float64
#
# ==================================================
# Processing Date: 2023-08-31
#   In-Sample Window: 2008-08-31 to 2023-07-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return: -0.006977
#   Turnover:      0.034696
#   Trans. Cost:   0.000034
#   Net Return:   -0.007011
# 11404    0.117326
# 26710    0.109135
# 27959    0.135389
# 28484    0.015301
# 34746    0.008633
# 47896    0.058095
# 52708    0.021201
# 57904    0.038963
# 59408    0.011451
# 59459    0.096303
# 60442    0.051847
# 66093    0.093458
# 66800   -0.001245
# 69032    0.018120
# 70519    0.009803
# 71563    0.038317
# 79323    0.064581
# 81055    0.022481
# 82775    0.006353
# 85269    0.010744
# 86868    0.036150
# 87842    0.036856
# 89195    0.000742
# dtype: float64
#
# ==================================================
# Processing Date: 2023-09-30
#   In-Sample Window: 2008-09-30 to 2023-08-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.001883
#   Turnover:      0.048153
#   Trans. Cost:   0.000048
#   Net Return:    0.001834
# 11404    0.113785
# 26710    0.107720
# 27959    0.131517
# 28484    0.015623
# 34746    0.010955
# 47896    0.060568
# 52708    0.021395
# 57904    0.037939
# 59408    0.012636
# 59459    0.094288
# 60442    0.050648
# 66093    0.093422
# 66800   -0.000286
# 69032    0.022852
# 70519    0.009754
# 71563    0.043143
# 79323    0.063639
# 81055    0.022102
# 82775    0.005712
# 85269    0.010369
# 86868    0.035587
# 87842    0.035768
# 89195    0.000866
# dtype: float64
#
# ==================================================
# Processing Date: 2023-10-31
#   In-Sample Window: 2008-10-31 to 2023-09-30
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.084604
#   Turnover:      0.051964
#   Trans. Cost:   0.000056
#   Net Return:    0.084547
# 11404    0.111064
# 26710    0.105796
# 27959    0.130095
# 28484    0.014612
# 34746    0.010137
# 47896    0.059036
# 52708    0.022730
# 57904    0.037720
# 59408    0.012999
# 59459    0.092046
# 60442    0.049275
# 66093    0.091015
# 66800   -0.000523
# 69032    0.022376
# 70519    0.009889
# 71563    0.042239
# 79323    0.067292
# 81055    0.022350
# 82775    0.013766
# 85269    0.010844
# 86868    0.036366
# 87842    0.037803
# 89195    0.001073
# dtype: float64
#
# ==================================================
# Processing Date: 2023-11-30
#   In-Sample Window: 2008-11-30 to 2023-10-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.052692
#   Turnover:      0.035898
#   Trans. Cost:   0.000038
#   Net Return:    0.052654
# 11404    0.110960
# 26710    0.107067
# 27959    0.129118
# 28484    0.014650
# 34746    0.007208
# 47896    0.060269
# 52708    0.022043
# 57904    0.038272
# 59408    0.013495
# 59459    0.091095
# 60442    0.049693
# 66093    0.090156
# 66800   -0.000970
# 69032    0.022384
# 70519    0.013917
# 71563    0.042169
# 79323    0.066428
# 81055    0.022215
# 82775    0.013700
# 85269    0.010833
# 86868    0.036077
# 87842    0.037375
# 89195    0.001847
# dtype: float64
#
# ==================================================
# Processing Date: 2023-12-31
#   In-Sample Window: 2008-12-31 to 2023-11-30
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.029234
#   Turnover:      0.064425
#   Trans. Cost:   0.000066
#   Net Return:    0.029168
# 11404    0.110288
# 26710    0.105420
# 27959    0.127858
# 28484    0.014452
# 34746    0.007229
# 47896    0.059502
# 52708    0.021611
# 57904    0.038701
# 59408    0.013345
# 59459    0.090089
# 60442    0.049046
# 66093    0.089186
# 66800   -0.001288
# 69032    0.021765
# 70519    0.010321
# 71563    0.041720
# 79323    0.067401
# 81055    0.021768
# 82775    0.025342
# 85269    0.010964
# 86868    0.035538
# 87842    0.037897
# 89195    0.001843
# dtype: float64
#
# ==================================================
# Processing Date: 2024-01-31
#   In-Sample Window: 2009-01-31 to 2023-12-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return: -0.000655
#   Turnover:      0.064504
#   Trans. Cost:   0.000064
#   Net Return:   -0.000719
# 11404    0.105559
# 26710    0.101324
# 27959    0.121780
# 28484    0.015027
# 34746    0.012253
# 47896    0.057196
# 52708    0.020468
# 57904    0.049194
# 59408    0.015611
# 59459    0.086870
# 60442    0.048811
# 66093    0.087286
# 66800   -0.000633
# 69032    0.024136
# 70519    0.010055
# 71563    0.040297
# 79323    0.075473
# 81055    0.023159
# 82775    0.024146
# 85269    0.010734
# 86868    0.034727
# 87842    0.036107
# 89195    0.000420
# dtype: float64
#
# ==================================================
# Processing Date: 2024-02-29
#   In-Sample Window: 2009-02-28 to 2024-01-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.062059
#   Turnover:      0.045919
#   Trans. Cost:   0.000049
#   Net Return:    0.062010
# 11404    0.105700
# 26710    0.100235
# 27959    0.122291
# 28484    0.013192
# 34746    0.011302
# 47896    0.055787
# 52708    0.019824
# 57904    0.048481
# 59408    0.014077
# 59459    0.084909
# 60442    0.047741
# 66093    0.085217
# 66800   -0.000866
# 69032    0.023676
# 70519    0.014025
# 71563    0.039828
# 79323    0.076503
# 81055    0.023121
# 82775    0.027250
# 85269    0.010962
# 86868    0.036402
# 87842    0.036965
# 89195    0.003378
# dtype: float64
#
# ==================================================
# Processing Date: 2024-03-31
#   In-Sample Window: 2009-03-31 to 2024-02-29
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return: -0.026701
#   Turnover:      0.030273
#   Trans. Cost:   0.000029
#   Net Return:   -0.026730
# 11404    0.106219
# 26710    0.095135
# 27959    0.121397
# 28484    0.015602
# 34746    0.012096
# 47896    0.055772
# 52708    0.019496
# 57904    0.049792
# 59408    0.017960
# 59459    0.083994
# 60442    0.047366
# 66093    0.084678
# 66800   -0.000670
# 69032    0.023069
# 70519    0.015496
# 71563    0.039677
# 79323    0.076683
# 81055    0.022388
# 82775    0.027217
# 85269    0.010309
# 86868    0.035916
# 87842    0.037290
# 89195    0.003117
# dtype: float64
#
# ==================================================
# Processing Date: 2024-04-30
#   In-Sample Window: 2009-04-30 to 2024-03-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.032821
#   Turnover:      0.077551
#   Trans. Cost:   0.000080
#   Net Return:    0.032741
# 11404    0.101795
# 26710    0.093684
# 27959    0.115704
# 28484    0.011934
# 34746    0.012067
# 47896    0.055162
# 52708    0.019110
# 57904    0.050190
# 59408    0.019145
# 59459    0.078514
# 60442    0.049948
# 66093    0.080179
# 66800   -0.000543
# 69032    0.021353
# 70519    0.014821
# 71563    0.044516
# 79323    0.074089
# 81055    0.022673
# 82775    0.027680
# 85269    0.009774
# 86868    0.036171
# 87842    0.035453
# 89195    0.026580
# dtype: float64
#
# ==================================================
# Processing Date: 2024-05-31
#   In-Sample Window: 2009-05-31 to 2024-04-30
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return: -0.023506
#   Turnover:      0.048387
#   Trans. Cost:   0.000047
#   Net Return:   -0.023553
# 11404    0.099639
# 26710    0.091718
# 27959    0.112329
# 28484    0.012151
# 34746    0.018659
# 47896    0.053717
# 52708    0.017606
# 57904    0.051045
# 59408    0.018732
# 59459    0.077035
# 60442    0.048886
# 66093    0.077743
# 66800   -0.000561
# 69032    0.022637
# 70519    0.014661
# 71563    0.049093
# 79323    0.072796
# 81055    0.025947
# 82775    0.027990
# 85269    0.009502
# 86868    0.035021
# 87842    0.034043
# 89195    0.029609
# dtype: float64
#
# ==================================================
# Processing Date: 2024-06-30
#   In-Sample Window: 2009-06-30 to 2024-05-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.078587
#   Turnover:      0.024344
#   Trans. Cost:   0.000026
#   Net Return:    0.078560
# 11404    0.098497
# 26710    0.091592
# 27959    0.111219
# 28484    0.012207
# 34746    0.018384
# 47896    0.054504
# 52708    0.017277
# 57904    0.051874
# 59408    0.019779
# 59459    0.076181
# 60442    0.050561
# 66093    0.077037
# 66800   -0.000495
# 69032    0.022608
# 70519    0.016207
# 71563    0.048741
# 79323    0.072056
# 81055    0.024740
# 82775    0.028325
# 85269    0.009871
# 86868    0.034885
# 87842    0.033754
# 89195    0.030194
# dtype: float64
#
# ==================================================
# Processing Date: 2024-07-31
#   In-Sample Window: 2009-07-31 to 2024-06-30
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.035683
#   Turnover:      0.053664
#   Trans. Cost:   0.000056
#   Net Return:    0.035627
# 11404    0.095069
# 26710    0.090576
# 27959    0.107488
# 28484    0.011687
# 34746    0.021068
# 47896    0.054279
# 52708    0.017413
# 57904    0.053646
# 59408    0.019780
# 59459    0.074192
# 60442    0.049566
# 66093    0.075805
# 66800   -0.001980
# 69032    0.021943
# 70519    0.016761
# 71563    0.047013
# 79323    0.070585
# 81055    0.028684
# 82775    0.036938
# 85269    0.009692
# 86868    0.034154
# 87842    0.032852
# 89195    0.032787
# dtype: float64
#
# ==================================================
# Processing Date: 2024-08-31
#   In-Sample Window: 2009-08-31 to 2024-07-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.005461
#   Turnover:      0.061619
#   Trans. Cost:   0.000062
#   Net Return:    0.005399
# 11404    0.093083
# 26710    0.088683
# 27959    0.104965
# 28484    0.011302
# 34746    0.020622
# 47896    0.052959
# 52708    0.017440
# 57904    0.050375
# 59408    0.019374
# 59459    0.072578
# 60442    0.049228
# 66093    0.074202
# 66800    0.016753
# 69032    0.021890
# 70519    0.018819
# 71563    0.047855
# 79323    0.068106
# 81055    0.028369
# 82775    0.036155
# 85269    0.009422
# 86868    0.033568
# 87842    0.032238
# 89195    0.032014
# dtype: float64
#
# ==================================================
# Processing Date: 2024-09-30
#   In-Sample Window: 2009-09-30 to 2024-08-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.002781
#   Turnover:      0.033833
#   Trans. Cost:   0.000034
#   Net Return:    0.002747
# 11404    0.092932
# 26710    0.088119
# 27959    0.104825
# 28484    0.011272
# 34746    0.020469
# 47896    0.052166
# 52708    0.017374
# 57904    0.050467
# 59408    0.019354
# 59459    0.072594
# 60442    0.052112
# 66093    0.072784
# 66800    0.016654
# 69032    0.022012
# 70519    0.018889
# 71563    0.047509
# 79323    0.068061
# 81055    0.028386
# 82775    0.036866
# 85269    0.009360
# 86868    0.033930
# 87842    0.031974
# 89195    0.031890
# dtype: float64
#
# ==================================================
# Processing Date: 2024-10-31
#   In-Sample Window: 2009-10-31 to 2024-09-30
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return:  0.080877
#   Turnover:      0.033128
#   Trans. Cost:   0.000036
#   Net Return:    0.080841
# 11404    0.092393
# 26710    0.087826
# 27959    0.104454
# 28484    0.011176
# 34746    0.020660
# 47896    0.051997
# 52708    0.017352
# 57904    0.049862
# 59408    0.019843
# 59459    0.072159
# 60442    0.052246
# 66093    0.072688
# 66800    0.017891
# 69032    0.021536
# 70519    0.019903
# 71563    0.047966
# 79323    0.067958
# 81055    0.028195
# 82775    0.036358
# 85269    0.009454
# 86868    0.034414
# 87842    0.031950
# 89195    0.031720
# dtype: float64
#
# ==================================================
# Processing Date: 2024-11-30
#   In-Sample Window: 2009-11-30 to 2024-10-31
#   Asset Universe: 29 total, 23 with complete data in window
#   Running Naive Nodewise for 23 assets...
#   Calculating GMV weights...
#   Gross Return: -0.078494
#   Turnover:      0.048131
#   Trans. Cost:   0.000044
#   Net Return:   -0.078539
# 11404    0.093182
# 26710    0.088009
# 27959    0.105491
# 28484    0.011196
# 34746    0.021382
# 47896    0.051502
# 52708    0.017469
# 57904    0.050596
# 59408    0.019812
# 59459    0.071970
# 60442    0.053018
# 66093    0.072895
# 66800    0.018611
# 69032    0.021399
# 70519    0.019805
# 71563    0.047294
# 79323    0.067021
# 81055    0.027319
# 82775    0.035917
# 85269    0.009582
# 86868    0.033409
# 87842    0.031351
# 89195    0.031769
# dtype: float64
# ==================================================
# --- Backtest Complete ---
# Sharpe Ratio: 0.1605
# Annualized Sharpe Ratio: 0.5560

# %%
with pd.option_context("display.max_rows", None):
    print(results_df['portfolio_weights'][0])
# Out:
# 10104    0.014157
# 10107    0.013370
# 10145    0.020299
# 10696    0.018943
# 11308    0.032671
# 11850    0.021576
# 12060    0.007817
# 12490    0.017076
# 13856    0.035770
# 13901    0.020899
# 14008    0.011004
# 14541    0.017758
# 14593    0.006272
# 15579    0.012480
# 17005    0.013289
# 17830    0.022510
# 18163    0.032076
# 18542    0.006204
# 19393    0.012741
# 19561    0.010228
# 20482    0.022690
# 21178    0.019130
# 21936    0.020964
# 22111    0.036158
# 22592    0.017865
# 22752    0.016301
# 24205    0.025857
# 24643    0.003239
# 26403    0.015860
# 27828    0.008145
# 27983    0.005226
# 38703    0.010461
# 43449    0.030656
# 46578    0.027846
# 47896    0.012712
# 48725    0.013920
# 49373    0.008603
# 50876    0.020438
# 52230    0.007426
# 54148    0.001972
# 55976    0.024941
# 57665    0.014694
# 57817    0.004701
# 59010    0.004981
# 59176    0.005870
# 59328    0.012143
# 59408    0.001888
# 60097    0.017366
# 61399    0.008981
# 62092    0.015380
# 64282    0.003536
# 65875    0.023569
# 66093    0.024109
# 66157    0.016225
# 66181    0.018219
# 69032    0.004364
# 70033    0.002437
# 70519    0.002280
# 75510    0.007301
# 76076    0.010567
# 77178    0.006869
# 77274    0.011242
# 77462    0.002665
# 77702    0.009855
# 82598    0.003317
# 82775   -0.000181
# 86580    0.000727
# 86868    0.007596
# 87055    0.020839
# 87447    0.017032
# 89525    0.012774
# 92655    0.011106
# dtype: float64

# %%
metrics['total_return']
# Out:
# 0.5492286216286506

# %%
metrics['variance']
# Out:
# 0.0031702314687692373

# %%
results_df['portfolio_turnover'].mean()
# Out:
# 0.06106678375597444
