# %% [markdown]
# # UNION

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Lasso
import warnings
warnings.filterwarnings('ignore')


def naive_nodewise_regression(Y_star, lambda_grid=None):
    """
    Implements Naive Nodewise Regression (Section 5.1.2).
    Uses GIC (Generalized Information Criterion) as in the paper.
    
    Parameters:
    -----------
    Y_star : np.ndarray, shape (n, p)
        Demeaned returns matrix (time x assets)
    lambda_grid : list or None
        Grid of lambda values to try. If None, creates default grid.
    
    Returns:
    --------
    Theta_hat : np.ndarray, shape (p, p)
        Estimated precision matrix
    """
    n, p = Y_star.shape

    # Initialize matrices
    Theta_hat = np.zeros((p, p))
    tau_squared = np.zeros(p)
    
    # Create lambda grid if not provided
    if lambda_grid is None:
        lambda_grid = np.logspace(-3, 1, 50)
    
    # For each asset j
    for j in range(p):
        # Step 1: Get y_j (target) and Y_{-j} (predictors)
        y_j = Y_star[:, j]
        Y_minus_j = np.delete(Y_star, j, axis=1)
        
        # Step 2-3: Estimate gamma_j using Lasso with GIC
        best_gic = np.inf
        best_lambda = lambda_grid[0]
        best_gamma = None
        best_ssr = None
        
        for lam in lambda_grid:
            lasso = Lasso(alpha=2*lam, fit_intercept=False, max_iter=10000)
            lasso.fit(Y_minus_j, y_j)
            gamma_j = lasso.coef_
            
            # Compute SSR and number of non-zero coefficients
            residuals = y_j - Y_minus_j @ gamma_j
            ssr = np.sum(residuals ** 2)
            sigma_sq_lambda = ssr / n
            q_lambda = np.sum(np.abs(gamma_j) > 1e-8)
            
            # Compute GIC
            if sigma_sq_lambda > 1e-10:
                gic = np.log(sigma_sq_lambda) + q_lambda * (np.log(p) / n) * np.log(np.log(n))
            else:
                gic = np.inf
            
            if gic < best_gic:
                best_gic = gic
                best_lambda = lam
                best_gamma = gamma_j.copy()
                best_ssr = ssr
        
        gamma_j_star = best_gamma
        tau_squared[j] = best_ssr / n + best_lambda * np.sum(np.abs(gamma_j_star))

        # Step 5: Form the j-th row of Theta_hat
        Theta_hat[j, j] = 1 / tau_squared[j]
        off_diag = -gamma_j_star / tau_squared[j]
        Theta_hat[j, :j] = off_diag[:j]
        Theta_hat[j, j+1:] = off_diag[j:]
    
    # Step 6: Symmetrize
    Theta_hat_sym = (Theta_hat + Theta_hat.T) / 2
    
    return Theta_hat_sym


def gmv_weights(Theta_hat):
    """
    Compute Global Minimum Variance (GMV) portfolio weights (Section 6.1).
    
    Parameters:
    -----------
    Theta_hat : np.ndarray, shape (p, p)
        Precision matrix
    
    Returns:
    --------
    w_star : np.ndarray, shape (p,)
        Portfolio weights
    """
    p = Theta_hat.shape[0]
    ones_p = np.ones(p)
    
    # w* = (Θ 1_p) / (1_p' Θ 1_p)
    numerator = Theta_hat @ ones_p
    denominator = ones_p @ Theta_hat @ ones_p
    
    if np.abs(denominator) < 1e-10:
        # Fallback to equal weights if precision matrix is near-singular
        return ones_p / p
    
    w_star = numerator / denominator
    
    return w_star


def load_yearly_signals(year, buys_path_template='buys_{}.csv', sells_path_template='sells_{}.csv'):
    """
    Load buy and sell signals for a specific year.
    
    Parameters:
    -----------
    year : int
        Year to load signals for
    buys_path_template : str
        Template for buys file path (use {} for year placeholder)
    sells_path_template : str
        Template for sells file path (use {} for year placeholder)
    
    Returns:
    --------
    permno_set : set
        Set of permnos in the buy and sell signals for this year
    """
    try:
        buys = pd.read_csv(buys_path_template.format(year), index_col=1)
        sells = pd.read_csv(sells_path_template.format(year), index_col=1)
        
        buys.index.name = 'permno'
        sells.index.name = 'permno'
        
        buys_index = buys.index.astype(int)
        sells_index = sells.index.astype(int)
        
        return set(buys_index.union(sells_index))
    except FileNotFoundError as e:
        print(f"  ⚠ Warning: Could not load signals for year {year}: {e}")
        return set()


def load_analyst_recommendations(analyst_rec_path):
    """
    Load analyst recommendations from CSV file.
    
    Parameters:
    -----------
    analyst_rec_path : str
        Path to analyst recommendations CSV file
    
    Returns:
    --------
    analyst_df : pd.DataFrame
        DataFrame with columns: permno, date, ticker, mean_recommendation, num_recommendations
        Indexed by date
    """
    try:
        analyst_df = pd.read_csv(analyst_rec_path)
        analyst_df['date'] = pd.to_datetime(analyst_df['date'])
        analyst_df['permno'] = analyst_df['permno'].astype(int)
        return analyst_df
    except FileNotFoundError as e:
        print(f"  ⚠ Warning: Could not load analyst recommendations: {e}")
        return pd.DataFrame(columns=['permno', 'date', 'ticker', 'mean_recommendation', 'num_recommendations'])


def get_analyst_permnos_for_date(analyst_df, date, strong_buy_threshold=1.5, strong_sell_threshold=4.5):
    """
    Get set of permnos with strong buy or strong sell analyst recommendations for a specific date.
    
    Parameters:
    -----------
    analyst_df : pd.DataFrame
        Analyst recommendations dataframe
    date : pd.Timestamp
        Date to get recommendations for
    strong_buy_threshold : float
        Mean recommendation must be strictly less than this for strong buy (default: 2.0)
    strong_sell_threshold : float
        Mean recommendation must be strictly greater than this for strong sell (default: 4.0)
    
    Returns:
    --------
    permno_set : set
        Set of permnos with strong buy or strong sell recommendations on this date
    """
    date_recs = analyst_df[analyst_df['date'] == date]
    
    # Filter for strong buys (< 2) or strong sells (> 4)
    strong_recs = date_recs[
        (date_recs['mean_recommendation'] < strong_buy_threshold) | 
        (date_recs['mean_recommendation'] > strong_sell_threshold)
    ]
    
    return set(strong_recs['permno'].values)


def backtest_nodewise_gmv_yearly(df, 
                                  test_start_date='2020-01-31', 
                                  test_end_date='2024-11-30',
                                  lookback_window=180,
                                  transaction_cost=0.001,
                                  buys_path_template='buys_{}.csv',
                                  sells_path_template='sells_{}.csv',
                                  analyst_rec_path=None,
                                  verbose=True):
    """
    Backtest Nodewise + GMV strategy with year-specific buy/sell signals 
    and analyst recommendations.
    
    Parameters:
    -----------
    df : pd.DataFrame
        DataFrame with columns: permno, datadate, ret_fwd_1
    test_start_date : str
        First date for out-of-sample returns (format: 'YYYY-MM-DD')
    test_end_date : str
        Last date for out-of-sample returns (format: 'YYYY-MM-DD')
    lookback_window : int
        Number of months in rolling training window (default: 180)
    transaction_cost : float
        Proportional transaction cost (default: 0.001 = 10 bps)
    buys_path_template : str
        Template for buys file path (use {} for year placeholder)
    sells_path_template : str
        Template for sells file path (use {} for year placeholder)
    analyst_rec_path : str or None
        Path to analyst recommendations CSV file. If None, only uses buy/sell signals.
    verbose : bool
        If True, prints detailed log at each time step.
    
    Returns:
    --------
    results_df : pd.DataFrame
        DataFrame with columns: date, portfolio_return, cumulative_return
    metrics : dict
        Overall performance metrics
    """
    # --- 1. Setup ---
    df = df.copy()
    if 'datadate' not in df.columns or 'permno' not in df.columns:
        raise ValueError("DataFrame must have 'datadate' and 'permno' columns")
    df['datadate'] = pd.to_datetime(df['datadate'])
    
    # Load analyst recommendations if provided
    analyst_df = None
    if analyst_rec_path is not None:
        analyst_df = load_analyst_recommendations(analyst_rec_path)
        if verbose and len(analyst_df) > 0:
            print(f"Loaded analyst recommendations: {len(analyst_df)} records")
    
    # Get unique dates
    all_dates = sorted(df['datadate'].unique())
    
    # Convert test dates to datetime
    test_start_dt = pd.to_datetime(test_start_date)
    test_end_dt = pd.to_datetime(test_end_date)
    
    # Find date indices
    try:
        test_start_idx = all_dates.index(test_start_dt)
        test_end_idx = all_dates.index(test_end_dt)
    except ValueError as e:
        raise ValueError(f"Date not found in DataFrame: {e}")
    
    if test_start_idx < lookback_window:
        raise ValueError(f"Not enough data for lookback. Test start date {test_start_date} "
                         f"requires data back to {all_dates[test_start_idx - lookback_window]}, "
                         f"but only {test_start_idx} periods are available.")
    
    # Storage for results
    portfolio_returns = []
    portfolio_dates = []
    portfolio_weights_list = []
    portfolio_turnover_list = []
    portfolio_gross_returns = []
    
    # Track weights by permno
    prev_weights_dict = {}
    prev_oos_returns_dict = {}
    prev_gross_return = 0.0
    
    # Cache for yearly signals
    yearly_signals_cache = {}
    
    # --- 2. Rolling Window Backtest ---
    if verbose:
        print("="*60)
        print("STARTING BACKTEST WITH YEARLY SIGNALS + ANALYST RECS")
        print("="*60)
        
    for t in range(test_start_idx, test_end_idx + 1):
        current_date = all_dates[t]
        current_year = current_date.year
        
        # Load signals for current year if not cached
        if current_year not in yearly_signals_cache:
            yearly_signals_cache[current_year] = load_yearly_signals(
                current_year, buys_path_template, sells_path_template
            )
        
        buysell_permnos = yearly_signals_cache[current_year]
        
        # Get analyst recommendations for current date
        analyst_permnos = set()
        if analyst_df is not None and len(analyst_df) > 0:
            analyst_permnos = get_analyst_permnos_for_date(analyst_df, current_date)
        
        # UNION of buy/sell signals and analyst recommendations
        allowed_permnos = buysell_permnos.union(analyst_permnos)
        
        if len(allowed_permnos) == 0:
            if verbose:
                print(f"\n[{t - test_start_idx + 1}/{test_end_idx - test_start_idx + 1}] "
                      f"Date: {current_date.strftime('%Y-%m-%d')}")
                print(f"  ⚠ No signals or analyst recs for {current_date.strftime('%Y-%m-%d')}, skipping period")
            continue
        
        # Define the lookback window
        window_start_date = all_dates[t - lookback_window]
        window_end_date = all_dates[t - 1]
        
        # Get training data for this window, filtered by allowed permnos
        train_data = df[(df['datadate'] >= window_start_date) & 
                        (df['datadate'] <= window_end_date) &
                        (df['permno'].isin(allowed_permnos))]
        
        # Pivot to get returns matrix (time x assets)
        returns_pivot = train_data.pivot(index='datadate', columns='permno', values='ret_fwd_1')
        
        # Reindex to ensure all dates are present
        window_dates = all_dates[t - lookback_window : t]
        returns_pivot = returns_pivot.reindex(index=window_dates)
        
        # Filter assets with any NaNs in this window
        nan_assets = returns_pivot.columns[returns_pivot.isna().any()]
        filtered_pivot = returns_pivot.drop(columns=nan_assets)
        
        current_assets = filtered_pivot.columns.tolist()
        Y = filtered_pivot.values
        n_train, p_current = Y.shape

        if verbose:
            print(f"\n[{t - test_start_idx + 1}/{test_end_idx - test_start_idx + 1}] "
                  f"Date: {current_date.strftime('%Y-%m-%d')} | Year: {current_year}")
            print(f"  Window: {window_start_date.strftime('%Y-%m-%d')} to "
                  f"{window_end_date.strftime('%Y-%m-%d')}")
            print(f"  Buy/Sell: {len(buysell_permnos)} | Analyst: {len(analyst_permnos)} | "
                  f"Union: {len(allowed_permnos)} | Assets w/ data: {p_current}")

        # Check for valid data
        if n_train < lookback_window or p_current < 2:
            if verbose:
                print(f"  ⚠ Insufficient data (n={n_train}, p={p_current}), using prev weights")
            # Filter previous weights to only allowed permnos
            new_weights_dict = {k: v for k, v in prev_weights_dict.items() if k in allowed_permnos}
        else:
            try:
                # Demean the returns
                Y_bar = Y.mean(axis=0)
                Y_star = Y - Y_bar
                
                if verbose:
                    print(f"  Running Nodewise Regression...")
                Theta_hat = naive_nodewise_regression(Y_star)
                
                if verbose:
                    print(f"  Computing GMV weights...")
                w_star = gmv_weights(Theta_hat)
                
                # Create weights dictionary
                new_weights_dict = {asset: w_star[i] for i, asset in enumerate(current_assets)}
                
            except Exception as e:
                if verbose:
                    print(f"  ✗ Error: {e}")
                    print(f"  Using previous weights")
                # Filter previous weights to only allowed permnos
                new_weights_dict = {k: v for k, v in prev_weights_dict.items() if k in allowed_permnos}

        # Normalize weights to sum to 1
        weight_sum = sum(new_weights_dict.values())
        if weight_sum > 1e-10:
            new_weights_dict = {k: v/weight_sum for k, v in new_weights_dict.items()}
        else:
            if verbose:
                print("  ⚠ Zero weight sum, using previous weights")
            new_weights_dict = {k: v for k, v in prev_weights_dict.items() if k in allowed_permnos}
            weight_sum = sum(new_weights_dict.values())
            if weight_sum > 1e-10:
                new_weights_dict = {k: v/weight_sum for k, v in new_weights_dict.items()}
        
        # --- 3. OOS Returns & Transaction Costs ---
        
        # Get out-of-sample returns for current month (only for allowed permnos)
        oos_data = df[(df['datadate'] == current_date) & (df['permno'].isin(allowed_permnos))]
        oos_returns_series = oos_data.set_index('permno')['ret_fwd_1']
        
        # Filter out NaN returns
        oos_returns_series = oos_returns_series.dropna()
        oos_returns_dict = oos_returns_series.to_dict()
        
        # Find common assets between weights and returns
        common_assets = set(new_weights_dict.keys()) & set(oos_returns_dict.keys())
        
        if len(common_assets) == 0:
            if verbose:
                print("  ⚠ No common assets with valid returns, skipping period")
            continue
        
        # Filter to common assets and renormalize
        common_weights = {a: new_weights_dict[a] for a in common_assets}
        common_weight_sum = sum(common_weights.values())
        if common_weight_sum > 1e-10:
            common_weights = {k: v/common_weight_sum for k, v in common_weights.items()}
        else:
            if verbose:
                print("  ⚠ Zero weight sum after filtering, skipping period")
            continue
        
        # Compute gross portfolio return
        gross_return = sum(common_weights[a] * oos_returns_dict[a] for a in common_assets)
        
        # Sanity check
        if np.isnan(gross_return) or np.isinf(gross_return):
            if verbose:
                print(f"  ⚠ Invalid gross return: {gross_return}, skipping period")
            continue
        
        # Calculate transaction costs
        if len(prev_weights_dict) > 0:
            all_traded_assets = set(common_weights.keys()) | set(prev_weights_dict.keys())
            
            # Adjust previous weights
            adjusted_prev = {}
            for asset in all_traded_assets:
                prev_w = prev_weights_dict.get(asset, 0.0)
                
                if asset in prev_oos_returns_dict:
                    prev_r = prev_oos_returns_dict[asset]
                    if prev_gross_return > -0.99:
                        adjusted_prev[asset] = prev_w * (1 + prev_r) / (1 + prev_gross_return)
                    else:
                        adjusted_prev[asset] = 0.0
                else:
                    adjusted_prev[asset] = 0.0
            
            # Renormalize adjusted weights
            adj_sum = sum(adjusted_prev.get(a, 0.0) for a in common_weights.keys())
            if adj_sum > 1e-10:
                adjusted_prev_normalized = {k: adjusted_prev.get(k, 0.0)/adj_sum 
                                           for k in common_weights.keys()}
            else:
                adjusted_prev_normalized = {k: 0.0 for k in common_weights.keys()}
            
            # Turnover
            turnover = sum(abs(common_weights.get(a, 0.0) - adjusted_prev_normalized.get(a, 0.0)) 
                          for a in all_traded_assets)
            
            # Transaction cost
            tc = transaction_cost * (1 + gross_return) * turnover
        else:
            # First period
            turnover = sum(abs(w) for w in common_weights.values())
            tc = transaction_cost * turnover
        
        # Net return
        net_return = gross_return - tc
        
        # Store results
        portfolio_returns.append(net_return)
        portfolio_dates.append(current_date)
        portfolio_weights_list.append(common_weights.copy())
        portfolio_turnover_list.append(turnover)
        portfolio_gross_returns.append(gross_return)
        
        # Update previous values for next iteration
        prev_weights_dict = common_weights.copy()
        prev_oos_returns_dict = {a: oos_returns_dict[a] for a in common_assets}
        prev_gross_return = gross_return
        
        if verbose:
            print(f"  Gross: {gross_return:>8.5f} | Turnover: {turnover:>6.4f} | "
                  f"TC: {tc:>8.6f} | Net: {net_return:>8.5f}")

    if verbose:
        print("\n" + "="*60)
        print("BACKTEST COMPLETE")
        print("="*60)
    
    # --- 4. Compile Results ---
    results_df = pd.DataFrame({
        'date': portfolio_dates,
        'portfolio_return': portfolio_returns,
        'portfolio_gross_return': portfolio_gross_returns,
        'portfolio_weights': portfolio_weights_list,
        'portfolio_turnover': portfolio_turnover_list
    })
    results_df['cumulative_return'] = (1 + results_df['portfolio_return']).cumprod() - 1
    
    # Compute overall metrics
    if len(portfolio_returns) > 0:
        mean_return = np.mean(portfolio_returns)
        variance = np.var(portfolio_returns, ddof=1)
        sharpe_ratio = mean_return / np.sqrt(variance) if variance > 0 else 0
        
        # Annualized metrics (monthly data)
        annual_return = mean_return * 12
        annual_volatility = np.sqrt(variance * 12)
        annual_sharpe = annual_return / annual_volatility if annual_volatility > 0 else 0
        
        metrics = {
            'mean_return': mean_return,
            'variance': variance,
            'sharpe_ratio': sharpe_ratio,
            'annual_return': annual_return,
            'annual_volatility': annual_volatility,
            'annual_sharpe_ratio': annual_sharpe,
            'total_return': results_df['cumulative_return'].iloc[-1],
            'avg_turnover': np.mean(portfolio_turnover_list),
            'n_periods': len(portfolio_returns)
        }
    else:
        metrics = {
            'mean_return': 0,
            'variance': 0,
            'sharpe_ratio': 0,
            'annual_return': 0,
            'annual_volatility': 0,
            'annual_sharpe_ratio': 0,
            'total_return': 0,
            'avg_turnover': 0,
            'n_periods': 0
        }
    
    return results_df, metrics

# %%
df = pd.read_csv('../green cleaned.csv', dtype={'ncusip': 'string'})
df['ret_fwd_1'] = df.groupby('permno')['ret_excess'].shift(-1)

results_df, metrics = backtest_nodewise_gmv_yearly(
    df=df,
    test_start_date='2020-01-31',
    test_end_date='2024-11-30',
    lookback_window=180,
    transaction_cost=0.001,
    buys_path_template='buys_{}.csv',
    sells_path_template='sells_{}.csv',
    analyst_rec_path='monthly_mean_recommendations.csv',  # <-- Add this
    verbose=True
)

print(f"\nSharpe Ratio: {metrics['sharpe_ratio']:.4f}")
print(f"Annualized Sharpe Ratio: {metrics['annual_sharpe_ratio']:.4f}")
print(f"Total Return: {metrics['total_return']:.4f}")
print(f"Average Turnover: {metrics['avg_turnover']:.4f}")
# Out:
# Loaded analyst recommendations: 16559 records
# ============================================================
# STARTING BACKTEST WITH YEARLY SIGNALS + ANALYST RECS
# ============================================================
#
# [1/59] Date: 2020-01-31 | Year: 2020
#   Window: 2005-01-31 to 2019-12-31
#   Buy/Sell: 40 | Analyst: 33 | Union: 73 | Assets w/ data: 40
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.09204 | Turnover: 1.0914 | TC: 0.001091 | Net: -0.09313
#
# [2/59] Date: 2020-02-29 | Year: 2020
#   Window: 2005-02-28 to 2020-01-31
#   Buy/Sell: 40 | Analyst: 14 | Union: 54 | Assets w/ data: 32
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.18155 | Turnover: 0.3029 | TC: 0.000248 | Net: -0.18179
#
# [3/59] Date: 2020-03-31 | Year: 2020
#   Window: 2005-03-31 to 2020-02-29
#   Buy/Sell: 40 | Analyst: 42 | Union: 79 | Assets w/ data: 48
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.11354 | Turnover: 0.9643 | TC: 0.001074 | Net:  0.11246
#
# [4/59] Date: 2020-04-30 | Year: 2020
#   Window: 2005-04-30 to 2020-03-31
#   Buy/Sell: 40 | Analyst: 15 | Union: 53 | Assets w/ data: 30
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02813 | Turnover: 0.4034 | TC: 0.000415 | Net:  0.02771
#
# [5/59] Date: 2020-05-31 | Year: 2020
#   Window: 2005-05-31 to 2020-04-30
#   Buy/Sell: 40 | Analyst: 33 | Union: 72 | Assets w/ data: 38
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.00997 | Turnover: 0.5722 | TC: 0.000567 | Net: -0.01053
#
# [6/59] Date: 2020-06-30 | Year: 2020
#   Window: 2005-06-30 to 2020-05-31
#   Buy/Sell: 40 | Analyst: 35 | Union: 72 | Assets w/ data: 44
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.04205 | Turnover: 1.0702 | TC: 0.001115 | Net:  0.04094
#
# [7/59] Date: 2020-07-31 | Year: 2020
#   Window: 2005-07-31 to 2020-06-30
#   Buy/Sell: 40 | Analyst: 53 | Union: 88 | Assets w/ data: 45
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.00089 | Turnover: 0.8455 | TC: 0.000846 | Net:  0.00005
#
# [8/59] Date: 2020-08-31 | Year: 2020
#   Window: 2005-08-31 to 2020-07-31
#   Buy/Sell: 40 | Analyst: 21 | Union: 60 | Assets w/ data: 32
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.00104 | Turnover: 0.4110 | TC: 0.000411 | Net:  0.00062
#
# [9/59] Date: 2020-09-30 | Year: 2020
#   Window: 2005-09-30 to 2020-08-31
#   Buy/Sell: 40 | Analyst: 29 | Union: 67 | Assets w/ data: 36
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.00067 | Turnover: 0.8192 | TC: 0.000820 | Net: -0.00015
#
# [10/59] Date: 2020-10-31 | Year: 2020
#   Window: 2005-10-31 to 2020-09-30
#   Buy/Sell: 40 | Analyst: 30 | Union: 68 | Assets w/ data: 37
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.11621 | Turnover: 0.7522 | TC: 0.000840 | Net:  0.11537
#
# [11/59] Date: 2020-11-30 | Year: 2020
#   Window: 2005-11-30 to 2020-10-31
#   Buy/Sell: 40 | Analyst: 26 | Union: 66 | Assets w/ data: 36
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03049 | Turnover: 0.6229 | TC: 0.000642 | Net:  0.02985
#
# [12/59] Date: 2020-12-31 | Year: 2020
#   Window: 2005-12-31 to 2020-11-30
#   Buy/Sell: 40 | Analyst: 24 | Union: 64 | Assets w/ data: 36
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.01645 | Turnover: 0.7845 | TC: 0.000797 | Net:  0.01565
#
# [13/59] Date: 2021-01-31 | Year: 2021
#   Window: 2006-01-31 to 2020-12-31
#   Buy/Sell: 123 | Analyst: 34 | Union: 145 | Assets w/ data: 81
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.05401 | Turnover: 1.8358 | TC: 0.001935 | Net:  0.05208
#
# [14/59] Date: 2021-02-28 | Year: 2021
#   Window: 2006-02-28 to 2021-01-31
#   Buy/Sell: 123 | Analyst: 36 | Union: 153 | Assets w/ data: 79
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.07220 | Turnover: 0.3722 | TC: 0.000399 | Net:  0.07180
#
# [15/59] Date: 2021-03-31 | Year: 2021
#   Window: 2006-03-31 to 2021-02-28
#   Buy/Sell: 123 | Analyst: 31 | Union: 149 | Assets w/ data: 75
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03651 | Turnover: 0.2527 | TC: 0.000262 | Net:  0.03625
#
# [16/59] Date: 2021-04-30 | Year: 2021
#   Window: 2006-04-30 to 2021-03-31
#   Buy/Sell: 123 | Analyst: 37 | Union: 150 | Assets w/ data: 83
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03137 | Turnover: 0.5058 | TC: 0.000522 | Net:  0.03085
#
# [17/59] Date: 2021-05-31 | Year: 2021
#   Window: 2006-05-31 to 2021-04-30
#   Buy/Sell: 123 | Analyst: 34 | Union: 149 | Assets w/ data: 82
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.00106 | Turnover: 0.3374 | TC: 0.000338 | Net:  0.00072
#
# [18/59] Date: 2021-06-30 | Year: 2021
#   Window: 2006-06-30 to 2021-05-31
#   Buy/Sell: 123 | Analyst: 31 | Union: 149 | Assets w/ data: 85
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.00607 | Turnover: 0.4038 | TC: 0.000406 | Net:  0.00567
#
# [19/59] Date: 2021-07-31 | Year: 2021
#   Window: 2006-07-31 to 2021-06-30
#   Buy/Sell: 123 | Analyst: 24 | Union: 143 | Assets w/ data: 75
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.00521 | Turnover: 0.1972 | TC: 0.000198 | Net:  0.00501
#
# [20/59] Date: 2021-08-31 | Year: 2021
#   Window: 2006-08-31 to 2021-07-31
#   Buy/Sell: 123 | Analyst: 28 | Union: 145 | Assets w/ data: 81
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.01793 | Turnover: 0.4002 | TC: 0.000393 | Net: -0.01832
#
# [21/59] Date: 2021-09-30 | Year: 2021
#   Window: 2006-09-30 to 2021-08-31
#   Buy/Sell: 123 | Analyst: 19 | Union: 138 | Assets w/ data: 74
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.04042 | Turnover: 0.2314 | TC: 0.000241 | Net:  0.04018
#
# [22/59] Date: 2021-10-31 | Year: 2021
#   Window: 2006-10-31 to 2021-09-30
#   Buy/Sell: 123 | Analyst: 23 | Union: 142 | Assets w/ data: 80
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.01526 | Turnover: 0.4560 | TC: 0.000449 | Net: -0.01571
#
# [23/59] Date: 2021-11-30 | Year: 2021
#   Window: 2006-11-30 to 2021-10-31
#   Buy/Sell: 123 | Analyst: 26 | Union: 144 | Assets w/ data: 76
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.07017 | Turnover: 0.2724 | TC: 0.000292 | Net:  0.06988
#
# [24/59] Date: 2021-12-31 | Year: 2021
#   Window: 2006-12-31 to 2021-11-30
#   Buy/Sell: 123 | Analyst: 17 | Union: 137 | Assets w/ data: 74
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.00178 | Turnover: 0.1646 | TC: 0.000164 | Net: -0.00195
#
# [25/59] Date: 2022-01-31 | Year: 2022
#   Window: 2007-01-31 to 2021-12-31
#   Buy/Sell: 34 | Analyst: 20 | Union: 53 | Assets w/ data: 26
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.01960 | Turnover: 1.7211 | TC: 0.001687 | Net: -0.02128
#
# [26/59] Date: 2022-02-28 | Year: 2022
#   Window: 2007-02-28 to 2022-01-31
#   Buy/Sell: 34 | Analyst: 19 | Union: 49 | Assets w/ data: 28
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.05488 | Turnover: 0.6925 | TC: 0.000731 | Net:  0.05415
#
# [27/59] Date: 2022-03-31 | Year: 2022
#   Window: 2007-03-31 to 2022-02-28
#   Buy/Sell: 34 | Analyst: 27 | Union: 58 | Assets w/ data: 31
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.04194 | Turnover: 0.7439 | TC: 0.000713 | Net: -0.04265
#
# [28/59] Date: 2022-04-30 | Year: 2022
#   Window: 2007-04-30 to 2022-03-31
#   Buy/Sell: 34 | Analyst: 22 | Union: 55 | Assets w/ data: 25
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02251 | Turnover: 0.2738 | TC: 0.000280 | Net:  0.02223
#
# [29/59] Date: 2022-05-31 | Year: 2022
#   Window: 2007-05-31 to 2022-04-30
#   Buy/Sell: 34 | Analyst: 27 | Union: 60 | Assets w/ data: 25
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.04312 | Turnover: 0.1864 | TC: 0.000178 | Net: -0.04330
#
# [30/59] Date: 2022-06-30 | Year: 2022
#   Window: 2007-06-30 to 2022-05-31
#   Buy/Sell: 34 | Analyst: 20 | Union: 53 | Assets w/ data: 28
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.06106 | Turnover: 0.2344 | TC: 0.000249 | Net:  0.06081
#
# [31/59] Date: 2022-07-31 | Year: 2022
#   Window: 2007-07-31 to 2022-06-30
#   Buy/Sell: 34 | Analyst: 26 | Union: 58 | Assets w/ data: 27
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.03131 | Turnover: 0.4540 | TC: 0.000440 | Net: -0.03175
#
# [32/59] Date: 2022-08-31 | Year: 2022
#   Window: 2007-08-31 to 2022-07-31
#   Buy/Sell: 34 | Analyst: 31 | Union: 62 | Assets w/ data: 29
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.08939 | Turnover: 0.4674 | TC: 0.000426 | Net: -0.08982
#
# [33/59] Date: 2022-09-30 | Year: 2022
#   Window: 2007-09-30 to 2022-08-31
#   Buy/Sell: 34 | Analyst: 28 | Union: 61 | Assets w/ data: 28
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.09779 | Turnover: 0.3190 | TC: 0.000350 | Net:  0.09744
#
# [34/59] Date: 2022-10-31 | Year: 2022
#   Window: 2007-10-31 to 2022-09-30
#   Buy/Sell: 34 | Analyst: 36 | Union: 68 | Assets w/ data: 39
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.06628 | Turnover: 1.0511 | TC: 0.001121 | Net:  0.06516
#
# [35/59] Date: 2022-11-30 | Year: 2022
#   Window: 2007-11-30 to 2022-10-31
#   Buy/Sell: 34 | Analyst: 23 | Union: 57 | Assets w/ data: 28
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.03106 | Turnover: 0.3932 | TC: 0.000381 | Net: -0.03144
#
# [36/59] Date: 2022-12-31 | Year: 2022
#   Window: 2007-12-31 to 2022-11-30
#   Buy/Sell: 34 | Analyst: 18 | Union: 51 | Assets w/ data: 28
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03096 | Turnover: 0.4385 | TC: 0.000452 | Net:  0.03050
#
# [37/59] Date: 2023-01-31 | Year: 2023
#   Window: 2008-01-31 to 2022-12-31
#   Buy/Sell: 137 | Analyst: 22 | Union: 154 | Assets w/ data: 70
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.04344 | Turnover: 1.9647 | TC: 0.001879 | Net: -0.04531
#
# [38/59] Date: 2023-02-28 | Year: 2023
#   Window: 2008-02-29 to 2023-01-31
#   Buy/Sell: 137 | Analyst: 22 | Union: 156 | Assets w/ data: 76
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.00606 | Turnover: 0.2678 | TC: 0.000266 | Net: -0.00633
#
# [39/59] Date: 2023-03-31 | Year: 2023
#   Window: 2008-03-31 to 2023-02-28
#   Buy/Sell: 137 | Analyst: 24 | Union: 155 | Assets w/ data: 73
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02277 | Turnover: 0.2937 | TC: 0.000300 | Net:  0.02247
#
# [40/59] Date: 2023-04-30 | Year: 2023
#   Window: 2008-04-30 to 2023-03-31
#   Buy/Sell: 137 | Analyst: 42 | Union: 169 | Assets w/ data: 82
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.06586 | Turnover: 0.6811 | TC: 0.000636 | Net: -0.06649
#
# [41/59] Date: 2023-05-31 | Year: 2023
#   Window: 2008-05-31 to 2023-04-30
#   Buy/Sell: 137 | Analyst: 34 | Union: 163 | Assets w/ data: 80
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.05412 | Turnover: 0.5086 | TC: 0.000536 | Net:  0.05358
#
# [42/59] Date: 2023-06-30 | Year: 2023
#   Window: 2008-06-30 to 2023-05-31
#   Buy/Sell: 137 | Analyst: 20 | Union: 152 | Assets w/ data: 75
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02135 | Turnover: 0.2580 | TC: 0.000263 | Net:  0.02108
#
# [43/59] Date: 2023-07-31 | Year: 2023
#   Window: 2008-07-31 to 2023-06-30
#   Buy/Sell: 137 | Analyst: 28 | Union: 155 | Assets w/ data: 78
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.04006 | Turnover: 0.3132 | TC: 0.000301 | Net: -0.04036
#
# [44/59] Date: 2023-08-31 | Year: 2023
#   Window: 2008-08-31 to 2023-07-31
#   Buy/Sell: 137 | Analyst: 21 | Union: 151 | Assets w/ data: 71
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.03661 | Turnover: 0.1913 | TC: 0.000184 | Net: -0.03679
#
# [45/59] Date: 2023-09-30 | Year: 2023
#   Window: 2008-09-30 to 2023-08-31
#   Buy/Sell: 137 | Analyst: 33 | Union: 165 | Assets w/ data: 82
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.02239 | Turnover: 0.4449 | TC: 0.000435 | Net: -0.02283
#
# [46/59] Date: 2023-10-31 | Year: 2023
#   Window: 2008-10-31 to 2023-09-30
#   Buy/Sell: 137 | Analyst: 30 | Union: 159 | Assets w/ data: 77
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.07075 | Turnover: 0.4612 | TC: 0.000494 | Net:  0.07025
#
# [47/59] Date: 2023-11-30 | Year: 2023
#   Window: 2008-11-30 to 2023-10-31
#   Buy/Sell: 137 | Analyst: 27 | Union: 158 | Assets w/ data: 80
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02775 | Turnover: 0.4217 | TC: 0.000433 | Net:  0.02731
#
# [48/59] Date: 2023-12-31 | Year: 2023
#   Window: 2008-12-31 to 2023-11-30
#   Buy/Sell: 137 | Analyst: 23 | Union: 154 | Assets w/ data: 77
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.00719 | Turnover: 0.2549 | TC: 0.000253 | Net: -0.00745
#
# [49/59] Date: 2024-01-31 | Year: 2024
#   Window: 2009-01-31 to 2023-12-31
#   Buy/Sell: 281 | Analyst: 18 | Union: 292 | Assets w/ data: 161
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02199 | Turnover: 1.6719 | TC: 0.001709 | Net:  0.02028
#
# [50/59] Date: 2024-02-29 | Year: 2024
#   Window: 2009-02-28 to 2024-01-31
#   Buy/Sell: 281 | Analyst: 18 | Union: 285 | Assets w/ data: 158
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03873 | Turnover: 0.0885 | TC: 0.000092 | Net:  0.03864
#
# [51/59] Date: 2024-03-31 | Year: 2024
#   Window: 2009-03-31 to 2024-02-29
#   Buy/Sell: 281 | Analyst: 22 | Union: 291 | Assets w/ data: 163
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.04215 | Turnover: 0.1659 | TC: 0.000159 | Net: -0.04231
#
# [52/59] Date: 2024-04-30 | Year: 2024
#   Window: 2009-04-30 to 2024-03-31
#   Buy/Sell: 281 | Analyst: 26 | Union: 294 | Assets w/ data: 162
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.01834 | Turnover: 0.1683 | TC: 0.000171 | Net:  0.01817
#
# [53/59] Date: 2024-05-31 | Year: 2024
#   Window: 2009-05-31 to 2024-04-30
#   Buy/Sell: 281 | Analyst: 21 | Union: 291 | Assets w/ data: 158
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.01481 | Turnover: 0.0975 | TC: 0.000096 | Net: -0.01490
#
# [54/59] Date: 2024-06-30 | Year: 2024
#   Window: 2009-06-30 to 2024-05-31
#   Buy/Sell: 281 | Analyst: 31 | Union: 295 | Assets w/ data: 161
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.06013 | Turnover: 0.1244 | TC: 0.000132 | Net:  0.06000
#
# [55/59] Date: 2024-07-31 | Year: 2024
#   Window: 2009-07-31 to 2024-06-30
#   Buy/Sell: 281 | Analyst: 18 | Union: 288 | Assets w/ data: 156
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03721 | Turnover: 0.0951 | TC: 0.000099 | Net:  0.03711
#
# [56/59] Date: 2024-08-31 | Year: 2024
#   Window: 2009-08-31 to 2024-07-31
#   Buy/Sell: 281 | Analyst: 17 | Union: 289 | Assets w/ data: 159
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.01604 | Turnover: 0.1557 | TC: 0.000158 | Net:  0.01588
#
# [57/59] Date: 2024-09-30 | Year: 2024
#   Window: 2009-09-30 to 2024-08-31
#   Buy/Sell: 281 | Analyst: 30 | Union: 295 | Assets w/ data: 162
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.02482 | Turnover: 0.1202 | TC: 0.000117 | Net: -0.02493
#
# [58/59] Date: 2024-10-31 | Year: 2024
#   Window: 2009-10-31 to 2024-09-30
#   Buy/Sell: 281 | Analyst: 28 | Union: 296 | Assets w/ data: 162
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.04802 | Turnover: 0.1536 | TC: 0.000161 | Net:  0.04786
#
# [59/59] Date: 2024-11-30 | Year: 2024
#   Window: 2009-11-30 to 2024-10-31
#   Buy/Sell: 281 | Analyst: 18 | Union: 290 | Assets w/ data: 156
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.06853 | Turnover: 0.1102 | TC: 0.000103 | Net: -0.06864
#
# ============================================================
# BACKTEST COMPLETE
# ============================================================
#
# Sharpe Ratio: 0.1495
# Annualized Sharpe Ratio: 0.5178
# Total Return: 0.4594
# Average Turnover: 0.5094

# %%
with pd.option_context("display.max_rows", None):
    print(results_df['portfolio_weights'][0])
# Out:
# {71563: 0.038730726522285, 11404: 0.10647320531757165, 59408: -0.010815025210646829, 85269: 0.011895111995926825, 47896: 0.05575475896919665, 60442: 0.05414056242636757, 64282: 0.01525749277494783, 81055: 0.02089863675241667, 87842: 0.04910328344855546, 82598: 0.015573095598374848, 69032: 0.012215480555465442, 66093: 0.0798725965302676, 57904: 0.039497621664209316, 27959: 0.12034359554548361, 34746: -0.0044753043270086765, 59459: 0.08169500509447297, 28484: 0.014576100021821276, 78916: 0.033293737457325466, 86868: 0.027682012051348154, 26710: 0.08677907969428147, 82775: -0.009651006235702666, 57817: 0.015222834378262294, 79323: 0.06051421364945256, 49373: 0.02850307604262365, 89195: -0.02095370578354578, 66800: -0.007218137327910712, 46578: 0.09225448599222023, 70519: -0.007163533598061796}

# %%
metrics['total_return']
# Out:
# 0.541987322136352

# %%
metrics['variance']
# Out:
# 0.0025714981032107353

# %%
results_df['portfolio_turnover'].mean()
# Out:
# 0.2077408180655912

# %% [markdown]
# # INTERSECTON

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Lasso
import warnings
warnings.filterwarnings('ignore')


def naive_nodewise_regression(Y_star, lambda_grid=None):
    """
    Implements Naive Nodewise Regression (Section 5.1.2).
    Uses GIC (Generalized Information Criterion) as in the paper.
    
    Parameters:
    -----------
    Y_star : np.ndarray, shape (n, p)
        Demeaned returns matrix (time x assets)
    lambda_grid : list or None
        Grid of lambda values to try. If None, creates default grid.
    
    Returns:
    --------
    Theta_hat : np.ndarray, shape (p, p)
        Estimated precision matrix
    """
    n, p = Y_star.shape

    # Initialize matrices
    Theta_hat = np.zeros((p, p))
    tau_squared = np.zeros(p)
    
    # Create lambda grid if not provided
    if lambda_grid is None:
        lambda_grid = np.logspace(-3, 1, 50)
    
    # For each asset j
    for j in range(p):
        # Step 1: Get y_j (target) and Y_{-j} (predictors)
        y_j = Y_star[:, j]
        Y_minus_j = np.delete(Y_star, j, axis=1)
        
        # Step 2-3: Estimate gamma_j using Lasso with GIC
        best_gic = np.inf
        best_lambda = lambda_grid[0]
        best_gamma = None
        best_ssr = None
        
        for lam in lambda_grid:
            lasso = Lasso(alpha=2*lam, fit_intercept=False, max_iter=10000)
            lasso.fit(Y_minus_j, y_j)
            gamma_j = lasso.coef_
            
            # Compute SSR and number of non-zero coefficients
            residuals = y_j - Y_minus_j @ gamma_j
            ssr = np.sum(residuals ** 2)
            sigma_sq_lambda = ssr / n
            q_lambda = np.sum(np.abs(gamma_j) > 1e-8)
            
            # Compute GIC
            if sigma_sq_lambda > 1e-10:
                gic = np.log(sigma_sq_lambda) + q_lambda * (np.log(p) / n) * np.log(np.log(n))
            else:
                gic = np.inf
            
            if gic < best_gic:
                best_gic = gic
                best_lambda = lam
                best_gamma = gamma_j.copy()
                best_ssr = ssr
        
        gamma_j_star = best_gamma
        tau_squared[j] = best_ssr / n + best_lambda * np.sum(np.abs(gamma_j_star))

        # Step 5: Form the j-th row of Theta_hat
        Theta_hat[j, j] = 1 / tau_squared[j]
        off_diag = -gamma_j_star / tau_squared[j]
        Theta_hat[j, :j] = off_diag[:j]
        Theta_hat[j, j+1:] = off_diag[j:]
    
    # Step 6: Symmetrize
    Theta_hat_sym = (Theta_hat + Theta_hat.T) / 2
    
    return Theta_hat_sym


def gmv_weights(Theta_hat):
    """
    Compute Global Minimum Variance (GMV) portfolio weights (Section 6.1).
    
    Parameters:
    -----------
    Theta_hat : np.ndarray, shape (p, p)
        Precision matrix
    
    Returns:
    --------
    w_star : np.ndarray, shape (p,)
        Portfolio weights
    """
    p = Theta_hat.shape[0]
    ones_p = np.ones(p)
    
    # w* = (Θ 1_p) / (1_p' Θ 1_p)
    numerator = Theta_hat @ ones_p
    denominator = ones_p @ Theta_hat @ ones_p
    
    if np.abs(denominator) < 1e-10:
        # Fallback to equal weights if precision matrix is near-singular
        return ones_p / p
    
    w_star = numerator / denominator
    
    return w_star


def load_yearly_signals(year, buys_path_template='buys_{}.csv', sells_path_template='sells_{}.csv'):
    """
    Load buy and sell signals for a specific year.
    
    Parameters:
    -----------
    year : int
        Year to load signals for
    buys_path_template : str
        Template for buys file path (use {} for year placeholder)
    sells_path_template : str
        Template for sells file path (use {} for year placeholder)
    
    Returns:
    --------
    permno_set : set
        Set of permnos in the buy and sell signals for this year
    """
    try:
        buys = pd.read_csv(buys_path_template.format(year), index_col=1)
        sells = pd.read_csv(sells_path_template.format(year), index_col=1)
        
        buys.index.name = 'permno'
        sells.index.name = 'permno'
        
        buys_index = buys.index.astype(int)
        sells_index = sells.index.astype(int)
        
        return set(buys_index.union(sells_index))
    except FileNotFoundError as e:
        print(f"  ⚠ Warning: Could not load signals for year {year}: {e}")
        return set()


def load_analyst_recommendations(analyst_rec_path):
    """
    Load analyst recommendations from CSV file.
    
    Parameters:
    -----------
    analyst_rec_path : str
        Path to analyst recommendations CSV file
    
    Returns:
    --------
    analyst_df : pd.DataFrame
        DataFrame with columns: permno, date, ticker, mean_recommendation, num_recommendations
        Indexed by date
    """
    try:
        analyst_df = pd.read_csv(analyst_rec_path)
        analyst_df['date'] = pd.to_datetime(analyst_df['date'])
        analyst_df['permno'] = analyst_df['permno'].astype(int)
        return analyst_df
    except FileNotFoundError as e:
        print(f"  ⚠ Warning: Could not load analyst recommendations: {e}")
        return pd.DataFrame(columns=['permno', 'date', 'ticker', 'mean_recommendation', 'num_recommendations'])


def get_analyst_permnos_for_date(analyst_df, date, strong_buy_threshold=2.5, strong_sell_threshold=3.5):
    """
    Get set of permnos with strong buy or strong sell analyst recommendations for a specific date.
    
    Parameters:
    -----------
    analyst_df : pd.DataFrame
        Analyst recommendations dataframe
    date : pd.Timestamp
        Date to get recommendations for
    strong_buy_threshold : float
        Mean recommendation must be strictly less than this for strong buy (default: 2.0)
    strong_sell_threshold : float
        Mean recommendation must be strictly greater than this for strong sell (default: 4.0)
    
    Returns:
    --------
    permno_set : set
        Set of permnos with strong buy or strong sell recommendations on this date
    """
    date_recs = analyst_df[analyst_df['date'] == date]
    
    # Filter for strong buys (< 2) or strong sells (> 4)
    strong_recs = date_recs[
        (date_recs['mean_recommendation'] < strong_buy_threshold) | 
        (date_recs['mean_recommendation'] > strong_sell_threshold)
    ]
    
    return set(strong_recs['permno'].values)


def backtest_nodewise_gmv_yearly(df, 
                                  test_start_date='2020-01-31', 
                                  test_end_date='2024-11-30',
                                  lookback_window=180,
                                  transaction_cost=0.001,
                                  buys_path_template='buys_{}.csv',
                                  sells_path_template='sells_{}.csv',
                                  analyst_rec_path=None,
                                  verbose=True):
    """
    Backtest Nodewise + GMV strategy with year-specific buy/sell signals 
    and analyst recommendations.
    
    Parameters:
    -----------
    df : pd.DataFrame
        DataFrame with columns: permno, datadate, ret_fwd_1
    test_start_date : str
        First date for out-of-sample returns (format: 'YYYY-MM-DD')
    test_end_date : str
        Last date for out-of-sample returns (format: 'YYYY-MM-DD')
    lookback_window : int
        Number of months in rolling training window (default: 180)
    transaction_cost : float
        Proportional transaction cost (default: 0.001 = 10 bps)
    buys_path_template : str
        Template for buys file path (use {} for year placeholder)
    sells_path_template : str
        Template for sells file path (use {} for year placeholder)
    analyst_rec_path : str or None
        Path to analyst recommendations CSV file. If None, only uses buy/sell signals.
    verbose : bool
        If True, prints detailed log at each time step.
    
    Returns:
    --------
    results_df : pd.DataFrame
        DataFrame with columns: date, portfolio_return, cumulative_return
    metrics : dict
        Overall performance metrics
    """
    # --- 1. Setup ---
    df = df.copy()
    if 'datadate' not in df.columns or 'permno' not in df.columns:
        raise ValueError("DataFrame must have 'datadate' and 'permno' columns")
    df['datadate'] = pd.to_datetime(df['datadate'])
    
    # Load analyst recommendations if provided
    analyst_df = None
    if analyst_rec_path is not None:
        analyst_df = load_analyst_recommendations(analyst_rec_path)
        if verbose and len(analyst_df) > 0:
            print(f"Loaded analyst recommendations: {len(analyst_df)} records")
    
    # Get unique dates
    all_dates = sorted(df['datadate'].unique())
    
    # Convert test dates to datetime
    test_start_dt = pd.to_datetime(test_start_date)
    test_end_dt = pd.to_datetime(test_end_date)
    
    # Find date indices
    try:
        test_start_idx = all_dates.index(test_start_dt)
        test_end_idx = all_dates.index(test_end_dt)
    except ValueError as e:
        raise ValueError(f"Date not found in DataFrame: {e}")
    
    if test_start_idx < lookback_window:
        raise ValueError(f"Not enough data for lookback. Test start date {test_start_date} "
                         f"requires data back to {all_dates[test_start_idx - lookback_window]}, "
                         f"but only {test_start_idx} periods are available.")
    
    # Storage for results
    portfolio_returns = []
    portfolio_dates = []
    portfolio_weights_list = []
    portfolio_turnover_list = []
    portfolio_gross_returns = []
    
    # Track weights by permno
    prev_weights_dict = {}
    prev_oos_returns_dict = {}
    prev_gross_return = 0.0
    
    # Cache for yearly signals
    yearly_signals_cache = {}
    
    # --- 2. Rolling Window Backtest ---
    if verbose:
        print("="*60)
        print("STARTING BACKTEST WITH YEARLY SIGNALS + ANALYST RECS")
        print("="*60)
        
    for t in range(test_start_idx, test_end_idx + 1):
        current_date = all_dates[t]
        current_year = current_date.year
        
        # Load signals for current year if not cached
        if current_year not in yearly_signals_cache:
            yearly_signals_cache[current_year] = load_yearly_signals(
                current_year, buys_path_template, sells_path_template
            )
        
        buysell_permnos = yearly_signals_cache[current_year]
        
        # Get analyst recommendations for current date
        analyst_permnos = set()
        if analyst_df is not None and len(analyst_df) > 0:
            analyst_permnos = get_analyst_permnos_for_date(analyst_df, current_date)
        
        # UNION of buy/sell signals and analyst recommendations
        allowed_permnos = buysell_permnos.intersection(analyst_permnos)
        
        if len(allowed_permnos) == 0:
            if verbose:
                print(f"\n[{t - test_start_idx + 1}/{test_end_idx - test_start_idx + 1}] "
                      f"Date: {current_date.strftime('%Y-%m-%d')}")
                print(f"  ⚠ No signals or analyst recs for {current_date.strftime('%Y-%m-%d')}, skipping period")
            continue
        
        # Define the lookback window
        window_start_date = all_dates[t - lookback_window]
        window_end_date = all_dates[t - 1]
        
        # Get training data for this window, filtered by allowed permnos
        train_data = df[(df['datadate'] >= window_start_date) & 
                        (df['datadate'] <= window_end_date) &
                        (df['permno'].isin(allowed_permnos))]
        
        # Pivot to get returns matrix (time x assets)
        returns_pivot = train_data.pivot(index='datadate', columns='permno', values='ret_fwd_1')
        
        # Reindex to ensure all dates are present
        window_dates = all_dates[t - lookback_window : t]
        returns_pivot = returns_pivot.reindex(index=window_dates)
        
        # Filter assets with any NaNs in this window
        nan_assets = returns_pivot.columns[returns_pivot.isna().any()]
        filtered_pivot = returns_pivot.drop(columns=nan_assets)
        
        current_assets = filtered_pivot.columns.tolist()
        Y = filtered_pivot.values
        n_train, p_current = Y.shape

        if verbose:
            print(f"\n[{t - test_start_idx + 1}/{test_end_idx - test_start_idx + 1}] "
                  f"Date: {current_date.strftime('%Y-%m-%d')} | Year: {current_year}")
            print(f"  Window: {window_start_date.strftime('%Y-%m-%d')} to "
                  f"{window_end_date.strftime('%Y-%m-%d')}")
            print(f"  Buy/Sell: {len(buysell_permnos)} | Analyst: {len(analyst_permnos)} | "
                  f"Intersection: {len(allowed_permnos)} | Assets w/ data: {p_current}")

        # Check for valid data
        if n_train < lookback_window or p_current < 2:
            if verbose:
                print(f"  ⚠ Insufficient data (n={n_train}, p={p_current}), using prev weights")
            # Filter previous weights to only allowed permnos
            new_weights_dict = {k: v for k, v in prev_weights_dict.items() if k in allowed_permnos}
        else:
            try:
                # Demean the returns
                Y_bar = Y.mean(axis=0)
                Y_star = Y - Y_bar
                
                if verbose:
                    print(f"  Running Nodewise Regression...")
                Theta_hat = naive_nodewise_regression(Y_star)
                
                if verbose:
                    print(f"  Computing GMV weights...")
                w_star = gmv_weights(Theta_hat)
                
                # Create weights dictionary
                new_weights_dict = {asset: w_star[i] for i, asset in enumerate(current_assets)}
                
            except Exception as e:
                if verbose:
                    print(f"  ✗ Error: {e}")
                    print(f"  Using previous weights")
                # Filter previous weights to only allowed permnos
                new_weights_dict = {k: v for k, v in prev_weights_dict.items() if k in allowed_permnos}

        # Normalize weights to sum to 1
        weight_sum = sum(new_weights_dict.values())
        if weight_sum > 1e-10:
            new_weights_dict = {k: v/weight_sum for k, v in new_weights_dict.items()}
        else:
            if verbose:
                print("  ⚠ Zero weight sum, using previous weights")
            new_weights_dict = {k: v for k, v in prev_weights_dict.items() if k in allowed_permnos}
            weight_sum = sum(new_weights_dict.values())
            if weight_sum > 1e-10:
                new_weights_dict = {k: v/weight_sum for k, v in new_weights_dict.items()}
        
        # --- 3. OOS Returns & Transaction Costs ---
        
        # Get out-of-sample returns for current month (only for allowed permnos)
        oos_data = df[(df['datadate'] == current_date) & (df['permno'].isin(allowed_permnos))]
        oos_returns_series = oos_data.set_index('permno')['ret_fwd_1']
        
        # Filter out NaN returns
        oos_returns_series = oos_returns_series.dropna()
        oos_returns_dict = oos_returns_series.to_dict()
        
        # Find common assets between weights and returns
        common_assets = set(new_weights_dict.keys()) & set(oos_returns_dict.keys())
        
        if len(common_assets) == 0:
            if verbose:
                print("  ⚠ No common assets with valid returns, skipping period")
            continue
        
        # Filter to common assets and renormalize
        common_weights = {a: new_weights_dict[a] for a in common_assets}
        common_weight_sum = sum(common_weights.values())
        if common_weight_sum > 1e-10:
            common_weights = {k: v/common_weight_sum for k, v in common_weights.items()}
        else:
            if verbose:
                print("  ⚠ Zero weight sum after filtering, skipping period")
            continue
        
        # Compute gross portfolio return
        gross_return = sum(common_weights[a] * oos_returns_dict[a] for a in common_assets)
        
        # Sanity check
        if np.isnan(gross_return) or np.isinf(gross_return):
            if verbose:
                print(f"  ⚠ Invalid gross return: {gross_return}, skipping period")
            continue
        
        # Calculate transaction costs
        if len(prev_weights_dict) > 0:
            all_traded_assets = set(common_weights.keys()) | set(prev_weights_dict.keys())
            
            # Adjust previous weights
            adjusted_prev = {}
            for asset in all_traded_assets:
                prev_w = prev_weights_dict.get(asset, 0.0)
                
                if asset in prev_oos_returns_dict:
                    prev_r = prev_oos_returns_dict[asset]
                    if prev_gross_return > -0.99:
                        adjusted_prev[asset] = prev_w * (1 + prev_r) / (1 + prev_gross_return)
                    else:
                        adjusted_prev[asset] = 0.0
                else:
                    adjusted_prev[asset] = 0.0
            
            # Renormalize adjusted weights
            adj_sum = sum(adjusted_prev.get(a, 0.0) for a in common_weights.keys())
            if adj_sum > 1e-10:
                adjusted_prev_normalized = {k: adjusted_prev.get(k, 0.0)/adj_sum 
                                           for k in common_weights.keys()}
            else:
                adjusted_prev_normalized = {k: 0.0 for k in common_weights.keys()}
            
            # Turnover
            turnover = sum(abs(common_weights.get(a, 0.0) - adjusted_prev_normalized.get(a, 0.0)) 
                          for a in all_traded_assets)
            
            # Transaction cost
            tc = transaction_cost * (1 + gross_return) * turnover
        else:
            # First period
            turnover = sum(abs(w) for w in common_weights.values())
            tc = transaction_cost * turnover
        
        # Net return
        net_return = gross_return - tc
        
        # Store results
        portfolio_returns.append(net_return)
        portfolio_dates.append(current_date)
        portfolio_weights_list.append(common_weights.copy())
        portfolio_turnover_list.append(turnover)
        portfolio_gross_returns.append(gross_return)
        
        # Update previous values for next iteration
        prev_weights_dict = common_weights.copy()
        prev_oos_returns_dict = {a: oos_returns_dict[a] for a in common_assets}
        prev_gross_return = gross_return
        
        if verbose:
            print(f"  Gross: {gross_return:>8.5f} | Turnover: {turnover:>6.4f} | "
                  f"TC: {tc:>8.6f} | Net: {net_return:>8.5f}")

    if verbose:
        print("\n" + "="*60)
        print("BACKTEST COMPLETE")
        print("="*60)
    
    # --- 4. Compile Results ---
    results_df = pd.DataFrame({
        'date': portfolio_dates,
        'portfolio_return': portfolio_returns,
        'portfolio_gross_return': portfolio_gross_returns,
        'portfolio_weights': portfolio_weights_list,
        'portfolio_turnover': portfolio_turnover_list
    })
    results_df['cumulative_return'] = (1 + results_df['portfolio_return']).cumprod() - 1
    
    # Compute overall metrics
    if len(portfolio_returns) > 0:
        mean_return = np.mean(portfolio_returns)
        variance = np.var(portfolio_returns, ddof=1)
        sharpe_ratio = mean_return / np.sqrt(variance) if variance > 0 else 0
        
        # Annualized metrics (monthly data)
        annual_return = mean_return * 12
        annual_volatility = np.sqrt(variance * 12)
        annual_sharpe = annual_return / annual_volatility if annual_volatility > 0 else 0
        
        metrics = {
            'mean_return': mean_return,
            'variance': variance,
            'sharpe_ratio': sharpe_ratio,
            'annual_return': annual_return,
            'annual_volatility': annual_volatility,
            'annual_sharpe_ratio': annual_sharpe,
            'total_return': results_df['cumulative_return'].iloc[-1],
            'avg_turnover': np.mean(portfolio_turnover_list),
            'n_periods': len(portfolio_returns)
        }
    else:
        metrics = {
            'mean_return': 0,
            'variance': 0,
            'sharpe_ratio': 0,
            'annual_return': 0,
            'annual_volatility': 0,
            'annual_sharpe_ratio': 0,
            'total_return': 0,
            'avg_turnover': 0,
            'n_periods': 0
        }
    
    return results_df, metrics

# %%
df = pd.read_csv('../green cleaned.csv', dtype={'ncusip': 'string'})
df['ret_fwd_1'] = df.groupby('permno')['ret_excess'].shift(-1)

results_df, metrics = backtest_nodewise_gmv_yearly(
    df=df,
    test_start_date='2020-01-31',
    test_end_date='2024-11-30',
    lookback_window=180,
    transaction_cost=0.001,
    buys_path_template='buys_{}.csv',
    sells_path_template='sells_{}.csv',
    analyst_rec_path='monthly_mean_recommendations.csv',  # <-- Add this
    verbose=True
)

print(f"\nSharpe Ratio: {metrics['sharpe_ratio']:.4f}")
print(f"Annualized Sharpe Ratio: {metrics['annual_sharpe_ratio']:.4f}")
print(f"Total Return: {metrics['total_return']:.4f}")
print(f"Average Turnover: {metrics['avg_turnover']:.4f}")
# Out:
# Loaded analyst recommendations: 16559 records
# ============================================================
# STARTING BACKTEST WITH YEARLY SIGNALS + ANALYST RECS
# ============================================================
#
# [1/59] Date: 2020-01-31 | Year: 2020
#   Window: 2005-01-31 to 2019-12-31
#   Buy/Sell: 40 | Analyst: 186 | Intersection: 17 | Assets w/ data: 14
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.11425 | Turnover: 1.0467 | TC: 0.001047 | Net: -0.11530
#
# [2/59] Date: 2020-02-29 | Year: 2020
#   Window: 2005-02-28 to 2020-01-31
#   Buy/Sell: 40 | Analyst: 95 | Intersection: 5 | Assets w/ data: 3
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.16653 | Turnover: 2.8857 | TC: 0.002405 | Net: -0.16894
#
# [3/59] Date: 2020-03-31 | Year: 2020
#   Window: 2005-03-31 to 2020-02-29
#   Buy/Sell: 40 | Analyst: 216 | Intersection: 16 | Assets w/ data: 13
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.13267 | Turnover: 1.9819 | TC: 0.002245 | Net:  0.13043
#
# [4/59] Date: 2020-04-30 | Year: 2020
#   Window: 2005-04-30 to 2020-03-31
#   Buy/Sell: 40 | Analyst: 193 | Intersection: 16 | Assets w/ data: 14
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.00810 | Turnover: 1.6811 | TC: 0.001695 | Net:  0.00640
#
# [5/59] Date: 2020-05-31 | Year: 2020
#   Window: 2005-05-31 to 2020-04-30
#   Buy/Sell: 40 | Analyst: 139 | Intersection: 8 | Assets w/ data: 7
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.04373 | Turnover: 0.7800 | TC: 0.000746 | Net: -0.04447
#
# [6/59] Date: 2020-06-30 | Year: 2020
#   Window: 2005-06-30 to 2020-05-31
#   Buy/Sell: 40 | Analyst: 156 | Intersection: 13 | Assets w/ data: 10
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.01995 | Turnover: 2.0453 | TC: 0.002086 | Net:  0.01786
#
# [7/59] Date: 2020-07-31 | Year: 2020
#   Window: 2005-07-31 to 2020-06-30
#   Buy/Sell: 40 | Analyst: 170 | Intersection: 17 | Assets w/ data: 13
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03403 | Turnover: 1.2695 | TC: 0.001313 | Net:  0.03272
#
# [8/59] Date: 2020-08-31 | Year: 2020
#   Window: 2005-08-31 to 2020-07-31
#   Buy/Sell: 40 | Analyst: 91 | Intersection: 4 | Assets w/ data: 4
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.04232 | Turnover: 1.0327 | TC: 0.000989 | Net: -0.04331
#
# [9/59] Date: 2020-09-30 | Year: 2020
#   Window: 2005-09-30 to 2020-08-31
#   Buy/Sell: 40 | Analyst: 164 | Intersection: 15 | Assets w/ data: 9
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.01501 | Turnover: 1.6675 | TC: 0.001693 | Net:  0.01332
#
# [10/59] Date: 2020-10-31 | Year: 2020
#   Window: 2005-10-31 to 2020-09-30
#   Buy/Sell: 40 | Analyst: 137 | Intersection: 9 | Assets w/ data: 6
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.15585 | Turnover: 1.7075 | TC: 0.001974 | Net:  0.15388
#
# [11/59] Date: 2020-11-30 | Year: 2020
#   Window: 2005-11-30 to 2020-10-31
#   Buy/Sell: 40 | Analyst: 149 | Intersection: 14 | Assets w/ data: 10
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02310 | Turnover: 1.1006 | TC: 0.001126 | Net:  0.02197
#
# [12/59] Date: 2020-12-31 | Year: 2020
#   Window: 2005-12-31 to 2020-11-30
#   Buy/Sell: 40 | Analyst: 156 | Intersection: 8 | Assets w/ data: 6
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02168 | Turnover: 1.0000 | TC: 0.001022 | Net:  0.02066
#
# [13/59] Date: 2021-01-31 | Year: 2021
#   Window: 2006-01-31 to 2020-12-31
#   Buy/Sell: 123 | Analyst: 215 | Intersection: 50 | Assets w/ data: 30
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.08643 | Turnover: 1.1655 | TC: 0.001266 | Net:  0.08516
#
# [14/59] Date: 2021-02-28 | Year: 2021
#   Window: 2006-02-28 to 2021-01-31
#   Buy/Sell: 123 | Analyst: 143 | Intersection: 38 | Assets w/ data: 24
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.07712 | Turnover: 1.5794 | TC: 0.001701 | Net:  0.07542
#
# [15/59] Date: 2021-03-31 | Year: 2021
#   Window: 2006-03-31 to 2021-02-28
#   Buy/Sell: 123 | Analyst: 164 | Intersection: 33 | Assets w/ data: 19
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.04632 | Turnover: 1.6803 | TC: 0.001758 | Net:  0.04456
#
# [16/59] Date: 2021-04-30 | Year: 2021
#   Window: 2006-04-30 to 2021-03-31
#   Buy/Sell: 123 | Analyst: 151 | Intersection: 39 | Assets w/ data: 23
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.05240 | Turnover: 1.7150 | TC: 0.001805 | Net:  0.05059
#
# [17/59] Date: 2021-05-31 | Year: 2021
#   Window: 2006-05-31 to 2021-04-30
#   Buy/Sell: 123 | Analyst: 144 | Intersection: 35 | Assets w/ data: 17
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.00071 | Turnover: 1.4270 | TC: 0.001428 | Net: -0.00072
#
# [18/59] Date: 2021-06-30 | Year: 2021
#   Window: 2006-06-30 to 2021-05-31
#   Buy/Sell: 123 | Analyst: 143 | Intersection: 36 | Assets w/ data: 16
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.01142 | Turnover: 1.8680 | TC: 0.001889 | Net:  0.00953
#
# [19/59] Date: 2021-07-31 | Year: 2021
#   Window: 2006-07-31 to 2021-06-30
#   Buy/Sell: 123 | Analyst: 132 | Intersection: 26 | Assets w/ data: 19
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.00777 | Turnover: 1.5585 | TC: 0.001546 | Net: -0.00932
#
# [20/59] Date: 2021-08-31 | Year: 2021
#   Window: 2006-08-31 to 2021-07-31
#   Buy/Sell: 123 | Analyst: 104 | Intersection: 21 | Assets w/ data: 16
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.03836 | Turnover: 1.4953 | TC: 0.001438 | Net: -0.03980
#
# [21/59] Date: 2021-09-30 | Year: 2021
#   Window: 2006-09-30 to 2021-08-31
#   Buy/Sell: 123 | Analyst: 122 | Intersection: 27 | Assets w/ data: 17
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.07265 | Turnover: 1.7287 | TC: 0.001854 | Net:  0.07079
#
# [22/59] Date: 2021-10-31 | Year: 2021
#   Window: 2006-10-31 to 2021-09-30
#   Buy/Sell: 123 | Analyst: 168 | Intersection: 36 | Assets w/ data: 20
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.02611 | Turnover: 1.5818 | TC: 0.001541 | Net: -0.02765
#
# [23/59] Date: 2021-11-30 | Year: 2021
#   Window: 2006-11-30 to 2021-10-31
#   Buy/Sell: 123 | Analyst: 178 | Intersection: 38 | Assets w/ data: 23
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.05178 | Turnover: 1.3430 | TC: 0.001413 | Net:  0.05037
#
# [24/59] Date: 2021-12-31 | Year: 2021
#   Window: 2006-12-31 to 2021-11-30
#   Buy/Sell: 123 | Analyst: 130 | Intersection: 32 | Assets w/ data: 18
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.02129 | Turnover: 1.7264 | TC: 0.001690 | Net: -0.02298
#
# [25/59] Date: 2022-01-31 | Year: 2022
#   Window: 2007-01-31 to 2021-12-31
#   Buy/Sell: 34 | Analyst: 185 | Intersection: 14 | Assets w/ data: 11
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.01962 | Turnover: 1.0000 | TC: 0.000980 | Net: -0.02060
#
# [26/59] Date: 2022-02-28 | Year: 2022
#   Window: 2007-02-28 to 2022-01-31
#   Buy/Sell: 34 | Analyst: 126 | Intersection: 11 | Assets w/ data: 8
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.06365 | Turnover: 1.1118 | TC: 0.001183 | Net:  0.06247
#
# [27/59] Date: 2022-03-31 | Year: 2022
#   Window: 2007-03-31 to 2022-02-28
#   Buy/Sell: 34 | Analyst: 127 | Intersection: 13 | Assets w/ data: 8
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.05386 | Turnover: 1.4250 | TC: 0.001348 | Net: -0.05520
#
# [28/59] Date: 2022-04-30 | Year: 2022
#   Window: 2007-04-30 to 2022-03-31
#   Buy/Sell: 34 | Analyst: 130 | Intersection: 7 | Assets w/ data: 4
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.08000 | Turnover: 1.3429 | TC: 0.001450 | Net:  0.07855
#
# [29/59] Date: 2022-05-31 | Year: 2022
#   Window: 2007-05-31 to 2022-04-30
#   Buy/Sell: 34 | Analyst: 121 | Intersection: 9 | Assets w/ data: 6
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.04157 | Turnover: 1.4735 | TC: 0.001412 | Net: -0.04298
#
# [30/59] Date: 2022-06-30 | Year: 2022
#   Window: 2007-06-30 to 2022-05-31
#   Buy/Sell: 34 | Analyst: 122 | Intersection: 9 | Assets w/ data: 4
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.07371 | Turnover: 1.0000 | TC: 0.001074 | Net:  0.07264
#
# [31/59] Date: 2022-07-31 | Year: 2022
#   Window: 2007-07-31 to 2022-06-30
#   Buy/Sell: 34 | Analyst: 133 | Intersection: 11 | Assets w/ data: 4
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.05620 | Turnover: 1.0000 | TC: 0.000944 | Net: -0.05715
#
# [32/59] Date: 2022-08-31 | Year: 2022
#   Window: 2007-08-31 to 2022-07-31
#   Buy/Sell: 34 | Analyst: 119 | Intersection: 9 | Assets w/ data: 4
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.13412 | Turnover: 1.4807 | TC: 0.001282 | Net: -0.13540
#
# [33/59] Date: 2022-09-30 | Year: 2022
#   Window: 2007-09-30 to 2022-08-31
#   Buy/Sell: 34 | Analyst: 103 | Intersection: 6 | Assets w/ data: 4
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.09272 | Turnover: 1.8274 | TC: 0.001997 | Net:  0.09072
#
# [34/59] Date: 2022-10-31 | Year: 2022
#   Window: 2007-10-31 to 2022-09-30
#   Buy/Sell: 34 | Analyst: 138 | Intersection: 11 | Assets w/ data: 8
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.11187 | Turnover: 1.9696 | TC: 0.002190 | Net:  0.10968
#
# [35/59] Date: 2022-11-30 | Year: 2022
#   Window: 2007-11-30 to 2022-10-31
#   Buy/Sell: 34 | Analyst: 112 | Intersection: 9 | Assets w/ data: 7
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.03446 | Turnover: 1.4931 | TC: 0.001442 | Net: -0.03590
#
# [36/59] Date: 2022-12-31 | Year: 2022
#   Window: 2007-12-31 to 2022-11-30
#   Buy/Sell: 34 | Analyst: 100 | Intersection: 5 | Assets w/ data: 2
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.08385 | Turnover: 1.0000 | TC: 0.001084 | Net:  0.08276
#
# [37/59] Date: 2023-01-31 | Year: 2023
#   Window: 2008-01-31 to 2022-12-31
#   Buy/Sell: 137 | Analyst: 148 | Intersection: 31 | Assets w/ data: 17
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.03150 | Turnover: 1.8820 | TC: 0.001823 | Net: -0.03333
#
# [38/59] Date: 2023-02-28 | Year: 2023
#   Window: 2008-02-29 to 2023-01-31
#   Buy/Sell: 137 | Analyst: 110 | Intersection: 29 | Assets w/ data: 12
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.06611 | Turnover: 0.9622 | TC: 0.000899 | Net: -0.06701
#
# [39/59] Date: 2023-03-31 | Year: 2023
#   Window: 2008-03-31 to 2023-02-28
#   Buy/Sell: 137 | Analyst: 142 | Intersection: 36 | Assets w/ data: 13
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02607 | Turnover: 1.7936 | TC: 0.001840 | Net:  0.02423
#
# [40/59] Date: 2023-04-30 | Year: 2023
#   Window: 2008-04-30 to 2023-03-31
#   Buy/Sell: 137 | Analyst: 143 | Intersection: 39 | Assets w/ data: 17
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.07587 | Turnover: 1.8872 | TC: 0.001744 | Net: -0.07761
#
# [41/59] Date: 2023-05-31 | Year: 2023
#   Window: 2008-05-31 to 2023-04-30
#   Buy/Sell: 137 | Analyst: 126 | Intersection: 29 | Assets w/ data: 12
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.05702 | Turnover: 1.6136 | TC: 0.001706 | Net:  0.05532
#
# [42/59] Date: 2023-06-30 | Year: 2023
#   Window: 2008-06-30 to 2023-05-31
#   Buy/Sell: 137 | Analyst: 99 | Intersection: 28 | Assets w/ data: 15
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.05425 | Turnover: 1.7361 | TC: 0.001830 | Net:  0.05242
#
# [43/59] Date: 2023-07-31 | Year: 2023
#   Window: 2008-07-31 to 2023-06-30
#   Buy/Sell: 137 | Analyst: 119 | Intersection: 29 | Assets w/ data: 14
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.04038 | Turnover: 1.1874 | TC: 0.001139 | Net: -0.04152
#
# [44/59] Date: 2023-08-31 | Year: 2023
#   Window: 2008-08-31 to 2023-07-31
#   Buy/Sell: 137 | Analyst: 147 | Intersection: 36 | Assets w/ data: 20
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.05977 | Turnover: 1.4090 | TC: 0.001325 | Net: -0.06109
#
# [45/59] Date: 2023-09-30 | Year: 2023
#   Window: 2008-09-30 to 2023-08-31
#   Buy/Sell: 137 | Analyst: 140 | Intersection: 31 | Assets w/ data: 13
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.03468 | Turnover: 0.9411 | TC: 0.000908 | Net: -0.03559
#
# [46/59] Date: 2023-10-31 | Year: 2023
#   Window: 2008-10-31 to 2023-09-30
#   Buy/Sell: 137 | Analyst: 171 | Intersection: 43 | Assets w/ data: 20
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.06453 | Turnover: 1.4690 | TC: 0.001564 | Net:  0.06297
#
# [47/59] Date: 2023-11-30 | Year: 2023
#   Window: 2008-11-30 to 2023-10-31
#   Buy/Sell: 137 | Analyst: 159 | Intersection: 35 | Assets w/ data: 17
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.01307 | Turnover: 1.2960 | TC: 0.001313 | Net:  0.01176
#
# [48/59] Date: 2023-12-31 | Year: 2023
#   Window: 2008-12-31 to 2023-11-30
#   Buy/Sell: 137 | Analyst: 170 | Intersection: 42 | Assets w/ data: 20
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.01380 | Turnover: 2.2503 | TC: 0.002281 | Net:  0.01152
#
# [49/59] Date: 2024-01-31 | Year: 2024
#   Window: 2009-01-31 to 2023-12-31
#   Buy/Sell: 281 | Analyst: 149 | Intersection: 68 | Assets w/ data: 38
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.01446 | Turnover: 4.5773 | TC: 0.004643 | Net:  0.00982
#
# [50/59] Date: 2024-02-29 | Year: 2024
#   Window: 2009-02-28 to 2024-01-31
#   Buy/Sell: 281 | Analyst: 141 | Intersection: 74 | Assets w/ data: 38
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.04092 | Turnover: 1.3391 | TC: 0.001394 | Net:  0.03953
#
# [51/59] Date: 2024-03-31 | Year: 2024
#   Window: 2009-03-31 to 2024-02-29
#   Buy/Sell: 281 | Analyst: 131 | Intersection: 61 | Assets w/ data: 37
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.04115 | Turnover: 1.5331 | TC: 0.001470 | Net: -0.04262
#
# [52/59] Date: 2024-04-30 | Year: 2024
#   Window: 2009-04-30 to 2024-03-31
#   Buy/Sell: 281 | Analyst: 144 | Intersection: 60 | Assets w/ data: 37
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02836 | Turnover: 1.4112 | TC: 0.001451 | Net:  0.02690
#
# [53/59] Date: 2024-05-31 | Year: 2024
#   Window: 2009-05-31 to 2024-04-30
#   Buy/Sell: 281 | Analyst: 133 | Intersection: 68 | Assets w/ data: 29
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.01704 | Turnover: 1.7458 | TC: 0.001716 | Net: -0.01875
#
# [54/59] Date: 2024-06-30 | Year: 2024
#   Window: 2009-06-30 to 2024-05-31
#   Buy/Sell: 281 | Analyst: 134 | Intersection: 66 | Assets w/ data: 33
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.05518 | Turnover: 1.3829 | TC: 0.001459 | Net:  0.05372
#
# [55/59] Date: 2024-07-31 | Year: 2024
#   Window: 2009-07-31 to 2024-06-30
#   Buy/Sell: 281 | Analyst: 199 | Intersection: 92 | Assets w/ data: 45
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.02928 | Turnover: 1.7904 | TC: 0.001843 | Net:  0.02744
#
# [56/59] Date: 2024-08-31 | Year: 2024
#   Window: 2009-08-31 to 2024-07-31
#   Buy/Sell: 281 | Analyst: 130 | Intersection: 73 | Assets w/ data: 41
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.01821 | Turnover: 1.6967 | TC: 0.001728 | Net:  0.01648
#
# [57/59] Date: 2024-09-30 | Year: 2024
#   Window: 2009-09-30 to 2024-08-31
#   Buy/Sell: 281 | Analyst: 134 | Intersection: 62 | Assets w/ data: 39
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.01939 | Turnover: 1.9421 | TC: 0.001904 | Net: -0.02129
#
# [58/59] Date: 2024-10-31 | Year: 2024
#   Window: 2009-10-31 to 2024-09-30
#   Buy/Sell: 281 | Analyst: 146 | Intersection: 78 | Assets w/ data: 46
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross:  0.03816 | Turnover: 1.1697 | TC: 0.001214 | Net:  0.03695
#
# [59/59] Date: 2024-11-30 | Year: 2024
#   Window: 2009-11-30 to 2024-10-31
#   Buy/Sell: 281 | Analyst: 123 | Intersection: 55 | Assets w/ data: 36
#   Running Nodewise Regression...
#   Computing GMV weights...
#   Gross: -0.07932 | Turnover: 1.1469 | TC: 0.001056 | Net: -0.08037
#
# ============================================================
# BACKTEST COMPLETE
# ============================================================
#
# Sharpe Ratio: 0.1104
# Annualized Sharpe Ratio: 0.3825
# Total Return: 0.3412
# Average Turnover: 1.5484
