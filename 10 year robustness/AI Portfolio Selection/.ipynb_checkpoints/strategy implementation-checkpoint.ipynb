# %%
# 2020:
# BUY RULE:
# if (bm > 0.85 AND mom12m > -0.4 AND mve > -0.75):
#     signal = BUY

# SELL RULE:
# if (bm < -0.75 AND mom12m < -0.55 AND mve < 0.0):
#     signal = SELL

# 2021:
# BUY RULE:
# if bm > 0.75 AND mom12m > 0.75 AND mve > -0.5:
#     signal = BUY

# SELL RULE:
# if bm < -1.0 OR mom12m < -1.0:
#     signal = SELL

# 2022:
# if bm < -0.65 AND mom12m > 0.65 AND mve > -0.5:
#     signal = BUY

# SELL RULE:
# if bm > 0.65 AND mom12m < -0.65:
#     signal = SELL

#2023:
# if (bm > 0.8 AND mom12m > 0.6) OR (mve < 0.2 AND bm > 1.1):
#     signal = BUY

# SELL RULE:
# if mom12m < -1.1 OR bm < -1.1:
#     signal = SELL

# 2024:
# if bm > 0.95 AND mve > 0.3 AND mom12m > -0.5:
#     signal = BUY

# SELL RULE:
# if (bm < -0.75 OR mom12m < -0.55 OR mve < -0.75) AND NOT (mom12m > 1.5):
#     signal = SELL

# 2019:
# BUY RULE:
# if (bm > 0.85 AND mom12m > -0.50) OR (bm > -0.25 AND mve > 1.25):
#     signal = BUY

# SELL RULE:
# if (bm < -0.70 AND mom12m < 0.50) OR (mom12m < -1.05 AND mve < 0.50):
#     signal = SELL

# 2018:
# BUY RULE:
# if bm < -1.0 AND mom12m > 1.0 AND mve > 0.5:
#     signal = BUY

# SELL RULE:
# if bm > 0.75 AND mom12m < -0.75:
#     signal = SELL

# 2017:
# BUY RULE:
# if bm > 0.63 AND mom12m > 0.76:
#     signal = BUY

# SELL RULE:
# if bm < -0.75 AND mom12m < -0.75 AND mve < 0:
#     signal = SELL

# 2016:
# BUY RULE:
# if (bm > 0.85 AND mom12m > 0.35) OR (bm > 1.25 AND mve < -0.25):
#     signal = BUY

# SELL RULE:
# if (bm < -0.75 AND mom12m < -0.35) OR (mom12m < -1.5):
#     signal = SELL

# 2015:
# BUY RULE:
# if (bm > 0.65 AND mom12m > 0.75) OR (mve > 1.5 AND mom12m > 0.5):
#     signal = BUY

# SELL RULE:
# if (bm < -0.65 AND mom12m < -0.65) OR (mve < -1.5 AND mom12m < 0):
#     signal = SELL

# %%
import pandas as pd
import numpy as np

green_cleaned = pd.read_csv('../../green cleaned.csv', dtype={'ncusip': 'string'})
green_cleaned['ret_fwd_1'] = (green_cleaned.groupby('permno')['ret_excess'].shift(-1) )

# %%
variables = ['datadate', 'permno', 'ticker', 'comnam', 'bm', 'mom12m', 'mve', 'ret_fwd_1']

# %%
start_date = '2014-12-31'

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()

conditions = [
    # BUY: bm > 0.75 AND mom12m > 0.35 AND mve > -0.5
    ( (analysis_df['bm'] > 0.65) & (analysis_df['mom12m'] > 0.75) ) | ((analysis_df['mve'] > 1.5) & (analysis_df['mom12m'] > 0.5) ),
    
    # SELL: bm < -0.5 AND mom12m < -0.75
    ( (analysis_df['bm'] < -0.65) & (analysis_df['mom12m'] < -0.65) ) | ( (analysis_df['mve'] < -1.5) & (analysis_df['mom12m'] < 0) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2015.csv', index=False)
sells.to_csv('sells_2015.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                            comnam  ret_fwd_1
# 1084    2014-12-31   10107   MSFT                    MICROSOFT CORP  -0.130248
# 9949    2014-12-31   11552   CELG                      CELGENE CORP   0.065260
# 23583   2014-12-31   13407     FB                      FACEBOOK INC  -0.027044
# 24615   2014-12-31   13688    PCG                      P G & E CORP   0.104621
# 24713   2014-12-31   13721   ABBV                        ABBVIE INC  -0.070294
# 26344   2014-12-31   13901     MO                  ALTRIA GROUP INC   0.077735
# 27733   2014-12-31   14008   AMGN                         AMGEN INC  -0.044133
# 30860   2014-12-31   14593   AAPL                         APPLE INC   0.061424
# 37921   2014-12-31   15720    EIX              EDISON INTERNATIONAL   0.040776
# 42185   2014-12-31   17005    CVS                 C V S HEALTH CORP   0.022843
# 64564   2014-12-31   21186    MWV                 MEADWESTVACO CORP   0.132688
# 67707   2014-12-31   21776    EXC                       EXELON CORP  -0.028048
# 79420   2014-12-31   23501    POM                PEPCO HOLDINGS INC   0.019309
# 81116   2014-12-31   23712    PEG  PUBLIC SERVICE ENTERPRISE GP INC   0.030669
# 82205   2014-12-31   23887    FTR      FRONTIER COMMUNICATIONS CORP   0.006747
# 83821   2014-12-31   24010    ETR                  ENTERGY CORP NEW   0.000343
# 88558   2014-12-31   24643     AA                         ALCOA INC  -0.008866
# 92302   2014-12-31   25099    TEG         INTEGRYS ENERGY GROUP INC   0.041747
# 99006   2014-12-31   26403    DIS                    DISNEY WALT CO  -0.034292
# 105189  2014-12-31   27828    HPQ                HEWLETT PACKARD CO  -0.099676
# 150875  2014-12-31   48486   LRCX                     LAM RESH CORP  -0.036552
# 152265  2014-12-31   48653    HUM                        HUMANA INC   0.019564
# 152805  2014-12-31   48725    UNP                UNION PACIFIC CORP  -0.016117
# 165351  2014-12-31   53613     MU             MICRON TECHNOLOGY INC  -0.164096
# 177470  2014-12-31   59248    TAP           MOLSON COORS BREWING CO   0.018921
# 178116  2014-12-31   59328   INTC                        INTEL CORP  -0.089556
# 183349  2014-12-31   60599    CTL                   CENTURYLINK INC  -0.060889
# 195457  2014-12-31   65330     LM                    LEGG MASON INC   0.038786
# 199382  2014-12-31   66181     HD                    HOME DEPOT INC  -0.005240
# 219755  2014-12-31   77274   GILD               GILEAD SCIENCES INC   0.112137
# 223110  2014-12-31   77730    TSN                   TYSON FOODS INC  -0.026191
# 256727  2014-12-31   89179    WLP                     WELLPOINT INC   0.073924
# 268110  2014-12-31   92655    UNH            UNITEDHEALTH GROUP INC   0.051044
# 268500  2014-12-31   92988    CFN                   CAREFUSION CORP  -0.000674
#
# --- SELL ---
#           datadate  permno ticker                            comnam  ret_fwd_1
# 3476    2014-12-31   10299   LLTC            LINEAR TECHNOLOGY CORP  -0.014474
# 10582   2014-12-31   11618   FAST                       FASTENAL CO  -0.060555
# 15797   2014-12-31   12073   PBCT      PEOPLES UNITED FINANCIAL INC  -0.062253
# 18919   2014-12-31   12490    IBM  INTERNATIONAL BUSINESS MACHS COR  -0.044440
# 22923   2014-12-31   13168   TRIP                   TRIPADVISOR INC  -0.102465
# 40520   2014-12-31   16600    HSY                        HERSHEY CO  -0.016550
# 54048   2014-12-31   19166    FMC                        F M C CORP   0.008241
# 57286   2014-12-31   19561     BA                         BOEING CO   0.118403
# 75164   2014-12-31   22779    MSI            MOTOROLA SOLUTIONS INC  -0.069618
# 87311   2014-12-31   24459    PBI                  PITNEY BOWES INC  -0.016003
# 111991  2014-12-31   30940    FLS                    FLOWSERVE CORP  -0.089253
# 114605  2014-12-31   34032    MAS                        MASCO CORP  -0.010714
# 124282  2014-12-31   39538    MAT                        MATTEL INC  -0.130716
# 128183  2014-12-31   40416    AVP                 AVON PRODUCTS INC  -0.175719
# 128804  2014-12-31   40539    TJX           T J X COMPANIES INC NEW  -0.038495
# 135132  2014-12-31   43123    ATI            ALLEGHENY TECHNOLOGIES  -0.179465
# 136287  2014-12-31   43449    MCD                    MCDONALDS CORP  -0.013447
# 138587  2014-12-31   44601    AVY               AVERY DENNISON CORP   0.007517
# 156362  2014-12-31   50017    RRC              RANGE RESOURCES CORP  -0.134331
# 162735  2014-12-31   52695    GWW                  GRAINGER W W INC  -0.074738
# 175510  2014-12-31   59010    GPS                           GAP INC  -0.016623
# 201959  2014-12-31   68857    CVC          CABLEVISION SYSTEMS CORP  -0.083333
# 203119  2014-12-31   70033    HOG               HARLEY DAVIDSON INC  -0.063875
# 213775  2014-12-31   76082    COG              CABOT OIL & GAS CORP  -0.104357
# 214937  2014-12-31   76201   XLNX                        XILINX INC  -0.108917
# 219163  2014-12-31   77157     OI                     OWENS ILL INC  -0.134865
# 219983  2014-12-31   77281    WFM            WHOLE FOODS MARKET INC   0.035799
# 222877  2014-12-31   77702   SBUX                    STARBUCKS CORP   0.066789
# 223499  2014-12-31   77768     PX                       PRAXAIR INC  -0.069234
# 223682  2014-12-31   78034   PDCO           PATTERSON COMPANIES INC   0.045530
# 224982  2014-12-31   78987   MCHP          MICROCHIP TECHNOLOGY INC  -0.000222
# 225392  2014-12-31   79089   FOSL                  FOSSIL GROUP INC  -0.116850
# 226444  2014-12-31   79265   FLIR                  FLIR SYSTEMS INC  -0.065305
# 226901  2014-12-31   79411   PETM                      PETSMART INC   0.005043
# 228218  2014-12-31   79881   URBN              URBAN OUTFITTERS INC  -0.007686
# 234171  2014-12-31   82298     DO     DIAMOND OFFSHORE DRILLING INC  -0.141106
# 235235  2014-12-31   82642     EL              LAUDER ESTEE COS INC  -0.073622
# 240363  2014-12-31   84381    ROK           ROCKWELL AUTOMATION INC  -0.020504
# 241065  2014-12-31   84788   AMZN                    AMAZON COM INC   0.142355
# 242714  2014-12-31   85348    YUM                    YUM BRANDS INC  -0.002196
# 248475  2014-12-31   86783   PCLN               PRICELINE GROUP INC  -0.114654
# 250234  2014-12-31   87070   HCBK           HUDSON CITY BANCORP INC  -0.113636
# 253650  2014-12-31   88590    DNB     DUN & BRADSTREET CORP DEL NEW  -0.048363
# 253828  2014-12-31   88661    COH                         COACH INC  -0.009851
# 256546  2014-12-31   89105    JOY                    JOY GLOBAL INC  -0.098452
# 257700  2014-12-31   89301    GME                 GAMESTOP CORP NEW   0.042899
# 259808  2014-12-31   90038    AIZ                      ASSURANT INC  -0.071898
# 260367  2014-12-31   90162    GNW            GENWORTH FINANCIAL INC  -0.178824
# 262053  2014-12-31   90537     NE                    NOBLE CORP PLC  -0.021123
# 263772  2014-12-31   91063   VIAB                    VIACOM INC NEW  -0.143920
# 265741  2014-12-31   91611   FSLR                   FIRST SOLAR INC  -0.051015
# 269105  2014-12-31   93422    QEP               Q E P RESOURCES INC   0.000000

# %%
start_date = '2015-12-31'

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()

conditions = [
    # BUY: bm > 0.75 AND mom12m > 0.35 AND mve > -0.5
    ( (analysis_df['bm'] > 0.85) & (analysis_df['mom12m'] > 0.35) ) | ( (analysis_df['bm'] > 1.25) & (analysis_df['mve'] < -0.25) ),
    
    # SELL: bm < -0.5 AND mom12m < -0.75
    ( (analysis_df['bm'] < -0.75) & (analysis_df['mom12m'] < -0.35) ) | ( analysis_df['mom12m'] < -1.5 )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2016.csv', index=False)
sells.to_csv('sells_2016.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                            comnam  ret_fwd_1
# 15809   2015-12-31   12073   PBCT      PEOPLES UNITED FINANCIAL INC  -0.099945
# 17472   2015-12-31   12369     GM                 GENERAL MOTORS CO  -0.128592
# 24627   2015-12-31   13688    PCG                      P G & E CORP   0.032237
# 27302   2015-12-31   13963   NWSA                     NEWS CORP NEW  -0.029292
# 33899   2015-12-31   15069    MRO                 MARATHON OIL CORP  -0.227264
# 60648   2015-12-31   20415    LUK            LEUCADIA NATIONAL CORP  -0.047829
# 65110   2015-12-31   21207    NEM               NEWMONT MINING CORP   0.109405
# 76449   2015-12-31   23026     FE                  FIRSTENERGY CORP   0.041816
# 79179   2015-12-31   23473   CINF         CINCINNATI FINANCIAL CORP  -0.026127
# 40532   2015-12-31   16600    HSY                        HERSHEY CO  -0.013094
# 63262   2015-12-31   21020    AAL       AMERICAN AIRLINES GROUP INC  -0.079439
# 87323   2015-12-31   24459    PBI                  PITNEY BOWES INC  -0.051916
# 88570   2015-12-31   24643     AA                         ALCOA INC  -0.261498
# 92766   2015-12-31   25232    OKE                     ONEOK INC NEW   0.034977
# 156374  2015-12-31   50017    RRC              RANGE RESOURCES CORP   0.201038
# 161838  2015-12-31   52337    THC             TENET HEALTHCARE CORP  -0.105050
# 165363  2015-12-31   53613     MU             MICRON TECHNOLOGY INC  -0.221145
# 168386  2015-12-31   55976    WMT               WAL MART STORES INC   0.082445
# 190731  2015-12-31   63765    SWN            SOUTHWESTERN ENERGY CO   0.250252
# 199770  2015-12-31   66384    WDC              WESTERN DIGITAL CORP  -0.201099
# 202502  2015-12-31   69550    MYL                         MYLAN N V  -0.025623
# 213787  2015-12-31   76082    COG              CABOT OIL & GAS CORP   0.174010
# 219995  2015-12-31   77281    WFM            WHOLE FOODS MARKET INC  -0.121145
# 223511  2015-12-31   77768     PX                       PRAXAIR INC  -0.023538
# 225404  2015-12-31   79089   FOSL                  FOSSIL GROUP INC        NaN
# 227392  2015-12-31   79588   GMCR         KEURIG GREEN MOUNTAIN INC  -0.004601
# 231806  2015-12-31   81061    MCK              MCKESSON H B O C INC  -0.183896
# 236652  2015-12-31   83111   ALXN       ALEXION PHARMACEUTICALS INC  -0.235067
# 236802  2015-12-31   83143    IRM             IRON MOUNTAIN INC NEW   0.019522
# 241760  2015-12-31   85072     RL                 RALPH LAUREN CORP   0.009050
# 243941  2015-12-31   85663    URI                UNITED RENTALS INC  -0.339637
# 248710  2015-12-31   86799    CNX                 CONSOL ENERGY INC   0.004963
# 249242  2015-12-31   86964   FFIV                  F 5 NETWORKS INC  -0.032897
# 253662  2015-12-31   88590    DNB     DUN & BRADSTREET CORP DEL NEW  -0.053117
# 254183  2015-12-31   88668    MON                   MONSANTO CO NEW  -0.075009
# 254249  2015-12-31   88837   GRMN                        GARMIN LTD  -0.053638
# 258684  2015-12-31   89533   WYNN                  WYNN RESORTS LTD  -0.026838
# 259173  2015-12-31   89641    STX            SEAGATE TECHNOLOGY PLC  -0.207683
# 263784  2015-12-31   91063   VIAB                    VIACOM INC NEW   0.108744
# 267056  2015-12-31   92293    TDC                  TERADATA CORP DE  -0.078828
# 268320  2015-12-31   92709    SNI  SCRIPPS NETWORKS INTERACTIVE INC   0.104229
# 268419  2015-12-31   92890    MJN         MEAD JOHNSON NUTRITION CO  -0.081924
# 269003  2015-12-31   93159    ESV                 E N S C O PLC NEW  -0.364622

# %%
start_date = '2016-12-31'

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()

conditions = [
    # BUY: bm > 0.75 AND mom12m > 0.35 AND mve > -0.5
    ( (analysis_df['bm'] > 0.63) & (analysis_df['mom12m'] > 0.76) ),
    
    # SELL: bm < -0.5 AND mom12m < -0.75
    ( (analysis_df['bm'] < -0.75) & (analysis_df['mom12m'] < -0.75) & (analysis_df['mve'] < 0) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2017.csv', index=False)
sells.to_csv('sells_2017.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                          comnam  ret_fwd_1
# 4921    2016-12-31   10516    ADM       ARCHER DANIELS MIDLAND CO  -0.030849
# 9621    2016-12-31   11404     ED         CONSOLIDATED EDISON INC   0.008693
# 11160   2016-12-31   11674    DTE                 D T E ENERGY CO   0.000920
# 24639   2016-12-31   13688    PCG                    P G & E CORP   0.018030
# 27140   2016-12-31   13936    PVH                      P V H CORP   0.039161
# 30221   2016-12-31   14541    CVX                CHEVRON CORP NEW  -0.054351
# 34934   2016-12-31   15408    KHC                  KRAFT HEINZ CO   0.022161
# 65122   2016-12-31   21207    NEM             NEWMONT MINING CORP   0.064466
# 67731   2016-12-31   21776    EXC                     EXELON CORP   0.010589
# 71808   2016-12-31   22293    GLW                     CORNING INC   0.091071
# 77084   2016-12-31   23085    SCG                  SCANA CORP NEW  -0.062900
# 79191   2016-12-31   23473   CINF       CINCINNATI FINANCIAL CORP  -0.068651
# 84618   2016-12-31   24109    AEP  AMERICAN ELECTRIC POWER CO INC   0.017071
# 90926   2016-12-31   24985    AEE                     AMEREN CORP   0.003222
# 106546  2016-12-31   27959    DUK            DUKE ENERGY CORP NEW   0.011453
# 107343  2016-12-31   27991    PNW      PINNACLE WEST CAPITAL CORP   0.002868
# 122079  2016-12-31   38762     NI                    NISOURCE INC   0.009989
# 156386  2016-12-31   50017    RRC            RANGE RESOURCES CORP  -0.059189
# 223134  2016-12-31   77730    TSN                 TYSON FOODS INC   0.017596
# 233753  2016-12-31   81774    FCX            FREEPORT MCMORAN INC   0.261920
# 237346  2016-12-31   83435   YHOO                       YAHOO INC   0.139243
# 244388  2016-12-31   85792    PWR             QUANTA SERVICES INC   0.029442
#
# --- SELL ---
#           datadate  permno ticker                      comnam  ret_fwd_1
# 22947   2016-12-31   13168   TRIP             TRIPADVISOR INC   0.140424
# 38285   2016-12-31   15797   CSRA                 C S R A INC  -0.026154
# 87335   2016-12-31   24459    PBI            PITNEY BOWES INC   0.047658
# 154668  2016-12-31   49373    HRB             BLOCK H & R INC  -0.066951
# 192203  2016-12-31   64282     LB                L BRANDS INC  -0.085910
# 217838  2016-12-31   76744   VRTX  VERTEX PHARMACEUTICALS INC   0.165203
# 229786  2016-12-31   80286   TSCO       TRACTOR SUPPLY CO NEW  -0.028629
# 232675  2016-12-31   81540    ABC      AMERISOURCEBERGEN CORP   0.115855
# 253405  2016-12-31   88446   ILMN                ILLUMINA INC   0.249991
# 255158  2016-12-31   89002    ADS  ALLIANCE DATA SYSTEMS CORP  -0.000925
# 263900  2016-12-31   91068    CMG  CHIPOTLE MEXICAN GRILL INC   0.116530
# 265109  2016-12-31   91392    WYN      WYNDHAM WORLDWIDE CORP   0.034823
# 265147  2016-12-31   91416    HBI             HANESBRANDS INC   0.098812

# %%
start_date = '2017-12-31'

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()

conditions = [
    # BUY: bm > 0.75 AND mom12m > 0.35 AND mve > -0.5
    ( (analysis_df['bm'] > 0.7) & (analysis_df['mom12m'] > 0.45) ) ,
    
    # SELL: bm < -0.5 AND mom12m < -0.75
    ( (analysis_df['bm'] < -0.45) & (analysis_df['mom12m'] < -0.45) & (analysis_df['mve'] < 0) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2018.csv', index=False)
sells.to_csv('sells_2018.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                          comnam  ret_fwd_1
# 17496   2017-12-31   12369     GM               GENERAL MOTORS CO   0.033443
# 67743   2017-12-31   21776    EXC                     EXELON CORP  -0.024037
# 71820   2017-12-31   22293    GLW                     CORNING INC  -0.025270
# 82998   2017-12-31   23931    XEL              X C E L ENERGY INC  -0.052541
# 83857   2017-12-31   24010    ETR                ENTERGY CORP NEW  -0.034374
# 84630   2017-12-31   24109    AEP  AMERICAN ELECTRIC POWER CO INC  -0.066308
# 88594   2017-12-31   24643   ARNC                     ARCONIC INC   0.101919
# 90938   2017-12-31   24985    AEE                     AMEREN CORP  -0.041207
# 119498  2017-12-31   37284   ANDV                        ANDEAVOR  -0.055249
# 148450  2017-12-31   47896    JPM             JPMORGAN CHASE & CO   0.085671
# 163002  2017-12-31   52708    LEN                     LENNAR CORP  -0.009739
# 165387  2017-12-31   53613     MU           MICRON TECHNOLOGY INC   0.062030
# 166965  2017-12-31   54148    PHM                 PULTE GROUP INC  -0.043907
# 179038  2017-12-31   59408    BAC            BANK OF AMERICA CORP   0.082811
# 199794  2017-12-31   66384    WDC            WESTERN DIGITAL CORP   0.117623
# 204677  2017-12-31   70519      C                   CITIGROUP INC   0.053497
# 222435  2017-12-31   77661    DHI                  D R HORTON INC  -0.040754
# 226790  2017-12-31   79323    ALL                   ALLSTATE CORP  -0.057928
# 241345  2017-12-31   85035   QRVO                       QORVO INC   0.076428
# 242404  2017-12-31   85269    VLO          VALERO ENERGY CORP NEW   0.042974
# 256763  2017-12-31   89179   ANTM                      ANTHEM INC   0.100307
# 257531  2017-12-31   89269    CNC                CENTENE CORP DEL   0.061845
# 268657  2017-12-31   93089   VRSK         VERISK ANALYTICS INC   0.040988

# %%
start_date = '2018-12-31'

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()

conditions = [
    # BUY: bm > 0.75 AND mom12m > 0.35 AND mve > -0.5
    ( (analysis_df['bm'] > 0.85) & (analysis_df['mom12m'] > -0.5) ) | ((analysis_df['bm'] > -0.25) & (analysis_df['mve'] > 1.25) ),
    
    # SELL: bm < -0.5 AND mom12m < -0.75
    ( (analysis_df['bm'] < -0.7) & (analysis_df['mom12m'] < -0.5) ) | ( (analysis_df['mom12m'] < -1.05) & (analysis_df['mve'] < 0.5) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2019.csv', index=False)
sells.to_csv('sells_2019.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                            comnam  ret_fwd_1
# 4945    2018-12-31   10516    ADM         ARCHER DANIELS MIDLAND CO   0.093824
# 13238   2018-12-31   11850    XOM                  EXXON MOBIL CORP   0.072544
# 16958   2018-12-31   12308   CHTR    CHARTER COMMUNICATIONS INC NEW   0.159601
# 20072   2018-12-31   12558    KMI                 KINDER MORGAN INC   0.187757
# 27021   2018-12-31   13928    COP                    CONOCOPHILLIPS   0.083546
# 30245   2018-12-31   14541    CVX                  CHEVRON CORP NEW   0.051765
# 32946   2018-12-31   14889    CFG      CITIZENS FINANCIAL GROUP INC   0.149599
# 33935   2018-12-31   15069    MRO                 MARATHON OIL CORP   0.099016
# 37376   2018-12-31   15707    HPE     HEWLETT PACKARD ENTERPRISE CO   0.178067
# 41472   2018-12-31   16851   DWDP                     DOWDUPONT INC   0.004071
# 42233   2018-12-31   17005    CVS                 C V S HEALTH CORP   0.005989
# 46204   2018-12-31   17830    UTX          UNITED TECHNOLOGIES CORP   0.106747
# 56426   2018-12-31   19502    WBA      WALGREENS BOOTS ALLIANCE INC   0.055415
# 61160   2018-12-31   20482    ABT               ABBOTT LABORATORIES   0.011311
# 67755   2018-12-31   21776    EXC                       EXELON CORP   0.056880
# 69009   2018-12-31   21936    PFE                        PFIZER INC  -0.021344
# 77108   2018-12-31   23085    SCG                    SCANA CORP NEW        NaN
# 79215   2018-12-31   23473   CINF         CINCINNATI FINANCIAL CORP   0.045691
# 85702   2018-12-31   24205    NEE                NEXTERA ENERGY INC   0.027586
# 99054   2018-12-31   26403    DIS                    DISNEY WALT CO   0.014954
# 101045  2018-12-31   26710      L                        LOEWS CORP   0.050185
# 106570  2018-12-31   27959    DUK              DUKE ENERGY CORP NEW   0.015049
# 107110  2018-12-31   27983    XRX                        XEROX CORP   0.425532
# 259856  2018-12-31   90038    AIZ                      ASSURANT INC   0.075606
# 261392  2018-12-31   90386    MOS                     MOSAIC CO NEW   0.103001
#
# --- SELL ---
#           datadate  permno ticker                            comnam  ret_fwd_1
# 9997    2018-12-31   11552   CELG                      CELGENE CORP   0.378147
# 10129   2018-12-31   11600   XRAY               DENTSPLY SIRONA INC   0.125285
# 13328   2018-12-31   11891    MGM       M G M RESORTS INTERNATIONAL   0.211420
# 18967   2018-12-31   12490    IBM  INTERNATIONAL BUSINESS MACHS COR   0.180446
# 19677   2018-12-31   12542   NLSN              NIELSEN HOLDINGS PLC   0.098629
# ...            ...     ...    ...                               ...        ...
# 258720  2018-12-31   89533   WYNN                  WYNN RESORTS LTD   0.241556
# 259540  2018-12-31   89866    LKQ                        L K Q CORP   0.102830
# 263299  2018-12-31   90880    AMP          AMERIPRISE FINANCIAL INC   0.210892
# 265171  2018-12-31   91416    HBI                   HANESBRANDS INC   0.194229
# 267388  2018-12-31   92602     PM   PHILIP MORRIS INTERNATIONAL INC   0.147091
#
# [70 rows x 5 columns]

# %%
start_date = '2019-12-31'

# 3. Create the filtered DataFrame for your analysis
# analysis_df = green_cleaned[
#     (green_cleaned['datadate'] >= start_date) & 
#     (green_cleaned['datadate'] <= end_date)
# ][variables].copy()

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()

conditions = [
    # BUY: bm > 0.75 AND mom12m > 0.35 AND mve > -0.5
    ( (analysis_df['bm'] > 0.85) & (analysis_df['mom12m'] > -0.4) ) & ((analysis_df['mve'] > -0.75) ),
    
    # SELL: bm < -0.5 AND mom12m < -0.75
    ( (analysis_df['bm'] < -0.75) & (analysis_df['mom12m'] < -0.55) ) & ( (analysis_df['mve'] < 0) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2020.csv', index=False)
sells.to_csv('sells_2020.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                            comnam  ret_fwd_1
# 9657    2019-12-31   11404     ED           CONSOLIDATED EDISON INC   0.037718
# 17520   2019-12-31   12369     GM                 GENERAL MOTORS CO  -0.089005
# 20084   2019-12-31   12558    KMI                 KINDER MORGAN INC  -0.003662
# 32297   2019-12-31   14776    SYF               SYNCHRONY FINANCIAL  -0.101272
# 37388   2019-12-31   15707    HPE     HEWLETT PACKARD ENTERPRISE CO  -0.122990
# 84114   2019-12-31   24053   EVRG                        EVERGY INC   0.107319
# 101057  2019-12-31   26710      L                        LOEWS CORP  -0.021113
# 106582  2019-12-31   27959    DUK              DUKE ENERGY CORP NEW   0.069087
# 109624  2019-12-31   28484    HES                         HESS CORP  -0.154570
# 115387  2019-12-31   34746   FITB               FIFTH THIRD BANCORP  -0.075796
# 148474  2019-12-31   47896    JPM               JPMORGAN CHASE & CO  -0.045346
# 163026  2019-12-31   52708    LEN                       LENNAR CORP   0.190401
# 172753  2019-12-31   57904    AFL                         AFLAC INC  -0.026442
# 179062  2019-12-31   59408    BAC              BANK OF AMERICA CORP  -0.069159
# 180226  2019-12-31   59459    TRV           TRAVELERS COMPANIES INC  -0.040219
# 182521  2019-12-31   60442    PNC  P N C FINANCIAL SERVICES GRP INC  -0.063506
# 198201  2019-12-31   66093      T                       A T & T INC  -0.025353
# 200357  2019-12-31   66800    AIG  AMERICAN INTERNATIONAL GROUP INC  -0.022146
# 202301  2019-12-31   69032     MS   MORGAN STANLEY DEAN WITTER & CO   0.027847
# 204701  2019-12-31   70519      C                     CITIGROUP INC  -0.063511
# 206231  2019-12-31   71563    BBT                      B B & T CORP  -0.085640
# 224448  2019-12-31   78916    AGN                      ALLERGAN PLC  -0.024996
# 226814  2019-12-31   79323    ALL                     ALLSTATE CORP   0.052857
# 231542  2019-12-31   81055    COF        CAPITAL ONE FINANCIAL CORP  -0.031521
# 236445  2019-12-31   82775    HIG   HARTFORD FINANCIAL SVCS GRP INC  -0.025819
# 242428  2019-12-31   85269    VLO            VALERO ENERGY CORP NEW  -0.101033
# 248943  2019-12-31   86868     GS           GOLDMAN SACHS GROUP INC   0.032710
# 252655  2019-12-31   87842    MET                       METLIFE INC  -0.026021
# 257057  2019-12-31   89195    PFG     PRINCIPAL FINANCIAL GROUP INC  -0.038573
#
# --- SELL ---
#           datadate  permno ticker                       comnam  ret_fwd_1
# 63310   2019-12-31   21020    AAL  AMERICAN AIRLINES GROUP INC  -0.065456
# 117822  2019-12-31   36003    ROL                  ROLLINS INC   0.143151
# 143479  2019-12-31   46578    CLX                    CLOROX CO   0.030158
# 154704  2019-12-31   49373    HRB              BLOCK H & R INC  -0.013225
# 172500  2019-12-31   57817    JWN                NORDSTROM INC  -0.100738
# 192239  2019-12-31   64282     LB                 L BRANDS INC   0.276846
# 208286  2019-12-31   75107   ABMD                  ABIOMED INC   0.090734
# 234946  2019-12-31   82598   NTAP                   NETAPP INC  -0.135758
# 242988  2019-12-31   85459   CHRW    CH ROBINSON WORLDWIDE INC  -0.077771
# 249290  2019-12-31   86964   FFIV             F 5 NETWORKS INC  -0.126828
# 267118  2019-12-31   92322   ULTA              ULTA BEAUTY INC   0.057047

# %%
start_date = '2020-12-31'

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()


conditions = [
    # BUY: bm > 0.75 AND mom12m > 0.75 AND mve > -0.5
    ( (analysis_df['bm'] > 0.75) & (analysis_df['mom12m'] > 0.75) ) & ((analysis_df['mve'] > -0.5) ),
    
    # SELL: bm < -1.0 OR mom12m < -1.0
    ( (analysis_df['bm'] < -1)  ) | ( (analysis_df['mom12m'] < -1) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2021.csv', index=False)
sells.to_csv('sells_2021.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker        comnam  ret_fwd_1
# 51488   2020-12-31   18592   CTVA   CORTEVA INC   0.029342
# 65170   2020-12-31   21207    NEM  NEWMONT CORP  -0.004942
# 163038  2020-12-31   52708    LEN   LENNAR CORP   0.093957
#
# --- SELL ---
#           datadate  permno ticker                           comnam  ret_fwd_1
# 13262   2020-12-31   11850    XOM                 EXXON MOBIL CORP   0.087721
# 13352   2020-12-31   11891    MGM      M G M RESORTS INTERNATIONAL  -0.093721
# 15289   2020-12-31   12060     GE              GENERAL ELECTRIC CO  -0.011211
# 15869   2020-12-31   12073   PBCT     PEOPLES UNITED FINANCIAL INC   0.070279
# 20096   2020-12-31   12558    KMI                KINDER MORGAN INC   0.049095
# ...            ...     ...    ...                              ...        ...
# 266226  2020-12-31   91926    DAL              DELTA AIR LINES INC  -0.056056
# 266957  2020-12-31   92239    CXO             CONCHO RESOURCES INC        NaN
# 267211  2020-12-31   92402   MSCI                      M S C I INC  -0.114829
# 267412  2020-12-31   92602     PM  PHILIP MORRIS INTERNATIONAL INC  -0.038027
# 269157  2020-12-31   93429   CBOE       C B O E GLOBAL MARKETS INC  -0.015027
#
# [120 rows x 5 columns]

# %%
start_date = '2021-12-31'

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()


conditions = [
    # BUY: bm < -0.65 AND mom12m > 0.65 AND mve > -0.5
    ( (analysis_df['bm'] < -0.65) & (analysis_df['mom12m'] > 0.65) ) & ((analysis_df['mve'] > -0.5) ),
    
    # SELL: bm > 0.65 AND mom12m < -0.65
    ( (analysis_df['bm'] >0.65)  ) & ( (analysis_df['mom12m'] < -0.65) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2022.csv', index=False)
sells.to_csv('sells_2022.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                            comnam  ret_fwd_1
# 801     2021-12-31   10104   ORCL                       ORACLE CORP  -0.065703
# 1168    2021-12-31   10107   MSFT                    MICROSOFT CORP  -0.075345
# 9141    2021-12-31   11403   CDNS        CADENCE DESIGN SYSTEMS INC  -0.183579
# 20611   2021-12-31   12622    HCA              H C A HEALTHCARE INC  -0.065663
# 34612   2021-12-31   15291   ETSY                          ETSY INC  -0.282543
# 145980  2021-12-31   46886   KLAC                        K L A CORP  -0.094952
# 158085  2021-12-31   50876    LLY                    LILLY ELI & CO  -0.111614
# 186374  2021-12-31   61399    LOW               LOWES COMPANIES INC  -0.078652
# 187283  2021-12-31   61735    AON                       AON PLC NEW  -0.078553
# 189656  2021-12-31   62498    WST  WEST PHARMACEUTICAL SERVICES INC  -0.161212
# 216339  2021-12-31   76605    AZO                      AUTOZONE INC  -0.052490
# 224858  2021-12-31   78975   INTU                        INTUIT INC  -0.135739
# 227683  2021-12-31   79698     IT                       GARTNER INC  -0.120932
# 247825  2021-12-31   86356   EBAY                          EBAY INC  -0.096692
# 248132  2021-12-31   86580   NVDA                       NVIDIA CORP  -0.167454
# 253306  2021-12-31   88352   ISRG            INTUITIVE SURGICAL INC  -0.209073
# 262523  2021-12-31   90664   DXCM                        DEXCOM INC  -0.198287
# 263629  2021-12-31   91041    LYV     LIVE NATION ENTERTAINMENT INC  -0.085053
# 267223  2021-12-31   92402   MSCI                       M S C I INC  -0.124973
# 268925  2021-12-31   93132   FTNT                      FORTINET INC  -0.172955
# 269218  2021-12-31   93436   TSLA                         TESLA INC  -0.113609
#
# --- SELL ---
#           datadate  permno ticker                      comnam  ret_fwd_1
# 9681    2021-12-31   11404     ED     CONSOLIDATED EDISON INC   0.013244
# 38005   2021-12-31   15720    EIX        EDISON INTERNATIONAL  -0.080000
# 41508   2021-12-31   16851     DD       DUPONT DE NEMOURS INC  -0.051746
# 58911   2021-12-31   20057   VTRS                 VIATRIS INC   0.106430
# 72786   2021-12-31   22517    PPL                  P P L CORP  -0.012641
# 107403  2021-12-31   27991    PNW  PINNACLE WEST CAPITAL CORP  -0.001842
# 133543  2021-12-31   42585    SJM              SMUCKER J M CO   0.035046
# 165435  2021-12-31   53613     MU       MICRON TECHNOLOGY INC  -0.116801
# 167013  2021-12-31   54148    PHM             PULTE GROUP INC  -0.078202
# 177554  2021-12-31   59248    TAP    MOLSON COORS BEVERAGE CO   0.028263
# 189459  2021-12-31   62308     GL              GLOBE LIFE INC   0.093657
# 191703  2021-12-31   64186     CI              CIGNA CORP NEW   0.003615
# 198225  2021-12-31   66093      T                 A T & T INC   0.057724

# %%
start_date = '2022-12-31'

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()


conditions = [
    # BUY: if (bm > 0.8 AND mom12m > 0.6) OR (mve < 0.2 AND bm > 1.1)
    ( (analysis_df['bm'] >0.8) & (analysis_df['mom12m'] > 0.6) ) | ((analysis_df['mve'] < 0.2) & (analysis_df['bm'] > 1.1) ),
    
    # SELL: if mom12m < -1.1 OR bm < -1.1:
    ( (analysis_df['bm'] < -1.1)  ) | ( (analysis_df['mom12m'] < -1.1) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2023.csv', index=False)
sells.to_csv('sells_2023.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                           comnam  ret_fwd_1
# 4993    2022-12-31   10516    ADM        ARCHER DANIELS MIDLAND CO  -0.111201
# 9693    2022-12-31   11404     ED          CONSOLIDATED EDISON INC  -0.003500
# 13286   2022-12-31   11850    XOM                 EXXON MOBIL CORP   0.048268
# 20120   2022-12-31   12558    KMI                KINDER MORGAN INC   0.024017
# 21341   2022-12-31   12872    MPC          MARATHON PETROLEUM CORP   0.100719
# 23546   2022-12-31   13356    PSX                      PHILLIPS 66  -0.040107
# 24085   2022-12-31   13641   FANG           DIAMONDBACK ENERGY INC   0.064785
# 24666   2022-12-31   13688    PCG                     P G & E CORP  -0.025640
# 30293   2022-12-31   14541    CVX                 CHEVRON CORP NEW  -0.033975
# 32994   2022-12-31   14889    CFG     CITIZENS FINANCIAL GROUP INC   0.107498
# 33983   2022-12-31   15069    MRO                MARATHON OIL CORP   0.011277
# 35006   2022-12-31   15408    KHC                   KRAFT HEINZ CO  -0.007922
# 37424   2022-12-31   15707    HPE    HEWLETT PACKARD ENTERPRISE CO   0.007152
# 41520   2022-12-31   16851     DD            DUPONT DE NEMOURS INC   0.074017
# 46252   2022-12-31   17830    RTX       RAYTHEON TECHNOLOGIES CORP  -0.014103
# 51512   2022-12-31   18592   CTVA                      CORTEVA INC   0.092961
# 58923   2022-12-31   20057   VTRS                      VIATRIS INC   0.089043
# 64660   2022-12-31   21186    WRK                      WESTROCK CO   0.112541
# 79263   2022-12-31   23473   CINF        CINCINNATI FINANCIAL CORP   0.101588
# 86783   2022-12-31   24328    EQT                       E Q T CORP  -0.037789
# 92190   2022-12-31   25081    CMA                     COMERICA INC   0.093134
# 101093  2022-12-31   26710      L                       LOEWS CORP   0.050503
# 107415  2022-12-31   27991    PNW       PINNACLE WEST CAPITAL CORP  -0.011719
# 109133  2022-12-31   28388    VNO             VORNADO REALTY TRUST        NaN
# 113626  2022-12-31   32986    ATO                ATMOS ENERGY CORP   0.045309
# 115423  2022-12-31   34746   FITB              FIFTH THIRD BANCORP   0.102565
# 116826  2022-12-31   35044     RF       REGIONS FINANCIAL CORP NEW   0.088337
# 117783  2022-12-31   35554    MTB                  M & T BANK CORP   0.071917
# 119804  2022-12-31   37584    BEN           FRANKLIN RESOURCES INC   0.179214
# 126774  2022-12-31   40125    DXC              D X C TECHNOLOGY CO   0.080651
# 133555  2022-12-31   42585    SJM                   SMUCKER J M CO  -0.039219
# 134680  2022-12-31   42906   HBAN        HUNTINGTON BANCSHARES INC   0.072387
# 153758  2022-12-31   49015    LNC            LINCOLN NATIONAL CORP   0.164469
# 264260  2022-12-31   91152    TDG              TRANSDIGM GROUP INC   0.136419
# 267436  2022-12-31   92602     PM  PHILIP MORRIS INTERNATIONAL INC   0.026438
# 269027  2022-12-31   93246   GNRC             GENERAC HOLDINGS INC   0.194593
# 269230  2022-12-31   93436   TSLA                        TESLA INC   0.402735
#
# [72 rows x 5 columns]

# %%
start_date = '2023-12-31'

analysis_df = green_cleaned[
    (green_cleaned['datadate'] == start_date)
][variables].copy()


conditions = [
    # BUY: if bm > 0.95 AND mve > 0.3 AND mom12m > -0.5:
    ( (analysis_df['bm'] >0.95) & (analysis_df['mve'] > 0.3) ) & ((analysis_df['mom12m'] > -0.5) ),
    
    # SELL: if (bm < -0.75 OR mom12m < -0.55 OR mve < -0.75) AND NOT (mom12m > 1.5):
    ( (analysis_df['bm'] < -0.75) | ( analysis_df['mom12m'] < -0.55 ) | ( analysis_df['mve'] < -0.75 )  ) & ( (analysis_df['mom12m'] <= 1.5) )
]

# 3. Define choices
choices = ['BUY', 'SELL']

# 4. Create the 'signal' column
analysis_df['signal'] = np.select(conditions, choices, default='HOLD')

buys = analysis_df[analysis_df['signal'] == 'BUY'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]
sells = analysis_df[analysis_df['signal'] == 'SELL'][['datadate', 'permno', 'ticker', 'comnam', 'ret_fwd_1']]


print("\n--- BUY ---")
with pd.option_context('display.max_rows', None):
    print(buys)


print("\n--- SELL ---")
print(sells)

buys.to_csv('buys_2024.csv', index=False)
sells.to_csv('sells_2024.csv', index=False)
# Out:
# --- BUY ---
#           datadate  permno ticker                            comnam  ret_fwd_1
# 23558   2023-12-31   13356    PSX                       PHILLIPS 66   0.079197
# 121873  2023-12-31   38703    WFC              WELLS FARGO & CO NEW   0.014804
# 148522  2023-12-31   47896    JPM               JPMORGAN CHASE & CO   0.026517
# 165459  2023-12-31   53613     MU             MICRON TECHNOLOGY INC   0.000104
# 178224  2023-12-31   59328   INTC                        INTEL CORP  -0.147387
# 198249  2023-12-31   66093      T                       A T & T INC   0.066069
# 200405  2023-12-31   66800    AIG  AMERICAN INTERNATIONAL GROUP INC   0.021278
#
# --- SELL ---
#           datadate  permno ticker                       comnam  ret_fwd_1
# 1654    2023-12-31   10138   TROW       T ROWE PRICE GROUP INC   0.002357
# 5005    2023-12-31   10516    ADM    ARCHER DANIELS MIDLAND CO  -0.235107
# 8795    2023-12-31   11308     KO                 COCA COLA CO   0.004803
# 9839    2023-12-31   11533   FICO              FAIR ISAAC CORP   0.025214
# 10189   2023-12-31   11600   XRAY          DENTSPLY SIRONA INC  -0.028302
# ...            ...     ...    ...                          ...        ...
# 267629  2023-12-31   92611      V                     VISA INC   0.044887
# 267735  2023-12-31   92614    AWK  AMERICAN WATER WORKS CO INC  -0.065083
# 268874  2023-12-31   93096     DG      DOLLAR GENERAL CORP NEW  -0.028900
# 268949  2023-12-31   93132   FTNT                 FORTINET INC   0.097128
# 269039  2023-12-31   93246   GNRC         GENERAC HOLDINGS INC  -0.125174
#
# [274 rows x 5 columns]
